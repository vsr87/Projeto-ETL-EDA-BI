# %% [markdown]
# # **Desafio**

# %% [markdown]
# ## **Descrição do cenário**

# %% [markdown]
# A empresa C3 atua no setor financeiro e acompanha o comportamento de ativos negociados em diferentes bolsas de valores ao redor do mundo. Com o aumento da volatilidade dos mercados e o crescimento da quantidade de dados financeiros disponíveis, a empresa busca formas mais inteligentes de orientar suas decisões estratégicas. Visando transformar dados brutos em conhecimento acionável, a C3 reuniu uma base robusta contendo informações históricas de preços, volumes, dividendos, indicadores financeiros e dados setoriais. Apesar da riqueza desses dados, eles ainda não foram analisados de forma estruturada.

# %% [markdown]
# ---
# ## **Problema a ser resolvido**

# %% [markdown]
# Para potencializar sua atuação, a C3 deseja compreender como diferentes variáveis influenciam o desempenho das ações e quais padrões podem ser extraídos para embasar previsões e escolhas de investimento mais eficazes. Essa iniciativa visa identificar oportunidades ocultas, riscos potenciais e gerar inteligência competitiva baseada em dados. Então, você foi desafiado a analisar esse conjunto de dados e ajudar a C3 a encontrar respostas para as seguintes perguntas:
#
# - Quais são os fatores que mais influenciam o preço de fechamento das ações ao longo do tempo?
# - Existe alguma associação entre características setoriais/industriais e o desempenho das ações?
# - Como o volume de negociações e os dividendos distribuídos se comportam entre diferentes setores e ao longo do tempo?
# - O que pode ser feito para otimizar as vendas?

# %% [markdown]
# ---
# # **ETL (Extract, Transform, Load)**

# %% [markdown]
# ## **Importação das bibliotecas**

# %% [markdown]
# -> Começaremos importando as bibliotecas que vão nos dar as ferramentas necessárias para o processo de ETL:
#
# - Pandas: para manipulação e análise de dados estruturados em tabelas
# - NumPy: para realizar operações matemáticas eficientes
# - thefuzz: usada para fuzzy matching, ou seja, para comparar strings que são parecidas, mas não exatamente iguais
# - re: biblioteca para trabalhar com strings
# - matplotlib: usada para criação de gráficos
# - google.colab: usada para acessar o google Drive pelo Colab
#
# -> O pip install abaixo é para baixar a biblioteca thefuzz e p drive.mount é para acessar de fato o Drive

# %%
# !pip install thefuzz[speedup]
# Out:
# Collecting thefuzz[speedup]
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz[speedup])
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.9 MB/s eta 0:00:00
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Installing collected packages: rapidfuzz, thefuzz
# Successfully installed rapidfuzz-3.13.0 thefuzz-0.22.1

# %%
#Importando as libs que serão utilizadas durante o tratamento dos dados
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from google.colab import drive
from thefuzz import fuzz, process

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# ## **Etapa *Extract***

# %% [markdown]
# -> Nessa primeira etapa, coletaremos os dados da base para determinadas variáveis, com as quais trabalharemos no decorrer da ETL
#
# ---

# %% [markdown]
# ### **Base stock_part1**

# %% [markdown]
# -> Primeiramente, importaremos a base *stock_part1*, no formato CSV, copiando-a para a variável "base1", que será usada para manipulação e tratamento

# %%
# Importando a base de dados stock_part1
base1 = pd.read_csv('/content/drive/MyDrive/pta/stock_part1.csv')

# %% [markdown]
# ---
# -> Agora vamos analisar o tamanho da base1

# %%
base1.shape
# Out:
# (200000, 11)

# %% [markdown]
# ---
# -> Agora, faremos uma visualização geral da base olhando apenas as primeiras linhas para entender a estrutura e conteúdo

# %%
# Visualizando as 10 primeiras linhas da base
base1.head(10)
# Out:
#    ID          Date Ticker     Open     High       Low    Close Adj Close  \
# 0   1    2023-09-03   meta   258.44   909.63   1380.05   595,86     61.54
# 1   2  Aug 28, 2024   NVDA   678.96   725.03    185.51   295.83    843.78
# 2   3  May 10, 2022   INTU  1348.94   215.00    831.86   874.05   $336,19
# 3   4    2017-12-26   NVDA  $186.39  1111.85    508.65   511.49   $952.63
# 4   5  Jan 20, 2022   WORK  1425.94   692.20    340.75  $378.58   1493.44
# 5   6    12/12/2016   GOOG    61.76   262,36  $1315.19   793.41    174.00
# 6   7    2015-11-13   tsla  1112.92   105,69   1342.15   917.22     57.66
# 7   8    31/01/2015   NVDA   485.90   190.38    425.99   866.78   1434.97
# 8   9  Feb 14, 2021   NFLX  $676.41  1033.25    604,71   524.23    350.97
# 9  10    2024-11-17   adbe  $522.85  $322.90    373.11   652.81    274.67
#
#           Volume Dividend Split Ratio
# 0  8,846,040,350     3.57         1:1
# 1     7346935699     2.85         3:2
# 2  8,027,589,419     2.28         2:1
# 3        1939.5M     4.51         3:2
# 4     8984007687     1.93         NaN
# 5     1434944091     4.09         3:2
# 6     4621479471     0.33         NaN
# 7     5081802848     0.33         2:1
# 8     7748945628     2.64         2:1
# 9     8357743507     2.41         2:1

# %% [markdown]
# ---
# -> Assim, podemos definir o **Dicionário dos dados** da base1:
#
# 1. **ID**
#   - Tipo: numérico
#   - Descrição: identificador único de cada linha do dataset, sendo uma sequência
#
# 2. **Date**
#   - Tipo: string
#   - Descrição: data dos dados da ação naquele dia
#
# 3. **Ticker**
#   - Tipo: string
#   - Descrição: código da empresa negociada na bolsa de valores
#
# 4. **Open**
#   - Tipo: numérico c
#   - Descrição: preço da ação no momento de abertura do mercado no dia especificado em "Date"
#
# 5. **High**
#   - Tipo: numérico (dólar)
#   - Descrição: maior valor que a ação atingiu durante o dia especificado em "Date"
#
# 6. **Low**
#   - Tipo: numérico (dólar)
#   - Descrição: menor valor que a ação atingiu no dia especificado em "Date"
#
# 7. **Close**
#   - Tipo: numérico (dólar)
#   - Descrição: preço da ação no fechamento do mercado no dia especificado em "Date"
#
# 8. **Adj Close (Adjusted Close)**
#   - Tipo: numérico (dólar)
#   - Descrição: preço de fechamento ajustado por eventos como dividendos, desdobramentos (splits), e distribuições, sendo mais apropriado para análise de performance ao longo do tempo
#
# 9. **Volume**
#   - Tipo: numérico
#   - Descrição: quantidade de ações negociadas no dia especificado em "Date"
#
# 10. **Dividendo**
#   - Tipo: numérico (dólar)
#   - Descrição: valor do dividendo pago por ação naquele dia
#
# 11. **Split Radio**
#   - Tipo: string (essência numérica)
#   - Descrição: mostra se houve desdobramento (split) ou agrupamento de ações nesse dia ()
#   ---

# %% [markdown]
# ### **Base stock_part2**

# %% [markdown]
# -> Primeiramente, importaremos a base *stock_part2*, no formato CSV, copiando-a para a variável "base2", que será usada para manipulação e tratamento

# %%
# Importando a base de dados stock_part2 do Drive
base2 = pd.read_csv('/content/drive/MyDrive/pta/stock_part2.csv')

# %% [markdown]
# ---
# -> Agora, faremos uma visualização geral da base olhando apenas as primeiras linhas para entender a estrutura e conteúdo

# %%
# Visualizando as 5 primeiras linhas da base
base2.head()
# Out:
#    ID       Sector        Industry Exchange   Currency        MarketCap  \
# 0   1      TELECOM       Chemicals     NYSE        USD  370,815,220,190
# 1   2  Real Estate   Property Mgmt      TSE          $    1289775810656
# 2   3   healthcare         Biotech      LSE          $      97815908000
# 3   4      Telecom  Electric Power     HKEX          $    1658573090566
# 4   5       retail         Banking   NASDAQ  US DOLLAR     315341356874
#
#   PE Ratio    EPS Next Earnings Previous Close        Day Range
# 0    27.40  16.68  May 19, 2025         567.57   X095.58-898.36
# 1    90.13   0,57    06-23-2025        $185.1Z    907.52-552.85
# 2   $15.67  18.17    07-21-2025         823.07  1380.78-1361.69
# 3    83.90  -4.82    23/07/2025         179.88    457.99-138.11
# 4    79.86   5.67    08/06/2025       $1004.79    644.16-920.32

# %% [markdown]
# ---
# -> Assim, podemos definir o **Dicionário dos dados** da base2:
#
# 1. **ID**
#   - Tipo: numérico
#   - Descrição: identificador único de cada linha do dataset, sendo uma sequência
#
# 2. **Sector**
#   - Tipo: string
#   - Descrição: Mostra qual o setor da empresa
#
# 3. **Industry**
#   - Tipo: string
#   - Descrição: Mostra com qual industria a empresa trabalha, sendo uma sub parte de sector
#
# 4. **Exchange**
#   - Tipo: numérico
#   - Descrição: Bolsa de valores onde ações da empresa são negociadas.
#
# 5. **Currency**
#   - Tipo: numérico
#   - Descrição: Qual o tipo de moeda usada na negociação(USD)
#
# 6. **Market Cap**
#   - Tipo: numérico
#   - Descrição: Valor atual da empresa na bolsa de valores
#
# 7. **PE Ratio**
#   - Tipo: numérico
#   - Descrição: Indica quantos dólares os investidores estão pagando por cada dólar de lucro que a empresa gera
#
# 8. **EPS**
#   - Tipo: numérico (dólar)
#   - Descrição: indica quanto de lucro líquido cada ação da empresa gerou no período analisado, dividindo o lucro pela quantidade de ações compradas
#
# 9. **Next Earnings**
#   - Tipo: data
#   - Descrição: significa o próximo anúncio de resultados (lucros) da empresa
#
# 10. **Previous Close**
#   - Tipo: numérico (dólar)
#   - Descrição: é o último preço pelo qual a ação foi negociada no final do dia anterior
#
# 11. **Day Range**
#   - Tipo: numérico
#   - Descrição: mostra a variação de preço da ação ao longo do dia atual de negociação
#     ---

# %% [markdown]
# ---
# ## **Etapa *Transform***

# %% [markdown]
# -> Nessa segunda etapa, faremos a limpeza e padronização dos dados que coletamos
#
# ---

# %% [markdown]
# ### **Base stock_part1**

# %% [markdown]
# -> Primeiro vamos verificar se existem valores nulos na nossa base

# %% [markdown]
# #### **Análise de dados faltantes**

# %%
# Armazena o número de dados faltantes de cada coluna da base na variável "dados_faltantes"
dados_faltantes = base1.isnull().sum()
print(dados_faltantes)
# Out:
# ID                 0
# Date               0
# Ticker             0
# Open               0
# High               0
# Low                0
# Close              0
# Adj Close          0
# Volume             0
# Dividend           0
# Split Ratio    38480
# dtype: int64

# %% [markdown]
# -> Notamos que apenas a coluna Split Ratio apresenta dados faltantes. No subtópico do tratamento específico desta coluna, adotaremos as medidas necessárias
#
# ---

# %% [markdown]
# #### **Análises de linhas duplicadas**

# %%
# Retorna o número de linhas duplicadas
base1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# -> Notamos que não haverá preocupação em excluir linhas duplicadas
#
# ---

# %% [markdown]
# #### **Tratamento da coluna Date**

# %% [markdown]
# ->  Aqui faremos a padronização da coluna Date, deixando as datas com dia, mês e ano, nessa ordem, separados por "-". Demos uma varrida visualmente nos dados e percebemos que as principais diferenças em relação a padronização foram:
#
# - Uso de "/" para separação
# - Formato americano
# - Mês por escrito
# - Número correspondente ao dia/mês irreal (ex: mês 65)
#
# -> Assim, padronizaremos usando um módulo de análises de datas usado para interpretar e converter automaticamente as datas escritas em diferentes formatos para a data padrão "XX-XX-XXXX". Isso será feito em uma variável temporária chamada "base_tmp1" para testar as modificações sem afetar a base original

# %%
# importa o módulo de análise de datas chamado parser, que serve para interpretar e converter automaticamente datas escritas em diferentes formatos para data padrão do Python (datetime)
from dateutil import parser

# Cópia da base original para teste
base_tmp1 = base1.copy()

# Função para padronizar datas deixando-as no formato DD-MM-YYYY
def padronizar_data(data):
    try:
        data_convertida = parser.parse(str(data), dayfirst=False)
        return data_convertida.strftime('%d-%m-%Y')
    except Exception:
        return data  # Caso falhe na conversão

# Aplica a função à coluna 'Date'
base_tmp1['Date'] = base_tmp1['Date'].apply(padronizar_data)

# %% [markdown]
# ---
# -> Analisaremos agora o quantitativo de datas ainda não padronizadas (datas com números inexistentes para dia ou mês, ou seja, datas irreais)

# %%
# Expressão regular para o formato DD-MM-AAAA
padrao_data = r'^\d{2}-\d{2}-\d{4}$'

# Garante que todos os valores sejam tratados como string
base_tmp1['Date'] = base_tmp1['Date'].astype(str)

# Conta quantas datas NÃO seguem o padrão
datas_nao_padronizadas = ~base_tmp1['Date'].str.match(padrao_data)
quantidade_nao_padronizadas = datas_nao_padronizadas.sum()

print(f"Número de datas não padronizadas: {quantidade_nao_padronizadas}")
# Out:
# Número de datas não padronizadas: 2030

# %% [markdown]
# ---
# -> Agora realizaremos os ajustes para as datas que não estão padronizadas por terem números não correspondentes com dia ou mês, ou seja, por serem irreais.
#
# -> Para isso, substituiremos essas datas errôneas pela moda geral da coluna
#
# -> Primeiramente, vamos encontrar a data modal

# %%
# Filtra somente as datas válidas no formato DD-MM-AAAA
datas_validas = base_tmp1['Date'].dropna().astype(str)
datas_formatadas = datas_validas[datas_validas.str.match(padrao_data)]

# Calcula a moda das datas válidas
moda_data = datas_formatadas.mode()

# Exibe o resultado
if not moda_data.empty:
    print(f"Moda da coluna 'Date' (apenas datas válidas): {moda_data.iloc[0]}")
else:
    print("Nenhuma data válida no formato DD-MM-AAAA foi encontrada.")
# Out:
# Moda da coluna 'Date' (apenas datas válidas): 20-06-2017

# %% [markdown]
# ---
# -> Agora faremos a substituição

# %%
# Garante que a coluna 'Date' seja string
base_tmp1['Date'] = base_tmp1['Date'].astype(str)

# Identifica as datas válidas
datas_validas = base_tmp1['Date'][base_tmp1['Date'].str.match(padrao_data)]

# Calcula a moda das datas válidas
moda_data = datas_validas.mode().iloc[0] if not datas_validas.empty else None

# Substitui datas inválidas pela moda, se a moda existir
if moda_data:
    # Cria uma máscara para identificar as datas inválidas
    mascara_invalidas = ~base_tmp1['Date'].str.match(padrao_data)

    # Conta quantas substituições serão feitas
    total_substituicoes = mascara_invalidas.sum()

    # Realiza a substituição
    base_tmp1.loc[mascara_invalidas, 'Date'] = moda_data

    print(f"{total_substituicoes} datas inválidas foram substituídas pela moda: {moda_data}")
else:
    print("Nenhuma data válida no formato DD-MM-AAAA foi encontrada para substituição.")
# Out:
# 2030 datas inválidas foram substituídas pela moda: 20-06-2017

# %%
# Garante que todos os valores sejam tratados como string
base_tmp1['Date'] = base_tmp1['Date'].astype(str)

# Conta quantas datas NÃO seguem o padrão
datas_nao_padronizadas = ~base_tmp1['Date'].str.match(padrao_data)
quantidade_nao_padronizadas = datas_nao_padronizadas.sum()

print(f"Número de datas não padronizadas: {quantidade_nao_padronizadas}")
# Out:
# Número de datas não padronizadas: 0

# %% [markdown]
# ---
#
# -> Agora vamos converter para o formato da biblioteca datetime () para facilitar nossas futuras análises

# %%
# Limpa a coluna Date antes da conversão
base_tmp1['Date'] = base_tmp1['Date'].astype(str).str.strip()

# Converte para datetime com formato explícito
base_tmp1['Date'] = pd.to_datetime(base_tmp1['Date'], format='%d-%m-%Y', errors='coerce')

# %% [markdown]
# ---
# -> Agora vamos visualizar as mudanças na base

# %%
base_tmp1.head(10)
# Out:
#    ID       Date Ticker     Open     High       Low    Close Adj Close  \
# 0   1 2023-09-03   meta   258.44   909.63   1380.05   595,86     61.54
# 1   2 2024-08-28   NVDA   678.96   725.03    185.51   295.83    843.78
# 2   3 2022-05-10   INTU  1348.94   215.00    831.86   874.05   $336,19
# 3   4 2017-12-26   NVDA  $186.39  1111.85    508.65   511.49   $952.63
# 4   5 2022-01-20   WORK  1425.94   692.20    340.75  $378.58   1493.44
# 5   6 2016-12-12   GOOG    61.76   262,36  $1315.19   793.41    174.00
# 6   7 2015-11-13   tsla  1112.92   105,69   1342.15   917.22     57.66
# 7   8 2015-01-31   NVDA   485.90   190.38    425.99   866.78   1434.97
# 8   9 2021-02-14   NFLX  $676.41  1033.25    604,71   524.23    350.97
# 9  10 2024-11-17   adbe  $522.85  $322.90    373.11   652.81    274.67
#
#           Volume Dividend Split Ratio
# 0  8,846,040,350     3.57         1:1
# 1     7346935699     2.85         3:2
# 2  8,027,589,419     2.28         2:1
# 3        1939.5M     4.51         3:2
# 4     8984007687     1.93         NaN
# 5     1434944091     4.09         3:2
# 6     4621479471     0.33         NaN
# 7     5081802848     0.33         2:1
# 8     7748945628     2.64         2:1
# 9     8357743507     2.41         2:1

# %% [markdown]
# ---
# #### **Tratamento das colunas Open, High, Low, Close, Adj Close e Dividend**

# %% [markdown]
# -> Aqui faremos a padronização das colunas mencionadas, deixando os números em dólar e na notação numérica com "." separando parte inteira de decimal (convertido para float). Demos uma varrida visualmente nos dados e percebemos que as principais diferenças em relação a padronização foram:
# - A presença de vírgula para separar a parte decimal e também a parte de milhar
# - A presença do símbolo "$"
# - A preseça de letras, como "Z"
#
# -> Assim, esses foram nosso foco na implementação da função de padronização. Porém, sabemos que podem haver outras variações que não notamos. Por isso, resolvemos fazer uma contagem das linhas de cada coluna que foram mantidas por já estarem padronizadas + as linhas de cada coluna que foram padronizadas e convertidas para float e comparar com o número total de linhas de cada coluna. Logo, se não forem iguais é porque houve linhas que não estavam inclusas nas prinicipais diferenças citadas anteriormente e que precisamos tratá-las.
#
# -> Também percebemos que alguns valores da mesma linha em relação a Low e High estão trocados (menor valor em high e maior valor em low) e faremos essas substituição

# %% [markdown]
# ---
# -> Primeiramente, vamos saber a quantidade de linhas de cada coluna

# %%
# Armazenando os nomes de cada coluna na variável "colunas"
colunas = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Dividend']

print("Quantidade de linhas de cada coluna: \n")

# Itera sobre cada coluna printando o nome + número de linhas dela
for col in colunas:
  print(f"{col}: {len(base1[colunas])}")
# Out:
# Quantidade de linhas de cada coluna:
#
# Open: 200000
# High: 200000
# Low: 200000
# Close: 200000
# Adj Close: 200000
# Dividend: 200000

# %% [markdown]
# ---
# -> Agora, implementaremos a função de padronização e a contagem de linhas já padronizadas + as que foram padronizadas em uma variável temporária chamada "base_tmp" para testar as modificações sem afetar a base original

# %%
# Biblioteca para trabalhar com strings
import re

# Função de padronização com contador
def padronizar_valor(valor):
    valor_original = valor

    valor_str = str(valor).strip()

    # Mantém o valor original se tiver letras/símbolos não permitidos (exceto $)
    if re.search(r"[^\d.,$-]", valor_str):
        return valor_original  # não altera

    # Remove cifrão
    valor_str = valor_str.replace('$', '')

    # Converte vírgula decimal para ponto se for o caso
    if re.match(r"^\d+,\d{2}$", valor_str):
        valor_str = valor_str.replace(',', '.')

    # Remove separadores de milhar
    valor_str = valor_str.replace(',', '')

    try:
        return float(valor_str)
    except ValueError:
        return valor_original  # retorna o original se não puder converter


print("Quantidade de linhas padronizadas de cada coluna: \n")

for col in colunas:
    # Aplica padronização
    base_tmp1[col] = base_tmp1[col].apply(padronizar_valor)

    # Conta quantos valores são float (incluindo os que já estavam como float)
    padronizados_col = base_tmp1[col].apply(lambda x: isinstance(x, float)).sum()
    print(f"{col}: {padronizados_col} valores padronizados")
# Out:
# Quantidade de linhas padronizadas de cada coluna:
#
# Open: 195763 valores padronizados
# High: 195691 valores padronizados
# Low: 195696 valores padronizados
# Close: 195666 valores padronizados
# Adj Close: 195744 valores padronizados
# Dividend: 196597 valores padronizados

# %% [markdown]
# ---
# -> Agora, vamos calcular os valores que não são float (não padronizados) de cada coluna

# %%
# Dicionário para armazenar contagem de não-floats por coluna
nao_float_count = {}

# Loop pelas colunas para verificar tipos
for col in colunas:
    count = base_tmp1[col].apply(lambda x: not isinstance(x, float)).sum()
    nao_float_count[col] = count

# Exibir resumo por coluna
print("Quantidade de valores que NÃO são float em cada coluna:")
for col, count in nao_float_count.items():
    print(f"{col}: {count}")

# Total geral
total_nao_float = sum(nao_float_count.values())
print(f"\nTOTAL de valores não padronizados como float: {total_nao_float}")
# Out:
# Quantidade de valores que NÃO são float em cada coluna:
# Open: 4237
# High: 4309
# Low: 4304
# Close: 4334
# Adj Close: 4256
# Dividend: 3403
#
# TOTAL de valores não padronizados como float: 24843

# %% [markdown]
# ---
# -> Agora vamos confirmar que esses valores são justamente o que contém 'Z'

# %%
def contar_valores_com_Z(df):
    colunas_alvo = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Dividend']
    contagem_total = 0

    for coluna in colunas_alvo:
        # Converte para string, verifica se contém 'Z' e soma os casos verdadeiros
        contagem_coluna = df[coluna].astype(str).str.contains('Z', case=False, na=False).sum()
        print(f"{coluna}: {contagem_coluna} valores com 'Z'")
        contagem_total += contagem_coluna

    print(f"Total de valores com 'Z': {contagem_total}")
    return contagem_total

contar_valores_com_Z(base_tmp1)
# Out:
# Open: 4237 valores com 'Z'
# High: 4309 valores com 'Z'
# Low: 4304 valores com 'Z'
# Close: 4334 valores com 'Z'
# Adj Close: 4256 valores com 'Z'
# Dividend: 3403 valores com 'Z'
# Total de valores com 'Z': 24843
# np.int64(24843)

# %% [markdown]
# ---
# -> Agora restringimos nosso tratamento apenas para os valores com 'Z', garantindo que não há outra variação
# -> Optamos por análises discutidas que substituiremos o 'Z' por '2', pois concluímos que é o que mais faz sentido e também porque se for comparar com a substituição por '0', essa última seria mais significativa, podendo afetar de forma mais significativa nossas análises futuras

# %%
def substituir_Z_por_2(df):
    colunas_alvo = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Dividend']
    substituicoes = 0

    for coluna in colunas_alvo:
        # Garante que os dados sejam tratados como strings
        df[coluna] = df[coluna].astype(str)

        # Conta quantos valores contêm 'Z' antes da substituição
        com_Z = df[coluna].str.contains('Z', case=False, na=False)
        substituicoes_coluna = com_Z.sum()

        # Substitui 'Z' por '2'
        df.loc[com_Z, coluna] = df.loc[com_Z, coluna].str.replace('Z', '2', case=False, regex=False)

        print(f"{coluna}: {substituicoes_coluna} substituições feitas")
        substituicoes += substituicoes_coluna

    print(f"Total de substituições realizadas: {substituicoes}")
    return df

base_tmp1 = substituir_Z_por_2(base_tmp1)
# Out:
# Open: 4237 substituições feitas
# High: 4309 substituições feitas
# Low: 4304 substituições feitas
# Close: 4334 substituições feitas
# Adj Close: 4256 substituições feitas
# Dividend: 3403 substituições feitas
# Total de substituições realizadas: 24843

# %% [markdown]
# ---
# -> Agora, vamos verificar se ainda resta algum símbolo que possa atrapalhar a conversão para o tipo numérico:

# %%
def encontrar_simbolos(df, coluna):
    if coluna not in df.columns:
        print(f"Coluna '{coluna}' não encontrada.")
        return set()

    simbolos = set()
    valores = df[coluna].dropna().astype(str)

    for valor in valores:
        encontrados = re.findall(r'[^0-9\s]', valor)  # tudo que não for número nem espaço
        simbolos.update(encontrados)

    return simbolos

for col in colunas:
      print(encontrar_simbolos(base_tmp1, col))
# Out:
# {',', '.', '$'}
# {',', '.', '$'}
# {',', '.', '$'}
# {',', '.', '$'}
# {',', '.', '$'}
# {',', '.', '$'}

# %% [markdown]
# ---
# -> Os símbolos '$' e ',' podem atrapalhar nossa conversão numérica, vamos corrigir isso:

# %%
for col in colunas:
    # Aplica padronização
    base_tmp1[col] = base_tmp1[col].apply(padronizar_valor)

    # Conta quantos valores são float (incluindo os que já estavam como float)
    padronizados_col = base_tmp1[col].apply(lambda x: isinstance(x, float)).sum()
    print(f"{col}: {padronizados_col} valores padronizados")
# Out:
# Open: 200000 valores padronizados
# High: 200000 valores padronizados
# Low: 200000 valores padronizados
# Close: 200000 valores padronizados
# Adj Close: 200000 valores padronizados
# Dividend: 200000 valores padronizados

# %% [markdown]
# ---
#
# -> Agora, vamos fazer as alterações entre valores trocados da coluna High e Low

# %%
# converte pra float
base_tmp1['Low'] = pd.to_numeric(base_tmp1['Low'], errors='coerce')
base_tmp1['High'] = pd.to_numeric(base_tmp1['High'], errors='coerce')

# contagem de casos onde Low > High
numCasos = base_tmp1['Low'] > base_tmp1['High']

print(f"Linhas com Low > High encontradas: {numCasos.sum()}")

# troca os valores
temp = base_tmp1.loc[numCasos, 'Low']
base_tmp1.loc[numCasos, 'Low'] = base_tmp1.loc[numCasos, 'High']
base_tmp1.loc[numCasos, 'High'] = temp
# Out:
# Linhas com Low > High encontradas: 99777

# %% [markdown]
# -> Além disso, encontramos outros tipos de inconsistência nessa base de dados, como por exemplo:
#
# Valor de Open/Close > High ou < Low, vamos tratar esses casos

# %%
#Podemos ver que há 4 casos, vamos olhar a quantidade de cada um:

close_high = base_tmp1['Close'] > base_tmp1['High']
close_low = base_tmp1['Close'] < base_tmp1['Low']
open_high = base_tmp1['Open'] > base_tmp1['High']
open_low = base_tmp1['Open'] < base_tmp1['Low']

print(f"Linhas com Close > High encontradas: {close_high.sum()}")
print(f"Linhas com Close < Low encontradas: {close_low.sum()}")
print(f"Linhas com Open > High encontradas: {open_high.sum()}")
print(f"Linhas com Open < Low encontradas: {open_low.sum()}")
# Out:
# Linhas com Close > High encontradas: 66603
# Linhas com Close < Low encontradas: 66496
# Linhas com Open > High encontradas: 67240
# Linhas com Open < Low encontradas: 66380

# %% [markdown]
# Conseguimos notar a alta incidência desses casos em nosso dataset, vamos corrigir caso a caso

# %%
# Corrigir Open > High
mask_open_gt_high = base_tmp1['Open'] > base_tmp1['High']
base_tmp1.loc[mask_open_gt_high, ['Open', 'High']] = base_tmp1.loc[mask_open_gt_high, ['High', 'Open']].values

# Corrigir Open < Low
mask_open_lt_low = base_tmp1['Open'] < base_tmp1['Low']
base_tmp1.loc[mask_open_lt_low, ['Open', 'Low']] = base_tmp1.loc[mask_open_lt_low, ['Low', 'Open']].values

# Corrigir Close > High
mask_close_gt_high = base_tmp1['Close'] > base_tmp1['High']
base_tmp1.loc[mask_close_gt_high, ['Close', 'High']] = base_tmp1.loc[mask_close_gt_high, ['High', 'Close']].values

# Corrigir Close < Low
mask_close_lt_low = base_tmp1['Close'] < base_tmp1['Low']
base_tmp1.loc[mask_close_lt_low, ['Close', 'Low']] = base_tmp1.loc[mask_close_lt_low, ['Low', 'Close']].values

# %% [markdown]
# Agora, vamos verificar se ainda há alguma inconsistência

# %%
close_high = base_tmp1['Close'] > base_tmp1['High']
close_low = base_tmp1['Close'] < base_tmp1['Low']
open_high = base_tmp1['Open'] > base_tmp1['High']
open_low = base_tmp1['Open'] < base_tmp1['Low']
numCasos = base_tmp1['Low'] > base_tmp1['High']

print(f"Linhas com Close > High encontradas: {close_high.sum()}")
print(f"Linhas com Close < Low encontradas: {close_low.sum()}")
print(f"Linhas com Open > High encontradas: {open_high.sum()}")
print(f"Linhas com Open < Low encontradas: {open_low.sum()}")
print(f"Linhas com Low > High encontradas: {numCasos.sum()}")
# Out:
# Linhas com Close > High encontradas: 0
# Linhas com Close < Low encontradas: 0
# Linhas com Open > High encontradas: 0
# Linhas com Open < Low encontradas: 0
# Linhas com Low > High encontradas: 0

# %% [markdown]
# -> Agora vamos confirmar que está tudo correto como float

# %%
for col in colunas:
      print(encontrar_simbolos(base_tmp1, col))
# Out:
# {'.'}
# {'.'}
# {'.'}
# {'.'}
# {'.'}
# {'.'}

# %% [markdown]
# -> Por fim, converteremos para numérico todas essas colunas

# %%
for col in colunas:
    base_tmp1[col] = pd.to_numeric(base_tmp1[col], errors='coerce')

# %% [markdown]
# ---
# -> Agora, faremos uma visualização geral das mudanças

# %%
# Printa as 14 primeiras linhas da base modificada
base_tmp1.head(14)
# Out:
#     ID       Date Ticker     Open     High     Low    Close  Adj Close  \
# 0    1 2023-09-03   meta   909.63  1380.05  258.44   595.86      61.54
# 1    2 2024-08-28   NVDA   678.96   725.03  185.51   295.83     843.78
# 2    3 2022-05-10   INTU   831.86  1348.94  215.00   874.05     336.19
# 3    4 2017-12-26   NVDA   508.65  1111.85  186.39   511.49     952.63
# 4    5 2022-01-20   WORK   692.20  1425.94  340.75   378.58    1493.44
# 5    6 2016-12-12   GOOG   262.36  1315.19   61.76   793.41     174.00
# 6    7 2015-11-13   tsla  1112.92  1342.15  105.69   917.22      57.66
# 7    8 2015-01-31   NVDA   425.99   866.78  190.38   485.90    1434.97
# 8    9 2021-02-14   NFLX   676.41  1033.25  524.23   604.71     350.97
# 9   10 2024-11-17   adbe   373.11   652.81  322.90   522.85     274.67
# 10  11 2023-05-03   PYPL   911.83  1332.30  448.28   855.59    1454.93
# 11  12 2017-11-26   UBER  1252.09  1407.84  285.80   341.07     178.46
# 12  13 2020-02-08   snap  1021.19  1469.74  842.57  1101.44     620.12
# 13  14 2022-12-09   AMZN  1123.95  1233.38  264.14  1201.11     440.03
#
#            Volume  Dividend Split Ratio
# 0   8,846,040,350      3.57         1:1
# 1      7346935699      2.85         3:2
# 2   8,027,589,419      2.28         2:1
# 3         1939.5M      4.51         3:2
# 4      8984007687      1.93         NaN
# 5      1434944091      4.09         3:2
# 6      4621479471      0.33         NaN
# 7      5081802848      0.33         2:1
# 8      7748945628      2.64         2:1
# 9      8357743507      2.41         2:1
# 10       7146.01M      0.36         NaN
# 11     6491094375      2.28         NaN
# 12     2885732552      4.28         3:2
# 13       4005.96M      2.42         1:1

# %% [markdown]
# ---
# #### **Tratamento da Coluna Ticker**

# %% [markdown]
# -> Nessa coluna, devemos corrigir e padronizar os nomes das empresas. Ao varrer um pouco o dataset, encontramos as seguintes questões:
#
# * Sigla da empresa com letras minúsculas
# * Erros na digitação das siglas das empresas - 1 letra errada...
#
# -> Para corrigirmos esse problema, iniciamos tornando todas as letras minúsculas, reduzindo ao menos um pouco as variações para iniciar.
#
# -> Para que conseguissemos distinguir quais siglas são de uma empresa ou não, listamos as ocorrências de cada sigla nesse dataset.

# %%
#Normalizando as siglas - Retirando espaços excessivos e tornando tudo maiúsculo
base_tmp1['Ticker'] = base_tmp1['Ticker'].str.upper().str.strip()

variacoes_siglas = base_tmp1['Ticker'].value_counts().reset_index()
variacoes_siglas.columns = ['variacao', 'frequencia']

#Para que possamos ver todas as siglas e sua frequência
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

print(variacoes_siglas)
# Out:
#      variacao  frequencia
# 0          ZM        6747
# 1          SQ        6694
# 2        PYPL        6477
# 3        SHOP        6450
# 4        META        6449
# 5        BABA        6440
# 6        SNAP        6423
# 7        WORK        6419
# 8         AMD        6384
# 9        CSCO        6372
# 10       ORCL        6367
# 11       AAPL        6364
# 12       INTC        6359
# 13       TSLA        6354
# 14       NVDA        6351
# 15       LYFT        6347
# 16        IBM        6346
# 17       SPOT        6346
# 18        VMW        6336
# 19       ADBE        6318
# 20       TWTR        6303
# 21       PINS        6299
# 22       MSFT        6298
# 23       INTU        6286
# 24       GOOG        6285
# 25       DOCU        6280
# 26       NFLX        6276
# 27        CRM        6266
# 28       AMZN        6251
# 29       UBER        6109
# 30       INTF          14
# 31        EMD          11
# 32       INTV          10
# 33        RBM          10
# 34       BYPL          10
# 35       SAOT          10
# 36       BMZN          10
# 37       INTT          10
# 38        IRM          10
# 39       INTB          10
# 40        VMD           9
# 41       AMZB           9
# 42       DOCG           9
# 43        IDM           9
# 44       IAPL           9
# 45       ADFE           9
# 46       AFZN           9
# 47        AMW           9
# 48       UBJR           9
# 49       INTA           9
# 50        SRM           9
# 51        AMZ           9
# 52       CSRO           9
# 53       IXTU           9
# 54        CRN           9
# 55        ZMW           9
# 56        DMD           8
# 57       AAPH           8
# 58        IXM           8
# 59       GTOG           8
# 60       MSRT           8
# 61       XAPL           8
# 62        WBM           8
# 63       SHHP           8
# 64       OUCL           8
# 65       UBEF           8
# 66       DPCU           8
# 67       PINL           8
# 68       NLLX           8
# 69       AQPL           8
# 70       WWTR           8
# 71       CSXO           8
# 72        AHD           8
# 73       UKER           8
# 74        CQM           8
# 75       UBEP           8
# 76        KMW           8
# 77       INLC           8
# 78       BABT           8
# 79       UBEQ           8
# 80        IBY           8
# 81        VLW           8
# 82       BABS           8
# 83       BYBA           8
# 84       MAPL           8
# 85       IZTU           8
# 86       BHBA           8
# 87        AMK           8
# 88       ADBM           8
# 89        ZRM           8
# 90       SPOH           8
# 91       XYPL           8
# 92       YWTR           8
# 93       YNAP           8
# 94        CRQ           8
# 95        AMJ           8
# 96       HOOG           8
# 97       SHOT           8
# 98       NVJA           8
# 99       NFLJ           8
# 100      BABJ           8
# 101       JBM           8
# 102      PBPL           8
# 103      MNTU           7
# 104       AMQ           7
# 105      GBER           7
# 106      SHLP           7
# 107      NFHX           7
# 108      GABA           7
# 109       CRX           7
# 110      SHUP           7
# 111       IMD           7
# 112      BNTC           7
# 113      BAZA           7
# 114      INTH           7
# 115       PMD           7
# 116      TWTN           7
# 117      PBNS           7
# 118      MSUT           7
# 119      GORK           7
# 120      BABI           7
# 121      TETA           7
# 122      BABQ           7
# 123      WSCO           7
# 124      INTS           7
# 125       IBN           7
# 126      MOTA           7
# 127      TABA           7
# 128      SPYT           7
# 129       IBD           7
# 130       UBM           7
# 131      MEDA           7
# 132       CHM           7
# 133       VMN           7
# 134       PMW           7
# 135      PXPL           7
# 136      PPNS           7
# 137       IEM           7
# 138       VMZ           7
# 139       IBZ           7
# 140      SNDP           7
# 141      ORML           7
# 142       RMD           7
# 143      RFLX           7
# 144      NFWX           7
# 145       CMW           7
# 146      AMZP           7
# 147      MSFM           7
# 148       CRG           7
# 149      JAPL           7
# 150      TWER           7
# 151      PIXS           7
# 152      CSCY           7
# 153      PIQS           7
# 154      AAPC           7
# 155      ATPL           7
# 156      LFFT           7
# 157      INTP           7
# 158       CRA           7
# 159      INTI           7
# 160      GROG           7
# 161      TSLJ           7
# 162       ISM           7
# 163       FBM           7
# 164      INTM           7
# 165      PIRS           7
# 166      KFLX           7
# 167       CDM           7
# 168      TGTR           7
# 169      SDAP           7
# 170      AUBE           7
# 171       IBK           7
# 172      TSUA           7
# 173      NFLW           7
# 174      JNTU           7
# 175      UABA           7
# 176      YRCL           7
# 177       IBF           7
# 178       VOW           7
# 179      TSLR           7
# 180       APD           7
# 181      AAUL           7
# 182      PYPM           7
# 183       DRM           7
# 184      BOCU           7
# 185      DSFT           7
# 186       AMP           7
# 187      KDBE           7
# 188      UWTR           7
# 189       CRO           7
# 190      SWAP           7
# 191       URM           7
# 192      PYPS           7
# 193      GJOG           7
# 194      JOOG           7
# 195       VMO           7
# 196      UNTC           7
# 197      SHOB           7
# 198      WMZN           7
# 199      OBER           7
# 200      SDOT           7
# 201       TRM           7
# 202      EOOG           6
# 203      SPOF           6
# 204      TOTR           6
# 205      FOCU           6
# 206      WDBE           6
# 207      NZDA           6
# 208       ORM           6
# 209      SHOW           6
# 210       CRE           6
# 211      DHOP           6
# 212      TXLA           6
# 213      OYCL           6
# 214      CSFT           6
# 215       ILM           6
# 216      XSCO           6
# 217      BBBA           6
# 218      NMZN           6
# 219      CYFT           6
# 220      WYPL           6
# 221      PIWS           6
# 222      SHOK           6
# 223      NFLS           6
# 224      TILA           6
# 225      SNOP           6
# 226      ORCT           6
# 227      TSLN           6
# 228       AVD           6
# 229       CBM           6
# 230       ABD           6
# 231       IBE           6
# 232      INTY           6
# 233      CMCO           6
# 234      AMUN           6
# 235      MKTA           6
# 236       CRJ           6
# 237      UMZN           6
# 238      ORWL           6
# 239      MWFT           6
# 240      UPOT           6
# 241      PINY           6
# 242      FVDA           6
# 243      PUNS           6
# 244      PSCO           6
# 245      MEBA           6
# 246      TBER           6
# 247      IBER           6
# 248      DORK           6
# 249       VVW           6
# 250      NFLH           6
# 251      UZER           6
# 252       AMN           6
# 253      BAEA           6
# 254      WYRK           6
# 255      GODG           6
# 256      AORK           6
# 257       YRM           6
# 258      WRRK           6
# 259      PRCL           6
# 260      SNWP           6
# 261      LEFT           6
# 262      AMLN           6
# 263      INDU           6
# 264      IRCL           6
# 265      GVDA           6
# 266      FSLA           6
# 267       LRM           6
# 268      UBQR           6
# 269      NVQA           6
# 270      IHOP           6
# 271      METE           6
# 272       CGM           6
# 273       IBC           6
# 274      INTZ           6
# 275      NVMA           6
# 276      HNTU           6
# 277       CTM           6
# 278      ADUE           6
# 279       AQD           6
# 280      ESFT           6
# 281      AMDN           6
# 282      LNTU           6
# 283      WXRK           6
# 284      SBOP           6
# 285      SPPT           6
# 286       ARD           6
# 287      UBKR           6
# 288      INPC           6
# 289      JVDA           6
# 290       FMW           6
# 291      TWYR           6
# 292      FNTU           6
# 293      SNGP           6
# 294      MMFT           6
# 295      CDBE           6
# 296       VMF           6
# 297      MSFJ           6
# 298       AMC           6
# 299      INTX           6
# 300      TSEA           6
# 301      MFLX           6
# 302       IBU           6
# 303      TSGA           6
# 304      AHZN           6
# 305      DUCU           6
# 306      LYFO           6
# 307      SPON           6
# 308      OVDA           6
# 309      AARL           6
# 310       CRP           6
# 311      SNAC           6
# 312      UBED           6
# 313      ORCJ           6
# 314      MEOA           6
# 315      PMNS           6
# 316      SNAA           6
# 317      NVDS           6
# 318      PTPL           6
# 319       CRB           6
# 320       VPW           6
# 321      YHOP           6
# 322       IBQ           6
# 323      GOQG           6
# 324       VBM           6
# 325      METH           6
# 326      LSFT           6
# 327       PRM           6
# 328      MBER           6
# 329      SPOJ           6
# 330      KSCO           6
# 331      ADQE           6
# 332       JMW           6
# 333      GBOG           6
# 334      ABBE           6
# 335      INVC           6
# 336      AHPL           6
# 337      SSAP           6
# 338      INTG           6
# 339      SRAP           6
# 340       VWW           6
# 341       ARM           6
# 342      OPCL           6
# 343      HNAP           6
# 344      SKOP           6
# 345      ORCW           6
# 346      PAPL           6
# 347      INAC           6
# 348      DMCU           6
# 349      GOOZ           6
# 350      DOKU           6
# 351      INXC           6
# 352      ONCL           6
# 353      MATA           6
# 354      ADOE           6
# 355      LYWT           6
# 356      XABA           6
# 357       RMW           6
# 358       IBB           6
# 359       AMR           6
# 360       HMD           6
# 361      SROT           6
# 362      BPBA           6
# 363      ACPL           6
# 364      TSHA           6
# 365      LINS           6
# 366      AAFL           6
# 367      GOTG           6
# 368      DPOT           6
# 369      VORK           6
# 370       CEM           6
# 371      YVDA           6
# 372      PFNS           6
# 373      PLPL           6
# 374       IBL           6
# 375      NQLX           6
# 376      TWTU           6
# 377      YSFT           6
# 378      NVDY           6
# 379      MSFY           6
# 380      CNAP           6
# 381      UBVR           6
# 382      AMZL           5
# 383      GOCG           5
# 384      MWTR           5
# 385      AOCU           5
# 386      MEWA           5
# 387      METM           5
# 388      ONAP           5
# 389      SPOB           5
# 390      XSFT           5
# 391      CSCP           5
# 392      WORW           5
# 393       IUM           5
# 394      WPRK           5
# 395      DOCH           5
# 396      LMZN           5
# 397      GNAP           5
# 398      BETA           5
# 399      OPOT           5
# 400      INKC           5
# 401       CMM           5
# 402       VIW           5
# 403      VYFT           5
# 404      GORG           5
# 405      WYFT           5
# 406      AZPL           5
# 407       KBM           5
# 408      CRCO           5
# 409      LGFT           5
# 410       MBM           5
# 411      LYFG           5
# 412      VSFT           5
# 413      SNAG           5
# 414      PYDL           5
# 415      PZNS           5
# 416      METY           5
# 417      MVDA           5
# 418      HYPL           5
# 419      LNTC           5
# 420      OINS           5
# 421      UYFT           5
# 422      UBFR           5
# 423      DOCS           5
# 424       OMD           5
# 425      ANTC           5
# 426      GCOG           5
# 427       NMD           5
# 428      XORK           5
# 429      SHXP           5
# 430      WOGK           5
# 431      NVDB           5
# 432      NINS           5
# 433      BAMA           5
# 434      NYLX           5
# 435      GYPL           5
# 436      NOOG           5
# 437      BNTU           5
# 438      UBNR           5
# 439      PINO           5
# 440      SNAW           5
# 441      BAHA           5
# 442      FABA           5
# 443      INTD           5
# 444      CSVO           5
# 445      HFLX           5
# 446      WOOK           5
# 447      UGER           5
# 448      DORU           5
# 449      TSLM           5
# 450      TVLA           5
# 451      PYNS           5
# 452      CSLA           5
# 453      INTJ           5
# 454       AWD           5
# 455       VME           5
# 456      SNMP           5
# 457      PINZ           5
# 458      GOBG           5
# 459      QAPL           5
# 460       WRM           5
# 461      ADGE           5
# 462       FMD           5
# 463      AAIL           5
# 464      LYCT           5
# 465      CSCT           5
# 466       VSW           5
# 467      GWTR           5
# 468      DSCO           5
# 469      TWUR           5
# 470      TULA           5
# 471      TWTP           5
# 472       XRM           5
# 473      LYFZ           5
# 474      TWTA           5
# 475      BAPL           5
# 476      NVDJ           5
# 477      CPCO           5
# 478       JRM           5
# 479      TWTL           5
# 480       IPM           5
# 481      ORAL           5
# 482      LYFM           5
# 483       IWM           5
# 484      CSCF           5
# 485      TSPA           5
# 486      KMZN           5
# 487      DOCZ           5
# 488      TWSR           5
# 489      LAPL           5
# 490      MCFT           5
# 491      SNAU           5
# 492       AUD           5
# 493      EDBE           5
# 494      SHOX           5
# 495      UBEI           5
# 496      DRCU           5
# 497      TSLP           5
# 498      TELA           5
# 499      PRPL           5
# 500      PYPT           5
# 501      SPZT           5
# 502      MSFS           5
# 503      NFLO           5
# 504      PYPQ           5
# 505      WDRK           5
# 506      AGBE           5
# 507      LHOP           5
# 508      SQOP           5
# 509      DTCU           5
# 510      SOCU           5
# 511      UBES           5
# 512      GOOV           5
# 513      AABE           5
# 514      OABA           5
# 515      AQBE           5
# 516      AAHL           5
# 517      NDLX           5
# 518      AADL           5
# 519      IBTC           5
# 520      CSCI           5
# 521      GOVG           5
# 522      SKOT           5
# 523       VMX           5
# 524      MNTA           5
# 525      BSCO           5
# 526      METG           5
# 527      PSLA           5
# 528       VNW           5
# 529      INGC           5
# 530       BBM           5
# 531      CSCU           5
# 532      PINE           5
# 533      EORK           5
# 534      TSLD           5
# 535      RABA           5
# 536      PIOS           5
# 537      LBER           5
# 538      MTFT           5
# 539      PINP           5
# 540       GRM           5
# 541      QPOT           5
# 542       IIM           5
# 543      ORCP           5
# 544      INQU           5
# 545      AMZG           5
# 546       IMM           5
# 547      SPOP           5
# 548      CFCO           5
# 549       IOM           5
# 550      UYER           5
# 551      PINJ           5
# 552      JHOP           5
# 553      CBCO           5
# 554      SHOO           5
# 555       VRW           5
# 556      PNTU           5
# 557      AGPL           5
# 558      INTO           5
# 559      PYPW           5
# 560      GLOG           5
# 561      AWTR           5
# 562      NJDA           5
# 563      CETA           5
# 564      LYZT           5
# 565      INTR           5
# 566      WNAP           5
# 567       NRM           5
# 568      AAPF           5
# 569      MSFO           5
# 570      JNTC           5
# 571      SOOT           5
# 572      AHOP           5
# 573      MSNT           5
# 574      PITS           5
# 575      MEGA           5
# 576      ZHOP           5
# 577      DOCK           5
# 578      TWPR           5
# 579      SNQP           5
# 580      PYPB           5
# 581      YINS           5
# 582      DDBE           5
# 583      VWTR           5
# 584      AAPV           5
# 585      CSUO           5
# 586      INDC           5
# 587      ADSE           5
# 588      PUPL           5
# 589      TSLW           5
# 590      INBC           5
# 591      LHFT           5
# 592      PDBE           5
# 593      INHU           5
# 594      GOLG           5
# 595      EETA           5
# 596      WORA           5
# 597      ANTU           5
# 598      DOCR           5
# 599       VMU           5
# 600      SHWP           5
# 601      COCU           5
# 602      SPTT           5
# 603      MUFT           5
# 604      TWAR           5
# 605      ORCG           5
# 606      CSWO           5
# 607      USLA           5
# 608      AHBE           5
# 609      PQPL           5
# 610      PIYS           5
# 611      TWXR           5
# 612       WMD           5
# 613       AYD           5
# 614      AGZN           5
# 615      SCOT           5
# 616      NVLA           5
# 617      MSMT           5
# 618      ADBW           5
# 619      SXOP           5
# 620      AMEN           5
# 621       JMD           5
# 622      VVDA           5
# 623      TCLA           5
# 624      PINT           5
# 625      INTE           5
# 626      TWLA           5
# 627      LYFF           5
# 628      WARK           5
# 629      TWTX           5
# 630      NSLA           5
# 631      ANPL           5
# 632      TWQR           5
# 633      METF           5
# 634      OXCL           5
# 635      SHOG           5
# 636      NFAX           5
# 637      PYYL           5
# 638      AMZM           5
# 639      TSFA           5
# 640       SMW           5
# 641      WOMK           5
# 642      CHOP           5
# 643      VOCU           5
# 644      TSLF           5
# 645      ICTU           5
# 646      HWTR           5
# 647      WORC           5
# 648      NFDA           5
# 649      TWTZ           5
# 650       CAM           5
# 651       AMG           5
# 652      OREL           5
# 653      PYPF           5
# 654      PINR           5
# 655      ZRCL           5
# 656       AMM           5
# 657      CACO           5
# 658      NULX           5
# 659      UBET           5
# 660       XMW           5
# 661      BWTR           5
# 662       VMH           5
# 663      NBLX           5
# 664       IZM           5
# 665      FNAP           5
# 666      NGDA           5
# 667      TNAP           5
# 668      DONU           5
# 669      ZABA           5
# 670      TWGR           5
# 671      JFLX           5
# 672      WSRK           5
# 673      LCFT           5
# 674      IDBE           5
# 675      NVIA           5
# 676      MBTA           5
# 677      PYTL           5
# 678      MYFT           5
# 679      AJPL           5
# 680      SMOT           5
# 681      LLFT           5
# 682      ORSL           5
# 683      GOEG           4
# 684      MSFL           4
# 685      TWTB           4
# 686       AFD           4
# 687      GOGG           4
# 688      LIFT           4
# 689      TTLA           4
# 690      GOOO           4
# 691      WODK           4
# 692      CSDO           4
# 693      RSCO           4
# 694      GOOB           4
# 695      METR           4
# 696      DLCU           4
# 697      KSLA           4
# 698       ASD           4
# 699      DOQU           4
# 700       IBI           4
# 701      GMZN           4
# 702      LOCU           4
# 703       ATD           4
# 704      DOCV           4
# 705      NQDA           4
# 706      UBEK           4
# 707      LOFT           4
# 708      WOZK           4
# 709      ADJE           4
# 710       ALD           4
# 711      NVHA           4
# 712      PINU           4
# 713      MEUA           4
# 714      GOIG           4
# 715      RETA           4
# 716      ZYPL           4
# 717      CRCL           4
# 718      NVNA           4
# 719       ITM           4
# 720      SBER           4
# 721      TJLA           4
# 722      PYEL           4
# 723       AED           4
# 724      SPOY           4
# 725       VEW           4
# 726      WORY           4
# 727      WORI           4
# 728      WJRK           4
# 729      ISTU           4
# 730       AOD           4
# 731      TWTF           4
# 732      XOCU           4
# 733      RYPL           4
# 734      ABPL           4
# 735      ANAP           4
# 736      YYPL           4
# 737      GOOD           4
# 738      WOQK           4
# 739      UBEY           4
# 740      SGAP           4
# 741      MKFT           4
# 742      FORK           4
# 743      SHDP           4
# 744      NKDA           4
# 745      SMOP           4
# 746      PONS           4
# 747       YBM           4
# 748      XETA           4
# 749      TWTQ           4
# 750       IBJ           4
# 751      ORCQ           4
# 752      SPUT           4
# 753      JSCO           4
# 754       COM           4
# 755      UIER           4
# 756      ALZN           4
# 757      SPQT           4
# 758      GPOG           4
# 759      LYFX           4
# 760      SNTP           4
# 761      WOTK           4
# 762      OCCL           4
# 763      MSCO           4
# 764      MOCU           4
# 765      CSEO           4
# 766      CQCO           4
# 767      HHOP           4
# 768       AJD           4
# 769      ADIE           4
# 770      SLOP           4
# 771      IFTU           4
# 772      AAPN           4
# 773      EINS           4
# 774      WOYK           4
# 775      KOCU           4
# 776      FBER           4
# 777      RAPL           4
# 778      AASL           4
# 779      LVFT           4
# 780      PMPL           4
# 781       ZMD           4
# 782      CSCX           4
# 783      TSLL           4
# 784      UHOP           4
# 785      ADZE           4
# 786      QWTR           4
# 787      PABA           4
# 788      SYOT           4
# 789      ACBE           4
# 790       DMW           4
# 791       VMI           4
# 792      UBZR           4
# 793      YABA           4
# 794      SPKT           4
# 795      SHYP           4
# 796      TWTT           4
# 797      EVDA           4
# 798      INRU           4
# 799      ADBN           4
# 800      ORCD           4
# 801      SFOP           4
# 802      HRCL           4
# 803      HVDA           4
# 804      GYOG           4
# 805      TWOR           4
# 806       OBM           4
# 807      RBER           4
# 808       CRK           4
# 809       IFM           4
# 810      PYFT           4
# 811       VMJ           4
# 812      GOWG           4
# 813      AAZN           4
# 814      AAVL           4
# 815      CVDA           4
# 816      DBER           4
# 817      DOCM           4
# 818      ALBE           4
# 819      SYAP           4
# 820      XDBE           4
# 821      NCDA           4
# 822      ISFT           4
# 823      LYIT           4
# 824       CRT           4
# 825      AANL           4
# 826       CRS           4
# 827      BABD           4
# 828      DOUU           4
# 829      SPCT           4
# 830      BEBA           4
# 831      SHTP           4
# 832      LYNT           4
# 833      ADBD           4
# 834      AMPN           4
# 835      TFLA           4
# 836      PENS           4
# 837      DOCP           4
# 838      AAAL           4
# 839      SPMT           4
# 840       AME           4
# 841      TWTO           4
# 842      TMZN           4
# 843      NFLA           4
# 844      AQZN           4
# 845      AFLX           4
# 846      INRC           4
# 847      AAPK           4
# 848       CNM           4
# 849      WOAK           4
# 850      DSCU           4
# 851       AMH           4
# 852      BABL           4
# 853      TNTU           4
# 854      TSLX           4
# 855      PCNS           4
# 856      MSLA           4
# 857      BABF           4
# 858      NDBE           4
# 859      UQER           4
# 860       VMG           4
# 861      ADBQ           4
# 862      TWNR           4
# 863      SPOM           4
# 864      PIKS           4
# 865       IYM           4
# 866      AMZH           4
# 867      SPOV           4
# 868      WPOT           4
# 869      NALX           4
# 870      TSLZ           4
# 871       IBG           4
# 872      BAVA           4
# 873      WINS           4
# 874      SSCO           4
# 875      SOOP           4
# 876      UAER           4
# 877      OOOG           4
# 878      GRCL           4
# 879      TSLT           4
# 880      PSFT           4
# 881      NVDX           4
# 882      ORFL           4
# 883      DYCU           4
# 884      RSLA           4
# 885      SNPP           4
# 886      SETA           4
# 887      TMLA           4
# 888      SUOP           4
# 889      MENA           4
# 890      PNPL           4
# 891      AXBE           4
# 892      ARBE           4
# 893      INIU           4
# 894      UBEB           4
# 895      DYPL           4
# 896      GXOG           4
# 897      WORD           4
# 898      AMKN           4
# 899      CSCS           4
# 900      YOCU           4
# 901      HSCO           4
# 902      SHZP           4
# 903      ORCF           4
# 904      TWHR           4
# 905       IBT           4
# 906      MTTA           4
# 907      PINC           4
# 908      SPGT           4
# 909      RSFT           4
# 910      TMTR           4
# 911      LYFS           4
# 912      AKBE           4
# 913      SPOD           4
# 914      MGTA           4
# 915      NFSX           4
# 916      BINS           4
# 917      NVZA           4
# 918      BABU           4
# 919      BNBA           4
# 920      LMFT           4
# 921      TWTM           4
# 922      NOCU           4
# 923      PTNS           4
# 924      CSCB           4
# 925      SEAP           4
# 926      ORRL           4
# 927      CSCD           4
# 928       CXM           4
# 929      OHOP           4
# 930       OMW           4
# 931      APPL           4
# 932      WERK           4
# 933      WRCL           4
# 934      INXU           4
# 935      ADVE           4
# 936      PYIL           4
# 937      NVCA           4
# 938      GOOC           4
# 939      UOCU           4
# 940      SNCP           4
# 941      CSYO           4
# 942      CSAO           4
# 943      YAPL           4
# 944      DOCE           4
# 945      UBPR           4
# 946      NYDA           4
# 947      MSFE           4
# 948      QSCO           4
# 949      NFLI           4
# 950      AAPS           4
# 951      SHVP           4
# 952      BABE           4
# 953      BABG           4
# 954      NWTR           4
# 955      PQNS           4
# 956      QABA           4
# 957      NFLL           4
# 958      DXCU           4
# 959      MDTA           4
# 960      TWTJ           4
# 961      NVDP           4
# 962      SQAP           4
# 963      UFER           4
# 964      MELA           4
# 965      NFQX           4
# 966      AVBE           4
# 967      RPOT           4
# 968      CYCO           4
# 969      TVTR           4
# 970      ARPL           4
# 971      EFLX           4
# 972      QYFT           4
# 973      TYTR           4
# 974      MORK           4
# 975      JSLA           4
# 976      ADTE           4
# 977      AZZN           4
# 978      NVDE           4
# 979      DVDA           4
# 980      UBEX           4
# 981       NMW           4
# 982      SNAS           4
# 983      LOOG           4
# 984      GZOG           4
# 985      GOOY           4
# 986      BGBA           4
# 987      TSLU           4
# 988      PHPL           4
# 989      GETA           4
# 990      NRCL           4
# 991      SPOZ           4
# 992      SEOT           4
# 993      IXTC           4
# 994      CSCG           4
# 995      NRLX           4
# 996      JETA           4
# 997      WORL           4
# 998      HOCU           4
# 999       CVM           4
# 1000     BRBA           4
# 1001     AAPT           4
# 1002     PKNS           4
# 1003     NELX           4
# 1004     ULER           4
# 1005     MIFT           4
# 1006     CSCM           4
# 1007      CCM           4
# 1008     ORKL           4
# 1009     HMZN           4
# 1010     BANA           4
# 1011     AMRN           4
# 1012     NFLD           4
# 1013     IATU           4
# 1014     AAOL           4
# 1015     ZYFT           4
# 1016     NKLX           4
# 1017     WURK           4
# 1018     PYPX           4
# 1019     PGPL           4
# 1020     XINS           4
# 1021     DVCU           4
# 1022     AAPB           4
# 1023      BMW           4
# 1024     NFYX           4
# 1025     VFLX           4
# 1026      AID           4
# 1027      QMD           4
# 1028     QSFT           4
# 1029     OHCL           4
# 1030     UBMR           4
# 1031     GOYG           4
# 1032     UBEH           4
# 1033     BMBA           4
# 1034     MSFK           4
# 1035      EMW           4
# 1036     NFLY           4
# 1037     SHEP           4
# 1038     PNAP           4
# 1039     CFLX           4
# 1040      RRM           4
# 1041     GOOI           4
# 1042     LDFT           4
# 1043     TNLA           4
# 1044     CSBO           4
# 1045     NFLC           4
# 1046     BABN           4
# 1047     NVVA           4
# 1048     WTRK           4
# 1049     WVRK           4
# 1050     TSLS           4
# 1051     BTBA           4
# 1052     EOCU           4
# 1053     WORZ           4
# 1054      CRW           4
# 1055     BOBA           4
# 1056     TSDA           4
# 1057     BHOP           4
# 1058     LYFV           4
# 1059     INYC           4
# 1060      GBM           4
# 1061     CSTO           4
# 1062     ADBF           4
# 1063     YFLX           4
# 1064     YYFT           4
# 1065     FYFT           4
# 1066     SMAP           4
# 1067     FRCL           4
# 1068     UNAP           4
# 1069     GEOG           4
# 1070      INM           4
# 1071     ENTU           4
# 1072     AAKL           4
# 1073     UBBR           4
# 1074     INAU           4
# 1075     ORCZ           4
# 1076     METK           4
# 1077     MEIA           4
# 1078     ISLA           4
# 1079      VMT           4
# 1080     AETA           4
# 1081     MSJT           4
# 1082     BRCL           4
# 1083      WMW           4
# 1084     OJCL           4
# 1085     ONTC           4
# 1086     PEPL           4
# 1087     INEC           4
# 1088     JPOT           4
# 1089     MSKT           4
# 1090     WLRK           4
# 1091      CRD           4
# 1092     AMCN           4
# 1093     CORK           4
# 1094     ORNL           4
# 1095     MSFR           4
# 1096     IFTC           4
# 1097     NADA           4
# 1098     ADXE           4
# 1099     OGCL           4
# 1100     NRDA           4
# 1101     RMZN           4
# 1102      ACD           4
# 1103     SCOP           4
# 1104     PPPL           4
# 1105     AMBE           4
# 1106      MRM           4
# 1107      AZD           4
# 1108     WOSK           4
# 1109     SNVP           4
# 1110     NSFT           4
# 1111     ADPL           4
# 1112     RDBE           4
# 1113     PFLX           4
# 1114     PVDA           4
# 1115     LYFC           4
# 1116     NYFT           4
# 1117     STOT           4
# 1118     DOCT           4
# 1119      VKW           4
# 1120     AMZA           4
# 1121      IKM           4
# 1122     GOMG           4
# 1123     PIGS           4
# 1124      AGD           4
# 1125     IGTU           4
# 1126     SFLX           4
# 1127     TSCO           4
# 1128     MSFB           4
# 1129     CSCL           4
# 1130     TWDR           4
# 1131     KNTU           4
# 1132     SNZP           4
# 1133      VXW           4
# 1134     NFCX           4
# 1135     CSIO           4
# 1136     XOOG           4
# 1137     NMLX           4
# 1138     YETA           4
# 1139     SVDA           4
# 1140     NSDA           4
# 1141     DOXU           4
# 1142     QETA           4
# 1143     AMZE           4
# 1144     PINH           4
# 1145     PIUS           4
# 1146     SHOF           4
# 1147     WOCK           4
# 1148     CSCR           4
# 1149     TWTD           4
# 1150      QMW           4
# 1151     PYUL           4
# 1152     INTK           4
# 1153     SPXT           4
# 1154      CJM           4
# 1155     IBTU           4
# 1156     NFMX           4
# 1157     JBER           4
# 1158     WKRK           4
# 1159     STAP           4
# 1160     YSCO           4
# 1161     WORV           4
# 1162     TDTR           4
# 1163     AAPQ           4
# 1164     MEXA           4
# 1165     USER           4
# 1166     MSHT           4
# 1167      AND           4
# 1168     XHOP           4
# 1169      IMW           4
# 1170     NFBX           4
# 1171     TWCR           4
# 1172     AMVN           4
# 1173     ADBU           4
# 1174     TYFT           4
# 1175     SNXP           4
# 1176     TSCA           4
# 1177     LYET           4
# 1178     AJBE           4
# 1179     PINK           3
# 1180      CWM           3
# 1181     BATA           3
# 1182     BDBE           3
# 1183     IVTU           3
# 1184     ITTU           3
# 1185     PIPL           3
# 1186     EPOT           3
# 1187     MSFF           3
# 1188     SPRT           3
# 1189     AKPL           3
# 1190     PISS           3
# 1191     SHOH           3
# 1192     SNNP           3
# 1193      CZM           3
# 1194     LRCL           3
# 1195     ISCO           3
# 1196     ZETA           3
# 1197     TWTH           3
# 1198      CRC           3
# 1199      CRH           3
# 1200     GNTU           3
# 1201     CSCN           3
# 1202     JWTR           3
# 1203     TINS           3
# 1204     DMZN           3
# 1205     METB           3
# 1206     WOPK           3
# 1207     SPOR           3
# 1208     IVDA           3
# 1209     NFZX           3
# 1210     METS           3
# 1211     UEER           3
# 1212     AAPY           3
# 1213     PILS           3
# 1214     THLA           3
# 1215     SNAI           3
# 1216     TSNA           3
# 1217     DNTU           3
# 1218     INTN           3
# 1219     LYFA           3
# 1220     PWPL           3
# 1221     BABO           3
# 1222     UYPL           3
# 1223     MSTT           3
# 1224     GSFT           3
# 1225     SHOJ           3
# 1226     MEPA           3
# 1227     PVNS           3
# 1228     FAPL           3
# 1229     TALA           3
# 1230      AMF           3
# 1231     BABZ           3
# 1232     FDBE           3
# 1233     LYQT           3
# 1234     TWRR           3
# 1235     IUTU           3
# 1236     AMZQ           3
# 1237     QMZN           3
# 1238     AMZY           3
# 1239     EHOP           3
# 1240     NHOP           3
# 1241     LYDT           3
# 1242     SNKP           3
# 1243     PYPY           3
# 1244     WBRK           3
# 1245     TSLE           3
# 1246      ERM           3
# 1247     MBFT           3
# 1248     ADBO           3
# 1249     MERA           3
# 1250     TSLV           3
# 1251     NFLB           3
# 1252     SHOE           3
# 1253     TWTW           3
# 1254     NVDK           3
# 1255     INTL           3
# 1256     IQTU           3
# 1257     LVDA           3
# 1258     GOXG           3
# 1259      CMD           3
# 1260     AMFN           3
# 1261     MPOT           3
# 1262     GOOQ           3
# 1263     SPVT           3
# 1264     OFCL           3
# 1265     LYFI           3
# 1266     EYFT           3
# 1267     UVER           3
# 1268     PWNS           3
# 1269     LYFK           3
# 1270     LYUT           3
# 1271      VMC           3
# 1272     MRFT           3
# 1273     YSLA           3
# 1274      VMA           3
# 1275     INWC           3
# 1276     CSCK           3
# 1277     ZNTC           3
# 1278     ZBER           3
# 1279     PIHS           3
# 1280     MEHA           3
# 1281     AAZL           3
# 1282     TSLY           3
# 1283     NVDM           3
# 1284      ABM           3
# 1285     ODBE           3
# 1286     PINN           3
# 1287     INFU           3
# 1288     TCTR           3
# 1289     AIBE           3
# 1290     ORTL           3
# 1291     SNAT           3
# 1292     BVBA           3
# 1293     LXFT           3
# 1294     NFXX           3
# 1295     MSOT           3
# 1296     SQOT           3
# 1297      AMT           3
# 1298     NFJX           3
# 1299     WNRK           3
# 1300     TOOG           3
# 1301     NPLX           3
# 1302     BAFA           3
# 1303     VMZN           3
# 1304     INTW           3
# 1305     AMIN           3
# 1306     NVDU           3
# 1307      AML           3
# 1308     TOCU           3
# 1309     CAPL           3
# 1310     INUU           3
# 1311     CSCA           3
# 1312     AABL           3
# 1313     MSVT           3
# 1314     UAPL           3
# 1315     AMZD           3
# 1316     AAQL           3
# 1317     SNBP           3
# 1318     ZSLA           3
# 1319     GOOA           3
# 1320     SDOP           3
# 1321     CSCV           3
# 1322     OTCL           3
# 1323     SNHP           3
# 1324     DOVU           3
# 1325     CSFO           3
# 1326     DOCX           3
# 1327     NVDO           3
# 1328     GMOG           3
# 1329     TWTV           3
# 1330     GOOJ           3
# 1331     CSKO           3
# 1332      IQM           3
# 1333     KBER           3
# 1334     SABA           3
# 1335     SIOT           3
# 1336     GFLX           3
# 1337     ORCA           3
# 1338     LNFT           3
# 1339     PHOP           3
# 1340     FMZN           3
# 1341     ROCU           3
# 1342     WOJK           3
# 1343     QOCU           3
# 1344     XNTU           3
# 1345     PXNS           3
# 1346     WAPL           3
# 1347     TWWR           3
# 1348      CRU           3
# 1349     QBER           3
# 1350     BIBA           3
# 1351      UMD           3
# 1352     UPER           3
# 1353      EBM           3
# 1354     WOHK           3
# 1355     MSCT           3
# 1356     CINS           3
# 1357     PYPN           3
# 1358      VMP           3
# 1359     SHOY           3
# 1360     BABK           3
# 1361      CRL           3
# 1362     SNAL           3
# 1363     NVFA           3
# 1364     PYVL           3
# 1365     SPOC           3
# 1366     ABER           3
# 1367     AAML           3
# 1368     WORU           3
# 1369     CSCE           3
# 1370     CLCO           3
# 1371     LYFY           3
# 1372     LSCO           3
# 1373     PYCL           3
# 1374     MEFA           3
# 1375     MSFC           3
# 1376     AUPL           3
# 1377     AMZF           3
# 1378     ADBL           3
# 1379     MWTA           3
# 1380     TKLA           3
# 1381     UBWR           3
# 1382     POPL           3
# 1383     METJ           3
# 1384     GDOG           3
# 1385     NIDA           3
# 1386     BAYA           3
# 1387     INUC           3
# 1388     PDPL           3
# 1389      PBM           3
# 1390     ARZN           3
# 1391     NFNX           3
# 1392      VMK           3
# 1393     DYFT           3
# 1394     AMMN           3
# 1395      LMD           3
# 1396     NPDA           3
# 1397     NVUA           3
# 1398     RORK           3
# 1399     VABA           3
# 1400     SJOT           3
# 1401      CRF           3
# 1402      HRM           3
# 1403     ZSCO           3
# 1404      VDW           3
# 1405     BAXA           3
# 1406     TGLA           3
# 1407     NVDQ           3
# 1408      DBM           3
# 1409     QYPL           3
# 1410     DOFU           3
# 1411     BASA           3
# 1412     MSFX           3
# 1413     NSCO           3
# 1414     GOOP           3
# 1415     ADLE           3
# 1416     UBEW           3
# 1417     UBEV           3
# 1418      MMW           3
# 1419     MHTA           3
# 1420     OSLA           3
# 1421     AMZS           3
# 1422     MSDT           3
# 1423     DOCA           3
# 1424      VCW           3
# 1425     UUER           3
# 1426     SPNT           3
# 1427     NFTX           3
# 1428     DOMU           3
# 1429     AAYL           3
# 1430      IBR           3
# 1431     PLNS           3
# 1432     MSTA           3
# 1433     METU           3
# 1434     ORCM           3
# 1435     TLLA           3
# 1436     SOOG           3
# 1437      CPM           3
# 1438      VMV           3
# 1439     SCAP           3
# 1440     MEMA           3
# 1441     QNTU           3
# 1442     GOSG           3
# 1443     TORK           3
# 1444     CECO           3
# 1445     BABV           3
# 1446     MGFT           3
# 1447     BOOG           3
# 1448     TOLA           3
# 1449     ADPE           3
# 1450     IOOG           3
# 1451     SHFP           3
# 1452     WOVK           3
# 1453     BVDA           3
# 1454     SSOP           3
# 1455     AMZK           3
# 1456     IJTU           3
# 1457     XPOT           3
# 1458     BAWA           3
# 1459     SPOI           3
# 1460      AKD           3
# 1461     NAPL           3
# 1462     BFLX           3
# 1463      HMW           3
# 1464     DOIU           3
# 1465     BYFT           3
# 1466     SNTC           3
# 1467     METW           3
# 1468     PINI           3
# 1469     ORIL           3
# 1470     NCLX           3
# 1471     VINS           3
# 1472     SVOP           3
# 1473     CTCO           3
# 1474     LYFJ           3
# 1475     INWU           3
# 1476     IMTC           3
# 1477     MXTA           3
# 1478     PJNS           3
# 1479     POOG           3
# 1480     AFPL           3
# 1481     GINS           3
# 1482     BWBA           3
# 1483     TQLA           3
# 1484     ZORK           3
# 1485     SPOU           3
# 1486      IBV           3
# 1487     MSPT           3
# 1488     AMON           3
# 1489     XYFT           3
# 1490      LMW           3
# 1491     OECL           3
# 1492     DNTC           3
# 1493     MAFT           3
# 1494     SXOT           3
# 1495     SNAZ           3
# 1496      TMW           3
# 1497     NXLX           3
# 1498     TETR           3
# 1499      XBM           3
# 1500     ZMZN           3
# 1501     COOG           3
# 1502      VBW           3
# 1503     PYAL           3
# 1504      KRM           3
# 1505     MSLT           3
# 1506     LETA           3
# 1507     SZOP           3
# 1508     TYPL           3
# 1509     SZOT           3
# 1510     CSLO           3
# 1511     ASPL           3
# 1512     UMER           3
# 1513     LYFW           3
# 1514     NETA           3
# 1515     NFIX           3
# 1516     PINA           3
# 1517     AINS           3
# 1518     IMTU           3
# 1519     SPST           3
# 1520     GOCU           3
# 1521     DGCU           3
# 1522      VMB           3
# 1523     WFRK           3
# 1524     UCER           3
# 1525     MDBE           3
# 1526     SYOP           3
# 1527     PCPL           3
# 1528     ADAE           3
# 1529     OKCL           3
# 1530     SPOE           3
# 1531     CSCH           3
# 1532     UBEJ           3
# 1533     SNAE           3
# 1534     INCU           3
# 1535     AVZN           3
# 1536     INQC           3
# 1537     NVDD           3
# 1538     AMWN           3
# 1539     ADBY           3
# 1540     WORR           3
# 1541     TDBE           3
# 1542     LYJT           3
# 1543      ICM           3
# 1544     AUZN           3
# 1545     MEZA           3
# 1546     VPOT           3
# 1547     SNAJ           3
# 1548     CSCW           3
# 1549     AMGN           3
# 1550     JINS           3
# 1551     KHOP           3
# 1552     MRTA           3
# 1553     UWER           3
# 1554     UBHR           3
# 1555     AMAN           3
# 1556     MEJA           3
# 1557     DOCC           3
# 1558     TSZA           3
# 1559      BRM           3
# 1560     SPOS           3
# 1561     ORXL           3
# 1562     HETA           3
# 1563     PYHL           3
# 1564     ZAPL           3
# 1565     SHPP           3
# 1566     PINM           3
# 1567     BFBA           3
# 1568     LYFL           3
# 1569     WOEK           3
# 1570     ORCS           3
# 1571     MABA           3
# 1572     IOTC           3
# 1573     UBDR           3
# 1574     IETC           3
# 1575     ORCI           3
# 1576     JDBE           3
# 1577     SPBT           3
# 1578     PMZN           3
# 1579     LBFT           3
# 1580     KSFT           3
# 1581     TSLQ           3
# 1582     MSFV           3
# 1583     UBEE           3
# 1584     AAPU           3
# 1585      AXD           3
# 1586     NFLN           3
# 1587     ZOOG           3
# 1588     SHIP           3
# 1589     OWCL           3
# 1590     ORCY           3
# 1591     ORPL           3
# 1592     RINS           3
# 1593     NFLF           3
# 1594     ODCL           3
# 1595     UBEZ           3
# 1596     PYPZ           3
# 1597     UBEA           3
# 1598     YBER           3
# 1599     ASCO           3
# 1600     RWTR           3
# 1601     NFLR           3
# 1602     NNLX           3
# 1603      SBM           3
# 1604     GDBE           3
# 1605     SRCL           3
# 1606     NWDA           3
# 1607     MVFT           3
# 1608     TZTR           3
# 1609     GPOT           3
# 1610     ADBS           3
# 1611      CSM           3
# 1612     CSCJ           3
# 1613     SNAN           3
# 1614     INCC           3
# 1615     GSCO           3
# 1616     SORK           3
# 1617     DODU           3
# 1618     UOER           3
# 1619     WETA           3
# 1620      IJM           3
# 1621     NFDX           3
# 1622      VMQ           3
# 1623     DRCL           3
# 1624     BABR           3
# 1625     ADZN           3
# 1626     MSAT           3
# 1627     AMBN           3
# 1628     MINS           3
# 1629      AMB           3
# 1630     LYOT           3
# 1631     WZRK           3
# 1632      AMA           3
# 1633     TNTR           3
# 1634     BABP           3
# 1635     NLDA           3
# 1636     VNTC           3
# 1637     PGNS           3
# 1638     RNTC           3
# 1639     XVDA           3
# 1640     LYYT           3
# 1641     ATBE           3
# 1642     PIPS           3
# 1643     RNAP           3
# 1644     MEYA           3
# 1645     GOOT           3
# 1646     KNTC           3
# 1647      CRV           3
# 1648     RNTU           3
# 1649     AWPL           3
# 1650     BAAA           3
# 1651     IKTC           3
# 1652     PSNS           3
# 1653      IBO           3
# 1654     AAEL           3
# 1655     PYPC           3
# 1656     GONG           3
# 1657     TRTR           3
# 1658     DOTU           3
# 1659     NEDA           3
# 1660     TPOT           3
# 1661     GKOG           3
# 1662     INNU           3
# 1663     SNUP           3
# 1664     AAPG           3
# 1665      IBP           3
# 1666      SMD           3
# 1667     METN           3
# 1668     CNCO           3
# 1669     GWOG           3
# 1670     HYFT           3
# 1671     MSFN           3
# 1672     CSSO           3
# 1673     AYBE           3
# 1674     NBDA           3
# 1675     NVRA           3
# 1676     ADBK           3
# 1677     WNTU           3
# 1678     OROL           3
# 1679     ORLL           3
# 1680     NVDH           3
# 1681     ILTU           3
# 1682     BAGA           3
# 1683     DSLA           3
# 1684     MSFD           3
# 1685     SYFT           3
# 1686     TNTC           3
# 1687     PPOT           3
# 1688     NFGX           3
# 1689     NFEX           3
# 1690     PYKL           3
# 1691     PZPL           3
# 1692     LYBT           3
# 1693     MESA           3
# 1694      VYW           3
# 1695     TWTI           3
# 1696     ACZN           3
# 1697     NVBA           3
# 1698      VMR           3
# 1699     DOOU           3
# 1700     MPFT           3
# 1701     PIES           3
# 1702     BARA           3
# 1703     DOCJ           3
# 1704     METI           3
# 1705     AAPE           3
# 1706     DOOG           3
# 1707     GOFG           3
# 1708     SHON           3
# 1709     IITU           3
# 1710     CDCO           3
# 1711     DDCU           3
# 1712     SPIT           3
# 1713     TSQA           3
# 1714     MLFT           3
# 1715     AWBE           3
# 1716     ORCX           3
# 1717     AFBE           3
# 1718     DOJU           3
# 1719     AMZT           3
# 1720     PYPV           3
# 1721     PINX           3
# 1722     OQCL           3
# 1723      AMY           3
# 1724     AAPX           3
# 1725     INZC           3
# 1726     INOU           3
# 1727     BCBA           3
# 1728     AABA           3
# 1729     GHOG           3
# 1730     LDBE           3
# 1731     IPTC           3
# 1732     UDBE           3
# 1733     ESCO           3
# 1734     LYVT           3
# 1735     AIZN           3
# 1736      CRI           3
# 1737     LUFT           3
# 1738     BDBA           3
# 1739     KYPL           3
# 1740     WORQ           3
# 1741     PINV           3
# 1742     MHFT           3
# 1743     BAOA           3
# 1744     DOAU           3
# 1745     WIRK           3
# 1746      ZBM           3
# 1747     KORK           3
# 1748     LNAP           3
# 1749     QORK           3
# 1750     GGOG           3
# 1751     PYPO           3
# 1752      TBM           3
# 1753     TQTR           3
# 1754     MJFT           3
# 1755     SUAP           3
# 1756     IFLX           3
# 1757     APBE           3
# 1758     ZNTU           3
# 1759      CRR           3
# 1760     ASFT           3
# 1761     SPAP           3
# 1762     TSXA           3
# 1763     OWTR           3
# 1764     PYLL           3
# 1765     INTQ           3
# 1766     JSFT           3
# 1767     PJPL           3
# 1768     QFLX           3
# 1769     DNAP           3
# 1770     SNSP           3
# 1771     PYPU           3
# 1772     NVDZ           2
# 1773     CSMO           2
# 1774     NTDA           2
# 1775     INNC           2
# 1776     PANS           2
# 1777     TWBR           2
# 1778     PVPL           2
# 1779     ABZN           2
# 1780     OSCL           2
# 1781     TWTK           2
# 1782     DOCY           2
# 1783     GOOS           2
# 1784     TSLI           2
# 1785     FNTC           2
# 1786     TWTC           2
# 1787     WGRK           2
# 1788     IINS           2
# 1789     IETA           2
# 1790     ADYE           2
# 1791     DWCU           2
# 1792     NUDA           2
# 1793     TSLK           2
# 1794     QDBE           2
# 1795      QBM           2
# 1796     TSLC           2
# 1797     TSTA           2
# 1798     AMZW           2
# 1799     DHCU           2
# 1800     TXTR           2
# 1801     TSLH           2
# 1802     LYGT           2
# 1803     UDER           2
# 1804     MEAA           2
# 1805     ISTC           2
# 1806     INSU           2
# 1807     ZFLX           2
# 1808     NBER           2
# 1809     SHJP           2
# 1810      IBX           2
# 1811     VNAP           2
# 1812     AMYN           2
# 1813     PYWL           2
# 1814     ARCL           2
# 1815     PRNS           2
# 1816     LYTT           2
# 1817     SSOT           2
# 1818     PDNS           2
# 1819     QRCL           2
# 1820     INOC           2
# 1821     AAPO           2
# 1822     ASLA           2
# 1823     BAIA           2
# 1824     DOHU           2
# 1825     LWFT           2
# 1826     SNAR           2
# 1827     IYTU           2
# 1828     IYPL           2
# 1829     SNAH           2
# 1830     WORF           2
# 1831     MSFP           2
# 1832     GOOE           2
# 1833      ADD           2
# 1834      TMD           2
# 1835     PYOL           2
# 1836     MSQT           2
# 1837     GAOG           2
# 1838     ADHE           2
# 1839     ORCC           2
# 1840     SWOT           2
# 1841     JOCU           2
# 1842     DJCU           2
# 1843     PIBS           2
# 1844     ZSFT           2
# ...
# 1989     FHOP           2
# 1990     TWJR           2
# 1991     KPOT           2
# 1992     METQ           2
# 1993     NVXA           2
# 1994     MOFT           2
# 1995     AJZN           2
# 1996     WOWK           2
# 1997     MCTA           2
# 1998     SHAP           2
# 1999     INIC           2
# 2000     MSFI           2
# 2001     DOCO           2
# 2002     LQFT           2
# 2003     UNTU           2
# 2004     PICS           2
# 2005     ASBE           2
# 2006     INSC           2
# 2007     CSOO           2
# 2008     HAPL           2
# 2009     PYJL           2
# 2010     UBEG           2
# 2011     DWTR           2
# 2012     UBEM           2
# 2013     YOOG           2
# 2014     UBEU           2
# 2015     GOKG           2
# 2016     PYRL           2
# 2017     VDBE           2
# 2018     SINS           2
# 2019     TYLA           2
# 2020     NFOX           2
# 2021     SNRP           2
# 2022     ADEE           2
# 2023     NDDA           2
# 2024     SPLT           2
# 2025     XNAP           2
# 2026     VRCL           2
# 2027     LYFB           2
# 2028     CWTR           2
# 2029     SIAP           2
# 2030     PYPG           2
# 2031     UOOG           2
# 2032     ORBL           2
# 2033     XWTR           2
# 2034     JYFT           2
# 2035      AAD           2
# 2036     SJAP           2
# 2037     ZDBE           2
# 2038     PFPL           2
# 2039     AMTN           2
# 2040     SNFP           2
# 2041     POCU           2
# 2042     IMZN           2
# 2043     INYU           2
# 2044     NFPX           2
# 2045     UNER           2
# 2046     IYFT           2
# 2047     OOCL           2
# 2048     MQFT           2
# 2049     PNTC           2
# 2050     AMXN           2
# 2051     METD           2
# 2052     GOZG           2
# 2053     AAPJ           2
# 2054     JRCL           2
# 2055     SPOO           2
# 2056     SNEP           2
# 2057     OACL           2
# 2058     LYPL           2
# 2059      IBH           2
# 2060     YDBE           2
# 2061     SAAP           2
# 2062      VGW           2
# 2063     CHCO           2
# 2064      VFW           2
# 2065     AMZR           2
# 2066     KAPL           2
# 2067     NSLX           2
# 2068     CZCO           2
# 2069     OETA           2
# 2070     NVDN           2
# 2071     SHOD           2
# 2072     SHOR           2
# 2073     EMZN           2
# 2074     OSCO           2
# 2075     NPOT           2
# 2076     ORVL           2
# 2077     TBLA           2
# 2078     AAXL           2
# 2079     NFLQ           2
# 2080     BABC           2
# 2081     EABA           2
# 2082     ADBJ           2
# 2083     LWTR           2
# 2084     BALA           2
# 2085     INHC           2
# 2086      MMD           2
# 2087     DOWU           2
# 2088     CPOT           2
# 2089     NVDL           2
# 2090     UBGR           2
# 2091     JYPL           2
# 2092     PKPL           2
# 2093     GOHG           2
# 2094     AOOG           2
# 2095     GNTC           2
# 2096     DOPU           2
# 2097      AMO           2
# 2098     ADBP           2
# 2099     PYPA           2
# 2100     WCRK           2
# 2101     ICTC           2
# 2102     UBRR           2
# 2103     CWCO           2
# 2104     SVAP           2
# 2105     TFTR           2
# 2106     LORK           2
# 2107     BQBA           2
# 2108     AALL           2
# 2109     CVCO           2
# 2110     HSLA           2
# 2111     NFLT           2
# 2112     OICL           2
# 2113     SHMP           2
# 2114     USFT           2
# 2115     WOBK           2
# 2116     NHLX           2
# 2117     UBOR           2
# 2118     SHKP           2
# 2119     BAPA           2
# 2120     DFLX           2
# 2121     UVDA           2
# 2122     OLCL           2
# 2123     SPOG           2
# 2124     SPOX           2
# 2125     AMHN           2
# 2126     SPET           2
# 2127     SNAK           2
# 2128     VYPL           2
# 2129     SPOK           2
# 2130     MRCL           2
# 2131     SWOP           2
# 2132     MYTA           2
# 2133     NVLX           2
# 2134     SKAP           2
# 2135      CRZ           2
# 2136     IQTC           2
# 2137     ILTC           2
# 2138     PIND           2
# 2139     MEFT           2
# 2140     WBER           2
# 2141     INBU           2
# 2142     ZWTR           2
# 2143     SPWT           2
# 2144     ADBH           2
# 2145     YNTC           2
# 2146     VBER           2
# 2147     AAPZ           2
# 2148     WORB           2
# 2149     QINS           2
# 2150     MEKA           2
# 2151     HNTC           2
# 2152     NVDW           2
# 2153     MSBT           2
# 2154     INJU           2
# 2155     SNIP           2
# 2156     USCO           2
# 2157     WVDA           2
# 2158     WWRK           2
# 2159     FYPL           2
# 2160     SAOP           2
# 2161     DKCU           2
# 2162     LTFT           2
# 2163     SHGP           2
# 2164     IZTC           2
# 2165     WORT           2
# 2166     SHNP           2
# 2167     TWVR           2
# 2168     IORK           2
# 2169     WOXK           2
# 2170     TSLB           2
# 2171      IAM           2
# 2172     EAPL           2
# 2173     ZINS           2
# 2174     MSFA           2
# 2175     RVDA           2
# 2176     HBER           2
# 2177     DBCU           2
# 2178     TWIR           2
# 2179     MSFZ           2
# 2180      AMV           2
# 2181     TWFR           2
# 2182     INVU           2
# 2183     SNOT           2
# 2184     INEU           2
# 2185      CRY           2
# 2186     PYFL           2
# 2187     MSZT           2
# 2188     NZLX           2
# 2189     AZBE           2
# 2190     NYPL           2
# 2191      LBM           2
# 2192     NVWA           2
# 2193     SSLA           2
# 2194     SROP           2
# 2195     LYFH           2
# 2196     WOCU           2
# 2197     ZPOT           2
# 2198     TWZR           2
# 2199     ORCV           2
# 2200     IJTC           2
# 2201     TSIA           2
# 2202     THOP           2
# 2203     GOPG           2
# 2204     PYPR           2
# 2205     PYPE           2
# 2206     ANBE           2
# 2207     AEBE           2
# 2208     XBER           2
# 2209     UBLR           2
# 2210      YMW           2
# 2211     WORN           2
# 2212     ORCK           2
# 2213     SHSP           2
# 2214     AMZZ           2
# 2215     XNTC           2
# 2216     SLOT           2
# 2217     CNTC           2
# 2218     SBAP           2
# 2219     APZN           2
# 2220      CLM           2
# 2221     ZOCU           2
# 2222     DOCQ           2
# 2223      IGM           2
# 2224     SPOW           2
# 2225     DINS           2
# 2226     INAP           2
# 2227     CSPO           2
# 2228     MDFT           2
# 2229     GSLA           2
# 2230     PETA           2
# 2231     ADBR           2
# 2232     AAPM           2
# 2233     RRCL           2
# 2234     PYBL           2
# 2235     INLU           2
# 2236     OMCL           2
# 2237      AMU           2
# 2238     UHER           2
# 2239     KETA           2
# 2240     NWLX           2
# 2241     KRCL           2
# 2242     AVPL           2
# 2243     BAJA           2
# 2244     MMZN           2
# 2245     ADBA           2
# 2246     PYPI           2
# 2247     WHRK           2
# 2248     IUTC           2
# 2249     UBEL           2
# 2250     ADBZ           2
# 2251     NVDT           2
# 2252     TSRA           2
# 2253     TWTY           2
# 2254     ORHL           2
# 2255      CYM           2
# 2256     AKZN           2
# 2257     AYPL           2
# 2258     TSTR           2
# 2259      IBA           2
# 2260     SEOP           2
# 2261     LABA           2
# 2262     AXPL           2
# 2263     XFLX           2
# 2264     AAPD           2
# 2265     MSWT           2
# 2266     NVDV           2
# 2267     AAPI           2
# 2268     IRTU           2
# 2269     IPOT           2
# 2270     NVGA           2
# 2271     IOTU           2
# 2272     ERCL           2
# 2273     MFFT           2
# 2274     KNAP           2
# 2275     IRTC           2
# 2276     AAWL           2
# 2277     BABH           2
# 2278     BKBA           1
# 2279     OAPL           1
# 2280     AAPW           1
# 2281     INJC           1
# 2282     NNAP           1
# 2283     LYFP           1
# 2284     PIAS           1
# 2285     NFLZ           1
# 2286     UBCR           1
# 2287     FETA           1
# 2288      YMD           1
# 2289     AWZN           1
# 2290     UORK           1
# 2291     IDTC           1
# 2292     DCCU           1
# 2293     CXCO           1
# 2294     CSCQ           1
# 2295     QNAP           1
# 2296     TAPL           1
# 2297     LPOT           1
# 2298     BNAP           1
# 2299     EWTR           1
# 2300     MSFU           1
# 2301     IWTU           1
# 2302     BABM           1
# 2303     IYTC           1
# 2304     IWTC           1
# 2305     TSLG           1
# 2306     DOCF           1
# 2307      IHM           1
# 2308     GOOR           1
# 2309     NNTU           1
# 2310     DOCN           1
# 2311     WSFT           1
# 2312     PYXL           1
# 2313     NODA           1
# 2314     ZNAP           1
# 2315     AMPL           1
# 2316     BABY           1
# 2317     PORK           1
# 2318     TWKR           1
# 2319     UXER           1
# 2320     WORP           1
# 2321     FSCO           1
# 2322     METX           1
# 2323     OBCL           1
# 2324     SXAP           1
# 2325     WORS           1
# 2326     INMU           1
# 2327     WOLK           1
# 2328     BAUA           1
# 2329     HORK           1
# 2330     SHOQ           1
# 2331     NFRX           1
# 2332     ORUL           1
# 2333     TJTR           1
# 2334     UBEC           1
# 2335     BABW           1
# 2336     ORGL           1
# 2337     TSOA           1
# 2338     TSBA           1
# 2339     SPOA           1
# 2340     OSFT           1
# 2341      XMD           1
# 2342     GOOF           1
# 2343     TSVA           1
# 2344     MSET           1
# 2345     MJTA           1
# 2346     NVDF           1
# 2347     CMZN           1
# 2348     DECU           1
# 2349     DFCU           1
# 2350      IBS           1
# 2351      HBM           1
# 2352     AMZO           1
# 2353     LZFT           1
# 2354     UFLX           1
# 2355     IABA           1
# 2356     LYFN           1
# 2357     DOYU           1
# 2358     ADNE           1
# 2359     INMC           1
# 2360     PIJS           1
# 2361     MSXT           1
# 2362     ANZN           1
# 2363     SYPL           1
# 2364     IITC           1
# 2365     VNTU           1
# 2366     TWMR           1
# 2367     PIZS           1
# 2368     PSPL           1
# 2369     YORK           1
# 2370     MZTA           1
# 2371     TATR           1
# 2372     WOOG           1
# 2373     NOLX           1
# 2374     HSFT           1
# 2375     NABA           1
# 2376     CSZO           1
# 2377      KMD           1
# 2378      VML           1
# 2379     CSJO           1
# 2380     TTTR           1
# 2381     LFLX           1
# 2382     LSLA           1
# 2383      FRM           1
# 2384     CSNO           1
# 2385      NBM           1
# 2386     CICO           1
# 2387     TSWA           1
# 2388     PYSL           1
# 2389     WORH           1
# 2390     SHOL           1
# 2391     WORX           1
# 2392     FOOG           1
# 2393      VRM           1
# 2394     SHOU           1
# 2395     LYFQ           1
# 2396     ADBT           1
# 2397     ATZN           1
# 2398     ADRE           1
# 2399     SAPL           1
# 2400     SNAX           1
# 2401     INGU           1
# 2402     FFLX           1
# 2403     BACA           1
# 2404     WOFK           1
# 2405     SZAP           1
# 2406     UBSR           1
# 2407     SNYP           1
# 2408     SWTR           1
# 2409     SNAY           1
# 2410     METZ           1
# 2411     JNAP           1
# 2412     WORJ           1
# 2413     UBEO           1
# 2414     LYLT           1
# 2415     WORO           1
# 2416     NILX           1
# 2417     DOCD           1
# 2418     MHOP           1
# 2419     GOOL           1
# 2420     NXDA           1
# 2421     IHTC           1
# 2422     JABA           1
# 2423     TFLX           1
# 2424     PYQL           1
# 2425     MUTA           1
# 2426     DOCB           1
# 2427     CSCC           1
# 2428     YMZN           1
# 2429     WORG           1
# 2430     CSCZ           1
# 2431     AVDA           1
# 2432     WHOP           1
# 2433     GOOU           1
# 2434     BLBA           1
# 2435     TSAA           1
# 2436     SHQP           1
# 2437     NVSA           1
# 2438     ORJL           1
# 2439     LYST           1
# 2440     TSKA           1
# 2441      VZW           1
# 2442     TKTR           1
# 2443     LYPT           1
# 2444     WORE           1
# 2445      VUW           1
# 2446     DOEU           1
# 2447     PYPK           1
# 2448     CSHO           1
# 2449     ADDE           1
# 2450     AATL           1
# 2451     TSMA           1
# 2452     BORK           1
# 2453     TSJA           1
# 2454     CYPL           1
# 2455     AMSN           1
# 2456     URCL           1
# 2457     DOSU           1
# 2458     NVAA           1
# 2459     KABA           1
# 2460     SPDT           1
# 2461     WMRK           1
# 2462     OYPL           1
# 2463     SHRP           1
# 2464     SNAD           1
# 2465     HDBE           1
# 2466     SGOT           1
# 2467     MSFW           1
# 2468     GOOH           1
# 2469     CKCO           1
# 2470     SDBE           1
# 2471     ORCN           1
# 2472     PYZL           1
# 2473     AMQN           1
# 2474     NFVX           1
# 2475     LYFD           1
# 2476     NVYA           1
# 2477     AMNN           1
# 2478     TDLA           1
# 2479     BUBA           1
# 2480     NFLP           1
# 2481     UTER           1
# 2482     PNNS           1
# 2483     PBER           1
# 2484     AMZX           1
# 2485     SUOT           1
# 2486     UJER           1
# 2487     EBER           1
# 2488     LYXT           1
# 2489     SSFT           1
# 2490     MNAP           1
# 2491     ZVDA           1
# 2492     GHOP           1
# 2493     GFOG           1
# 2494      CUM           1
# 2495     DICU           1
# 2496     CUCO           1
# 2497     NHDA           1
# 2498     RYFT           1
# 2499     ORYL           1
# 2500     KYFT           1
# 2501     PIMS           1
# 2502     AOZN           1
# 2503     MMTA           1
# 2504     ADCE           1
# 2505     SHOS           1
# 2506     METV           1
# 2507     UBTR           1
# 2508     QNTC           1
# 2509     ADBX           1
# 2510      VHW           1
# 2511     TITR           1
# 2512     GOOX           1
# 2513     SNAQ           1
# 2514     VSCO           1
# 2515     CJCO           1
# 2516     INPU           1
# 2517     BABB           1
# 2518     BBER           1
# 2519     AACL           1
# 2520     AAGL           1
# 2521     FWTR           1
# 2522      UMW           1
# 2523     DOCW           1
# 2524     SFAP           1
# 2525     TSSA           1
# 2526     TWTG           1
# 2527     ITTC           1
# 2528     AAPP           1
# 2529     LKFT           1
# 2530     ADBV           1
# 2531     GOJG           1
# 2532      VQW           1
# 2533     SNAF           1
# 2534     ORCU           1
# 2535     PINF           1
# 2536     QSLA           1
# 2537     IDTU           1
# 2538     NFLU           1
# 2539     LYFE           1
# 2540     SPFT           1
# 2541     OORK           1
# 2542     WONK           1
# 2543     ORCB           1
# 2544     OOCU           1
# 2545     LJFT           1
# 2546     PYPJ           1
# 2547     UBAR           1
# 2548     VHOP           1
# 2549     PIFS           1
# 2550     MPTA           1
# 2551     VOOG           1
# 2552     VETA           1
# 2553     NFLE           1
# 2554      IBW           1
# 2555      CFM           1
# 2556     LYRT           1
# 2557     STOP           1
# 2558     ADWE           1
# 2559     NNTC           1
# 2560     GUOG           1
# 2561     TPLA           1
# 2562     LYFR           1
# 2563     SJOP           1
# 2564     CNTU           1
# 2565     IPTU           1
# 2566     CGCO           1
# 2567     INKU           1
# 2568     MFTA           1
# 2569     JMZN           1
# 2570     HINS           1
# 2571     WFLX           1
# 2572     WORM           1
# 2573     DAPL           1
# 2574     METC           1
# 2575     PING           1
# 2576     WSLA           1
# 2577     MSST           1
# 2578     DOCI           1
# 2579     QOOG           1
# 2580     SHOM           1
# 2581     AAPR           1
# 2582      AMS           1
# 2583     PINW           1
# 2584     GAPL           1
# 2585     SPOL           1
# 2586     XSLA           1
# 2587     KOOG           1
# 2588     WNTC           1
# 2589     UETA           1
# 2590     UBUR           1
# 2591     DNCU           1
# 2592     DZCU           1
# 2593     ORCE           1
# 2594     SHOV           1
# 2595     SOAP           1
# 2596     SNAV           1
# 2597     NVKA           1
# 2598     GSOG           1
# 2599     SHOZ           1
# 2600     OMZN           1
# 2601     ORCO           1
# 2602     AAPA           1
# 2603     BSLA           1

# %% [markdown]
# -> Podemos notar que 30 siglas foram citadas mais de 6000 vezes nesse dataset, enquanto todas as outras foram citadas 14 ou menos vezes.
#
# -> A partir disso, podemos concluir que são 30 empresas que foram listadas nesse dataset e as demais são variações erradas, uma vez que a diferença é muito grande (6000 para 14).
#
# -> A partir disso, vamos agrupar as siglas por grau de semelhança com objetivo de fazer a correção das mais siglas e padronizar nosso dataset.

# %%
#Utilizando a função criada por Jairo com adição do retorno agora, uma vez que manipularemos os grupos
def Verifica_Categorias_base_retorno(dataframe, categoria):

    if categoria not in dataframe.columns:
        print(f"Erro: a categoria '{categoria}' não foi encontrada no DataFrame.")
        return []

    valores = dataframe[categoria].dropna().astype(str).str.strip().unique().tolist()  # Aqui estou pegando todos os nomes da lista Sector
    grupos = []

    while valores:
        base = valores.pop(0)
        grupo = [base]
        similares = []

        for v in valores:
            if fuzz.ratio(base, v) >= 60:  # Pega apenas os valores mais próximos para comparação
                grupo.append(v)
                similares.append(v)

        # Remove os que já foram agrupados
        valores = [v for v in valores if v not in similares]
        grupos.append(grupo)

    # Exibe os grupos
    for i, grupo in enumerate(grupos, 1):
        print(f"Grupo {i}: {grupo}")

    return grupos  # <-- retorno adicionado aqui


grupos_siglas = Verifica_Categorias_base_retorno(variacoes_siglas, 'variacao')
# Out:
# Grupo 1: ['ZM', 'ZMW', 'ZRM', 'AMZM', 'IZM', 'ZMD', 'CZM', 'ZMZN', 'ZBM']
# Grupo 2: ['SQ', 'SQOP', 'SNQP', 'SPQT', 'SQAP', 'SQOT', 'TSLQ', 'TSQA', 'MSQT', 'SPOQ', 'CSQO', 'CSCQ', 'SHOQ', 'SHQP', 'SNAQ']
# Grupo 3: ['PYPL', 'BYPL', 'XYPL', 'PBPL', 'PXPL', 'PYPM', 'PYPS', 'WYPL', 'PTPL', 'PAPL', 'PLPL', 'PYDL', 'HYPL', 'GYPL', 'PRPL', 'PYPT', 'PYPQ', 'PYPW', 'PYPB', 'PUPL', 'PQPL', 'PYYL', 'PYPF', 'PYTL', 'ZYPL', 'PYEL', 'RYPL', 'YYPL', 'PMPL', 'PNPL', 'DYPL', 'APPL', 'PYIL', 'YAPL', 'PHPL', 'PYPX', 'PGPL', 'PEPL', 'PPPL', 'PYUL', 'PIPL', 'PWPL', 'UYPL', 'PYPY', 'PYPN', 'PYVL', 'PYCL', 'POPL', 'PDPL', 'QYPL', 'PYAL', 'TYPL', 'PCPL', 'PYHL', 'PYPZ', 'PYPC', 'PYKL', 'PZPL', 'PYPV', 'KYPL', 'PYPO', 'PYLL', 'PJPL', 'PYPU', 'PVPL', 'PYWL', 'IYPL', 'PYOL', 'EYPL', 'PYNL', 'MYPL', 'PYPH', 'PYJL', 'PYRL', 'PYPG', 'PFPL', 'LYPL', 'JYPL', 'PKPL', 'PYPA', 'VYPL', 'FYPL', 'PYFL', 'NYPL', 'PYPR', 'PYPE', 'PYBL', 'PYPI', 'AYPL', 'PYXL', 'SYPL', 'PSPL', 'PYSL', 'PYQL', 'PYPK', 'CYPL', 'OYPL', 'PYZL', 'PYPJ']
# Grupo 4: ['SHOP', 'SHHP', 'SHOT', 'SHLP', 'SHUP', 'SHOB', 'SHOW', 'DHOP', 'SHOK', 'SNOP', 'IHOP', 'SBOP', 'YHOP', 'SKOP', 'SHXP', 'SHOX', 'LHOP', 'SPOP', 'JHOP', 'SHOO', 'AHOP', 'ZHOP', 'SHWP', 'SXOP', 'SHOG', 'CHOP', 'SHDP', 'SMOP', 'HHOP', 'SLOP', 'UHOP', 'SHYP', 'SFOP', 'SHTP', 'SOOP', 'SUOP', 'SHZP', 'OHOP', 'SHVP', 'SHEP', 'BHOP', 'SCOP', 'SHOF', 'XHOP', 'SHOH', 'SHOJ', 'EHOP', 'NHOP', 'SHOE', 'SDOP', 'SNHP', 'PHOP', 'SHOY', 'SHFP', 'SSOP', 'SVOP', 'SZOP', 'SYOP', 'KHOP', 'SHPP', 'SHIP', 'SHON', 'SHJP', 'SHOA', 'SHBP', 'SHCP', 'SGOP', 'SHOC', 'SHOI', 'FHOP', 'SHAP', 'SHOD', 'SHOR', 'SHMP', 'SHKP', 'SWOP', 'SAOP', 'SHGP', 'SHNP', 'SROP', 'THOP', 'SHSP', 'SEOP', 'SHOL', 'SHOU', 'MHOP', 'WHOP', 'CSHO', 'SHRP', 'GHOP', 'SHOS', 'VHOP', 'STOP', 'SJOP', 'SHOM', 'SHOV', 'SOAP', 'SHOZ']
# Grupo 5: ['META', 'TETA', 'MOTA', 'MEDA', 'MKTA', 'MEBA', 'METE', 'MEOA', 'METH', 'MATA', 'MEWA', 'METM', 'BETA', 'METY', 'MNTA', 'METG', 'CETA', 'MEGA', 'EETA', 'METF', 'MBTA', 'METR', 'MEUA', 'RETA', 'XETA', 'SETA', 'MENA', 'MTTA', 'MGTA', 'MDTA', 'MELA', 'GETA', 'JETA', 'METK', 'MEIA', 'AETA', 'YETA', 'QETA', 'MEXA', 'ZETA', 'METB', 'METS', 'MEPA', 'MERA', 'MEHA', 'MEFA', 'MWTA', 'METJ', 'MHTA', 'MSTA', 'METU', 'MEMA', 'METW', 'MXTA', 'LETA', 'NETA', 'MEZA', 'MRTA', 'MEJA', 'HETA', 'WETA', 'MEYA', 'METN', 'MESA', 'METI', 'IETA', 'MEAA', 'METT', 'METL', 'MVTA', 'MEVA', 'METO', 'MLTA', 'METP', 'DETA', 'MECA', 'MITA', 'METQ', 'MCTA', 'METD', 'OETA', 'MYTA', 'MEFT', 'MEKA', 'PETA', 'KETA', 'FETA', 'METX', 'MSET', 'MJTA', 'MZTA', 'METZ', 'MUTA', 'MMTA', 'METV', 'MPTA', 'VETA', 'MFTA', 'METC', 'UETA']
# Grupo 6: ['BABA', 'BABT', 'BABS', 'BYBA', 'BHBA', 'BABJ', 'GABA', 'BAZA', 'BABI', 'BABQ', 'TABA', 'UABA', 'BBBA', 'BAEA', 'XABA', 'BPBA', 'BAMA', 'BAHA', 'FABA', 'OABA', 'RABA', 'ZABA', 'PABA', 'YABA', 'BABD', 'BEBA', 'BABL', 'BABF', 'BAVA', 'BABU', 'BNBA', 'BABE', 'BABG', 'QABA', 'BGBA', 'BRBA', 'BANA', 'BMBA', 'BABN', 'BTBA', 'BOBA', 'BATA', 'BABO', 'BABZ', 'BVBA', 'BAFA', 'SABA', 'BIBA', 'BABK', 'BAYA', 'VABA', 'BAXA', 'BASA', 'BABV', 'BAWA', 'BWBA', 'BFBA', 'MABA', 'BABR', 'BABP', 'BAAA', 'BAGA', 'BARA', 'BCBA', 'AABA', 'BDBA', 'BAOA', 'BAIA', 'WABA', 'BADA', 'HABA', 'DABA', 'BABX', 'BXBA', 'BABC', 'EABA', 'BALA', 'BQBA', 'BAPA', 'BAJA', 'ADBA', 'LABA', 'BABH', 'BKBA', 'BABM', 'BABY', 'BAUA', 'BABW', 'IABA', 'NABA', 'BACA', 'JABA', 'BLBA', 'KABA', 'BUBA', 'BABB']
# Grupo 7: ['SNAP', 'YNAP', 'SNDP', 'SDAP', 'SWAP', 'SNWP', 'SNGP', 'SNAC', 'SNAA', 'SSAP', 'SRAP', 'HNAP', 'CNAP', 'ONAP', 'GNAP', 'SNAG', 'SNAW', 'SNMP', 'SNAU', 'WNAP', 'FNAP', 'TNAP', 'ANAP', 'SGAP', 'SNTP', 'SYAP', 'SNPP', 'SEAP', 'SNCP', 'SNAS', 'PNAP', 'SMAP', 'UNAP', 'SNVP', 'SNZP', 'STAP', 'SNXP', 'SNNP', 'SNAI', 'TSNA', 'SNKP', 'SNAT', 'SNBP', 'SNAL', 'SCAP', 'NAPL', 'SNAZ', 'SNAE', 'SNAJ', 'SNAN', 'RNAP', 'SNUP', 'LNAP', 'SUAP', 'SPAP', 'DNAP', 'SNSP', 'VNAP', 'SNAR', 'SNAH', 'SNAM', 'SLAP', 'SNLP', 'SNAO', 'SNAB', 'ENAP', 'SNRP', 'XNAP', 'SIAP', 'SJAP', 'SNFP', 'SNEP', 'SAAP', 'SVAP', 'SNAK', 'SKAP', 'SNIP', 'SBAP', 'INAP', 'KNAP', 'NNAP', 'QNAP', 'BNAP', 'ZNAP', 'SXAP', 'SAPL', 'SNAX', 'SZAP', 'SNYP', 'SNAY', 'JNAP', 'SNAD', 'MNAP', 'SFAP', 'SNAF', 'SNAV']
# Grupo 8: ['WORK', 'GORK', 'DORK', 'WYRK', 'AORK', 'WRRK', 'WXRK', 'VORK', 'WORW', 'WPRK', 'XORK', 'WOGK', 'WOOK', 'WDRK', 'EORK', 'WORA', 'WARK', 'WOMK', 'WORC', 'WSRK', 'WODK', 'WOZK', 'WORY', 'WORI', 'WJRK', 'WOQK', 'FORK', 'WOTK', 'WOYK', 'TWOR', 'WOAK', 'WORD', 'WERK', 'MORK', 'WORL', 'ORKL', 'WURK', 'WTRK', 'WVRK', 'WORZ', 'WLRK', 'CORK', 'WOSK', 'WOCK', 'WKRK', 'WORV', 'WOPK', 'WBRK', 'WNRK', 'WOJK', 'WOHK', 'WORU', 'RORK', 'TORK', 'WOVK', 'ZORK', 'WFRK', 'WORR', 'WOEK', 'SORK', 'WZRK', 'WORQ', 'WIRK', 'KORK', 'QORK', 'WGRK', 'WORF', 'NORK', 'WOIK', 'WOUK', 'WQRK', 'WOWK', 'WCRK', 'LORK', 'WOBK', 'WORB', 'WWRK', 'WORT', 'IORK', 'WOXK', 'WORN', 'ORCK', 'WHRK', 'UORK', 'PORK', 'WORP', 'WORS', 'WOLK', 'HORK', 'YORK', 'WORH', 'WORX', 'WOFK', 'WORJ', 'WORO', 'WORG', 'WORE', 'BORK', 'WMRK', 'OORK', 'WONK', 'WORM']
# Grupo 9: ['AMD', 'EMD', 'VMD', 'AMW', 'AMZ', 'DMD', 'AHD', 'AMK', 'AMJ', 'AMQ', 'IMD', 'PMD', 'RMD', 'APD', 'AMP', 'AVD', 'ABD', 'AMN', 'AQD', 'AMDN', 'ARD', 'AMC', 'ARM', 'AMR', 'HMD', 'OMD', 'NMD', 'AWD', 'FMD', 'AUD', 'WMD', 'AYD', 'JMD', 'CAM', 'AMG', 'AMM', 'AFD', 'ASD', 'ATD', 'ALD', 'AED', 'AOD', 'AJD', 'AME', 'AMH', 'AID', 'QMD', 'ACD', 'AZD', 'AGD', 'AND', 'AMF', 'CMD', 'ABM', 'AMT', 'AML', 'AMZD', 'UMD', 'LMD', 'AKD', 'AXD', 'AMB', 'AMA', 'SMD', 'AMY', 'ADD', 'TMD', 'AMX', 'GMD', 'AMI', 'AAD', 'MMD', 'AMO', 'IAM', 'AMV', 'AMU', 'YMD', 'XMD', 'KMD', 'AMS']
# Grupo 10: ['CSCO', 'CSRO', 'CSXO', 'WSCO', 'CSCY', 'XSCO', 'CMCO', 'PSCO', 'KSCO', 'CSCP', 'CRCO', 'CSVO', 'CSCT', 'DSCO', 'CPCO', 'CSCF', 'CSCI', 'BSCO', 'CSCU', 'CFCO', 'CBCO', 'CSUO', 'CSWO', 'SCOT', 'CACO', 'CSDO', 'RSCO', 'JSCO', 'MSCO', 'CSEO', 'CQCO', 'CSCX', 'SSCO', 'CSCS', 'HSCO', 'CSCB', 'CSCD', 'CSYO', 'CSAO', 'QSCO', 'CYCO', 'CSCG', 'CSCM', 'CSBO', 'CSTO', 'TSCO', 'CSCL', 'CSIO', 'CSCR', 'YSCO', 'ISCO', 'CSCN', 'CSCK', 'CSCA', 'CSCV', 'CSFO', 'CSKO', 'CSCE', 'CLCO', 'LSCO', 'ZSCO', 'NSCO', 'CECO', 'CTCO', 'CSLO', 'CSCH', 'CSCW', 'ASCO', 'CSCJ', 'GSCO', 'CNCO', 'CSSO', 'CDCO', 'ESCO', 'CSMO', 'CCCO', 'COCO', 'CSGO', 'CSOO', 'CHCO', 'CZCO', 'OSCO', 'CWCO', 'CVCO', 'USCO', 'CSPO', 'CXCO', 'FSCO', 'CSZO', 'CSJO', 'CSNO', 'CICO', 'CSCC', 'CSCZ', 'CKCO', 'CUCO', 'VSCO', 'CJCO', 'CGCO']
# Grupo 11: ['ORCL', 'OUCL', 'ORML', 'YRCL', 'OYCL', 'ORCT', 'ORWL', 'PRCL', 'IRCL', 'ORCJ', 'OPCL', 'ORCW', 'ONCL', 'ORAL', 'ORCP', 'ORCG', 'OXCL', 'OREL', 'ZRCL', 'ORSL', 'CRCL', 'ORCQ', 'OCCL', 'ORCD', 'HRCL', 'GRCL', 'ORFL', 'ORCF', 'ORRL', 'WRCL', 'NRCL', 'OHCL', 'FRCL', 'ORCZ', 'BRCL', 'OJCL', 'ORNL', 'OGCL', 'LRCL', 'OFCL', 'ORTL', 'OTCL', 'ORCA', 'ORCM', 'ORIL', 'OECL', 'OKCL', 'ORXL', 'ORCS', 'ORCI', 'OWCL', 'ORCY', 'ORPL', 'ODCL', 'SRCL', 'DRCL', 'OROL', 'ORLL', 'ORCX', 'OQCL', 'OSCL', 'ARCL', 'QRCL', 'ORCC', 'ORCH', 'OZCL', 'ORDL', 'ORCR', 'DOCL', 'XRCL', 'VRCL', 'ORBL', 'OOCL', 'JRCL', 'OACL', 'ORVL', 'OICL', 'OLCL', 'MRCL', 'ORCV', 'RRCL', 'OMCL', 'KRCL', 'ORHL', 'ERCL', 'OBCL', 'ORUL', 'ORGL', 'ORJL', 'URCL', 'ORCN', 'ORYL', 'ORCU', 'ORCB', 'ORCE', 'ORCO']
# Grupo 12: ['AAPL', 'IAPL', 'AAPH', 'XAPL', 'AQPL', 'MAPL', 'JAPL', 'AAPC', 'ATPL', 'AAUL', 'AARL', 'AHPL', 'ACPL', 'AAFL', 'AZPL', 'QAPL', 'AAIL', 'BAPL', 'LAPL', 'AAHL', 'AADL', 'AGPL', 'AAPF', 'AAPV', 'ANPL', 'AJPL', 'ABPL', 'AAPN', 'RAPL', 'AASL', 'AAVL', 'AANL', 'AAAL', 'AAPK', 'AAPS', 'ARPL', 'AAPT', 'AAOL', 'AAPB', 'AAKL', 'ADPL', 'AAPQ', 'AKPL', 'AAPY', 'FAPL', 'AAZL', 'CAPL', 'AABL', 'UAPL', 'AAQL', 'WAPL', 'AAML', 'AUPL', 'AAYL', 'AFPL', 'ASPL', 'ZAPL', 'AAPU', 'AWPL', 'AAEL', 'AAPG', 'AAPE', 'AAPX', 'AAPO', 'AOPL', 'HAPL', 'AAPJ', 'KAPL', 'AAXL', 'AALL', 'AAPZ', 'EAPL', 'AAPM', 'AVPL', 'AXPL', 'AAPD', 'AAPI', 'AAWL', 'OAPL', 'AAPW', 'TAPL', 'AMPL', 'AATL', 'AACL', 'AAGL', 'AAPP', 'DAPL', 'AAPR', 'GAPL', 'AAPA']
# Grupo 13: ['INTC', 'INTU', 'INTF', 'INTV', 'INTT', 'INTB', 'INTA', 'INLC', 'BNTC', 'INTH', 'INTS', 'INTP', 'INTI', 'INTM', 'UNTC', 'INTY', 'INTZ', 'INPC', 'INTX', 'INVC', 'INTG', 'INAC', 'INXC', 'INKC', 'LNTC', 'ANTC', 'INTD', 'INTJ', 'IBTC', 'INGC', 'INTO', 'INTR', 'JNTC', 'INDC', 'INBC', 'PINT', 'INTE', 'INRC', 'PINC', 'IXTC', 'INYC', 'ONTC', 'INEC', 'IFTC', 'INTK', 'INTN', 'INTL', 'INWC', 'ZNTC', 'INTW', 'INUC', 'SNTC', 'IMTC', 'DNTC', 'INCU', 'INQC', 'IOTC', 'IETC', 'INCC', 'VNTC', 'RNTC', 'KNTC', 'IKTC', 'TNTC', 'INZC', 'IPTC', 'INTQ', 'INNC', 'FNTC', 'ISTC', 'INOC', 'ENTC', 'IATC', 'IGTC', 'INIC', 'INSC', 'PNTC', 'INHC', 'GNTC', 'ICTC', 'IQTC', 'ILTC', 'YNTC', 'HNTC', 'IZTC', 'IJTC', 'XNTC', 'CNTC', 'IUTC', 'IRTC', 'INJC', 'IDTC', 'IYTC', 'IWTC', 'INMC', 'IITC', 'IHTC', 'QNTC', 'ITTC', 'NNTC', 'WNTC']
# Grupo 14: ['TSLA', 'TSLJ', 'TSUA', 'TSLR', 'TXLA', 'TILA', 'TSLN', 'FSLA', 'TSEA', 'TSGA', 'TSHA', 'TSLM', 'TVLA', 'CSLA', 'TULA', 'TSPA', 'TSLP', 'TELA', 'PSLA', 'TSLD', 'TSLW', 'USLA', 'TCLA', 'TWLA', 'NSLA', 'TSFA', 'TSLF', 'TTLA', 'KSLA', 'TJLA', 'TSLL', 'TFLA', 'TSLX', 'MSLA', 'TSLZ', 'TSLT', 'RSLA', 'TMLA', 'JSLA', 'TSLU', 'TNLA', 'TSLS', 'TSDA', 'ISLA', 'TSCA', 'THLA', 'TALA', 'TSLE', 'TSLV', 'YSLA', 'TSLY', 'ZSLA', 'TKLA', 'TGLA', 'OSLA', 'TLLA', 'TOLA', 'TQLA', 'TSZA', 'DSLA', 'TSXA', 'TSLI', 'TSLK', 'TSLC', 'TSTA', 'TSLH', 'ASLA', 'TSLO', 'ESLA', 'TRLA', 'TSYA', 'TYLA', 'TBLA', 'HSLA', 'TSLB', 'SSLA', 'TSIA', 'GSLA', 'TSRA', 'TSLG', 'TSOA', 'TSBA', 'TSVA', 'LSLA', 'TSWA', 'TSAA', 'TSKA', 'TSMA', 'TSJA', 'TDLA', 'TSSA', 'QSLA', 'TPLA', 'WSLA', 'XSLA', 'BSLA']
# Grupo 15: ['NVDA', 'NVJA', 'NZDA', 'FVDA', 'GVDA', 'NVQA', 'NVMA', 'JVDA', 'OVDA', 'NVDS', 'YVDA', 'NVDY', 'MVDA', 'NVDB', 'NVDJ', 'NJDA', 'NVLA', 'VVDA', 'NFDA', 'NGDA', 'NVIA', 'NQDA', 'NVHA', 'NVNA', 'NKDA', 'EVDA', 'HVDA', 'CVDA', 'NCDA', 'NVDX', 'NVZA', 'NVCA', 'NYDA', 'NVDP', 'NVDE', 'DVDA', 'NVVA', 'NADA', 'NRDA', 'PVDA', 'SVDA', 'NSDA', 'IVDA', 'NVDK', 'LVDA', 'NVDM', 'NVDU', 'NVDO', 'NVFA', 'NIDA', 'NPDA', 'NVUA', 'NVDQ', 'BVDA', 'NVDD', 'NWDA', 'NLDA', 'XVDA', 'NEDA', 'NBDA', 'NVRA', 'NVDH', 'NVBA', 'NVDZ', 'NTDA', 'NUDA', 'NMDA', 'NVDG', 'KVDA', 'QVDA', 'NVOA', 'NVDR', 'NVEA', 'NVDI', 'NVXA', 'NDDA', 'NVDN', 'NVDL', 'UVDA', 'NVDW', 'WVDA', 'RVDA', 'NVWA', 'NVDT', 'NVDV', 'NVGA', 'NODA', 'NVDF', 'NXDA', 'AVDA', 'NVSA', 'NVAA', 'NVYA', 'ZVDA', 'NHDA', 'NVKA']
# Grupo 16: ['LYFT', 'LFFT', 'CYFT', 'LEFT', 'LYFO', 'LSFT', 'LYWT', 'YSFT', 'VYFT', 'WYFT', 'LGFT', 'LYFG', 'UYFT', 'LYCT', 'LYFZ', 'LYFM', 'LYZT', 'LHFT', 'LYFF', 'LCFT', 'MYFT', 'LLFT', 'LIFT', 'LOFT', 'LYFX', 'LVFT', 'PYFT', 'LYIT', 'LYNT', 'LYFS', 'LMFT', 'QYFT', 'ZYFT', 'LDFT', 'LYFV', 'YYFT', 'FYFT', 'LYFC', 'NYFT', 'TYFT', 'LYET', 'LYFA', 'LYQT', 'LYDT', 'LYFI', 'EYFT', 'LYFK', 'LYUT', 'LXFT', 'LNFT', 'LYFY', 'DYFT', 'BYFT', 'LYFJ', 'XYFT', 'LYFW', 'LYJT', 'LYFL', 'LBFT', 'LYOT', 'LYYT', 'HYFT', 'SYFT', 'LYBT', 'MLFT', 'LYVT', 'LUFT', 'LYGT', 'LYTT', 'LWFT', 'LYKT', 'LPFT', 'AYFT', 'LYHT', 'LAFT', 'GYFT', 'LRFT', 'LYMT', 'LQFT', 'LYFB', 'JYFT', 'IYFT', 'LTFT', 'LYFH', 'LYFP', 'LZFT', 'LYFN', 'LYFQ', 'LYLT', 'LYST', 'LYPT', 'LYFD', 'LYXT', 'RYFT', 'KYFT', 'LKFT', 'LYFE', 'LJFT', 'LYRT', 'LYFR']
# Grupo 17: ['IBM', 'RBM', 'IRM', 'IDM', 'IXM', 'WBM', 'IBY', 'JBM', 'IBN', 'IBD', 'UBM', 'IEM', 'IBZ', 'ISM', 'FBM', 'IBK', 'IBF', 'ILM', 'CBM', 'IBE', 'IBC', 'IBU', 'IBQ', 'VBM', 'IBB', 'IBL', 'IUM', 'KBM', 'MBM', 'IPM', 'IWM', 'BBM', 'IIM', 'IMM', 'IOM', 'IBI', 'ITM', 'YBM', 'IBJ', 'OBM', 'IFM', 'IYM', 'IBG', 'IBT', 'BMW', 'GBM', 'INM', 'IKM', 'IMW', 'IQM', 'EBM', 'PBM', 'DBM', 'IBR', 'IBV', 'XBM', 'ICM', 'BRM', 'SBM', 'IJM', 'IBO', 'IBP', 'TBM', 'QBM', 'IBX', 'IVM', 'IBH', 'LBM', 'IGM', 'IBA', 'IHM', 'IBS', 'HBM', 'NBM', 'IBW']
# Grupo 18: ['SPOT', 'SAOT', 'SPOH', 'SPYT', 'SDOT', 'SPOF', 'UPOT', 'SPPT', 'SPON', 'SPOJ', 'SROT', 'DPOT', 'SPOB', 'OPOT', 'SPZT', 'SKOT', 'QPOT', 'SOOT', 'SPTT', 'SMOT', 'SPOY', 'SPUT', 'SYOT', 'SPKT', 'SPCT', 'SPMT', 'SPOM', 'SPOV', 'WPOT', 'SPGT', 'SPOD', 'RPOT', 'SPOZ', 'SEOT', 'JPOT', 'STOT', 'SPXT', 'EPOT', 'SPRT', 'SPOR', 'MPOT', 'SPVT', 'MSOT', 'SIOT', 'SPOC', 'SJOT', 'SPNT', 'XPOT', 'SPOI', 'SPOU', 'MSPT', 'SXOT', 'SZOT', 'SPST', 'SPOE', 'VPOT', 'SPOS', 'SPBT', 'GPOT', 'TPOT', 'PPOT', 'SPIT', 'SSOT', 'SWOT', 'SPHT', 'SVOT', 'SFOT', 'BPOT', 'SPAT', 'SBOT', 'FPOT', 'KPOT', 'SPLT', 'SPOO', 'NPOT', 'CPOT', 'SPOG', 'SPOX', 'SPET', 'SPOK', 'SPWT', 'SNOT', 'ZPOT', 'SLOT', 'SPOW', 'IPOT', 'LPOT', 'SPOA', 'SPDT', 'SGOT', 'SUOT', 'SPFT', 'SPOL']
# Grupo 19: ['VMW', 'KMW', 'VLW', 'VMN', 'PMW', 'VMZ', 'CMW', 'VOW', 'VMO', 'VVW', 'FMW', 'VMF', 'VPW', 'JMW', 'VWW', 'RMW', 'VIW', 'VME', 'VSW', 'VMX', 'VNW', 'VRW', 'VMU', 'SMW', 'XMW', 'VMH', 'VEW', 'DMW', 'VMI', 'VMJ', 'VMG', 'OMW', 'NMW', 'CVM', 'EMW', 'VMT', 'WMW', 'VKW', 'VXW', 'QMW', 'VMC', 'VMA', 'VMP', 'VMK', 'VDW', 'MMW', 'VCW', 'VMV', 'HMW', 'LMW', 'TMW', 'VBW', 'VMB', 'VMQ', 'VYW', 'VMR', 'VJW', 'VTW', 'VAW', 'VMY', 'VGW', 'VFW', 'YMW', 'VML', 'VRM', 'VZW', 'VUW', 'VHW', 'UMW', 'VQW']
# Grupo 20: ['ADBE', 'ADFE', 'ADBM', 'AUBE', 'KDBE', 'WDBE', 'ADUE', 'CDBE', 'ADQE', 'ABBE', 'ADOE', 'ADGE', 'EDBE', 'AGBE', 'AABE', 'AQBE', 'DDBE', 'ADSE', 'PDBE', 'AHBE', 'ADBW', 'IDBE', 'ADJE', 'ADIE', 'ADZE', 'ACBE', 'ADBN', 'DBER', 'ALBE', 'XDBE', 'ADBD', 'NDBE', 'ADBQ', 'AXBE', 'ARBE', 'AKBE', 'ADVE', 'AVBE', 'ADTE', 'ADBF', 'ADXE', 'AMBE', 'RDBE', 'ADBU', 'AJBE', 'BDBE', 'FDBE', 'ADBO', 'ODBE', 'AIBE', 'ABER', 'ADBL', 'ADLE', 'ADPE', 'MDBE', 'ADAE', 'ADBY', 'TDBE', 'JDBE', 'GDBE', 'ADBS', 'ATBE', 'AYBE', 'ADBK', 'AWBE', 'AFBE', 'LDBE', 'UDBE', 'APBE', 'ADYE', 'QDBE', 'ADHE', 'AOBE', 'ADBB', 'ASBE', 'VDBE', 'ADEE', 'ZDBE', 'YDBE', 'ADBJ', 'ADBP', 'ADBH', 'AZBE', 'ANBE', 'AEBE', 'ADBR', 'ADBZ', 'ADNE', 'ADBT', 'ADRE', 'ADDE', 'HDBE', 'SDBE', 'ADCE', 'ADBX', 'ADBV', 'ADWE']
# Grupo 21: ['TWTR', 'WWTR', 'YWTR', 'TWTN', 'TWER', 'TGTR', 'UWTR', 'TOTR', 'TWYR', 'TWTU', 'MWTR', 'GWTR', 'TWUR', 'TWTP', 'TWTA', 'TWTL', 'TWSR', 'AWTR', 'TWPR', 'VWTR', 'TWAR', 'TWXR', 'TWTX', 'TWQR', 'HWTR', 'TWTZ', 'BWTR', 'TWGR', 'TWTB', 'TWTF', 'TWTQ', 'QWTR', 'TWTT', 'TWTO', 'TWNR', 'TWHR', 'TMTR', 'TWTM', 'NWTR', 'TWTJ', 'TVTR', 'TYTR', 'TWDR', 'TWTD', 'TDTR', 'TWCR', 'TWTH', 'JWTR', 'TWRR', 'TWTW', 'TCTR', 'TWTV', 'TWWR', 'TETR', 'RWTR', 'TZTR', 'TNTR', 'TRTR', 'TWTI', 'TQTR', 'OWTR', 'TWBR', 'TWTK', 'TWTC', 'TXTR', 'TWTS', 'KWTR', 'PWTR', 'TUTR', 'TWLR', 'TPTR', 'THTR', 'TWJR', 'DWTR', 'CWTR', 'XWTR', 'LWTR', 'TFTR', 'ZWTR', 'TWVR', 'TWIR', 'TWFR', 'TWZR', 'TWTY', 'TSTR', 'EWTR', 'TWKR', 'TJTR', 'TWMR', 'TATR', 'TTTR', 'SWTR', 'TKTR', 'TITR', 'FWTR', 'TWTG']
# Grupo 22: ['PINS', 'PINL', 'PBNS', 'PPNS', 'PIXS', 'PIQS', 'PIRS', 'PIWS', 'PINY', 'PUNS', 'PMNS', 'LINS', 'PFNS', 'PZNS', 'OINS', 'NINS', 'PINO', 'PYNS', 'PINZ', 'PINE', 'PIOS', 'PINP', 'PINJ', 'PITS', 'YINS', 'PIYS', 'PINR', 'PINU', 'PONS', 'EINS', 'PENS', 'PCNS', 'PIKS', 'WINS', 'BINS', 'PTNS', 'PQNS', 'PKNS', 'XINS', 'PIGS', 'PINH', 'PIUS', 'PINK', 'PISS', 'TINS', 'PILS', 'PVNS', 'PWNS', 'PIHS', 'PINN', 'PXNS', 'CINS', 'PLNS', 'PINI', 'VINS', 'PJNS', 'GINS', 'PINA', 'AINS', 'JINS', 'PINM', 'RINS', 'MINS', 'PGNS', 'PIPS', 'PSNS', 'PIES', 'PINX', 'PINV', 'PANS', 'IINS', 'INSU', 'PRNS', 'PDNS', 'PIBS', 'PIIS', 'PINQ', 'PIVS', 'KINS', 'UINS', 'PIDS', 'PINB', 'PICS', 'SINS', 'PIND', 'QINS', 'ZINS', 'DINS', 'PIAS', 'PIJS', 'PIZS', 'PNNS', 'PIMS', 'PINF', 'PIFS', 'HINS', 'PING', 'PINW']
# Grupo 23: ['MSFT', 'MSRT', 'MSUT', 'MSFM', 'DSFT', 'CSFT', 'MWFT', 'ESFT', 'MMFT', 'MSFJ', 'MSFY', 'XSFT', 'VSFT', 'MCFT', 'MSFS', 'MTFT', 'MSFO', 'MSNT', 'MUFT', 'MSMT', 'MSFL', 'MKFT', 'ISFT', 'PSFT', 'RSFT', 'MSFE', 'MIFT', 'QSFT', 'MSFK', 'MSJT', 'MSKT', 'MSFR', 'NSFT', 'MSFB', 'MSHT', 'MSFF', 'MSTT', 'GSFT', 'MBFT', 'MRFT', 'MSVT', 'MSCT', 'MSFC', 'MSFX', 'MSDT', 'MGFT', 'MAFT', 'MSLT', 'KSFT', 'MSFV', 'MVFT', 'MSAT', 'MSFN', 'MSFD', 'MPFT', 'MHFT', 'MJFT', 'ASFT', 'JSFT', 'MSFP', 'ZSFT', 'TSFT', 'MSYT', 'FSFT', 'MZFT', 'MSIT', 'BSFT', 'MSFG', 'MOFT', 'MSFI', 'MQFT', 'USFT', 'MSBT', 'MSFA', 'MSFZ', 'MSZT', 'MDFT', 'MSWT', 'MFFT', 'MSFU', 'WSFT', 'OSFT', 'MSXT', 'HSFT', 'MSFW', 'SSFT', 'MSST']
# Grupo 24: ['GOOG', 'GTOG', 'HOOG', 'GROG', 'GJOG', 'JOOG', 'EOOG', 'GODG', 'GOQG', 'GBOG', 'GOOZ', 'GOTG', 'GOCG', 'GORG', 'GCOG', 'NOOG', 'GOBG', 'GOOV', 'GOVG', 'GLOG', 'GOLG', 'GOEG', 'GOGG', 'GOOO', 'GOOB', 'GOIG', 'GOOD', 'GPOG', 'GYOG', 'GOWG', 'OOOG', 'GXOG', 'GOOC', 'LOOG', 'GZOG', 'GOOY', 'GOYG', 'GOOI', 'GEOG', 'GOMG', 'XOOG', 'GOXG', 'GOOQ', 'TOOG', 'GOOA', 'GMOG', 'GOOJ', 'GDOG', 'GOOP', 'SOOG', 'GOSG', 'BOOG', 'IOOG', 'POOG', 'COOG', 'ZOOG', 'GOOT', 'GONG', 'GKOG', 'GWOG', 'DOOG', 'GOFG', 'GHOG', 'GGOG', 'GOOS', 'GOOE', 'GAOG', 'GOOM', 'GOON', 'GIOG', 'GOOK', 'GOUG', 'GQOG', 'GOAG', 'GNOG', 'GVOG', 'YOOG', 'GOKG', 'UOOG', 'GOZG', 'GOHG', 'AOOG', 'GOPG', 'GOOR', 'GOOF', 'WOOG', 'FOOG', 'GOOL', 'GOOU', 'GOOH', 'GFOG', 'GOOX', 'GOJG', 'VOOG', 'GUOG', 'QOOG', 'KOOG', 'GSOG']
# Grupo 25: ['DOCU', 'DOCG', 'DPCU', 'BOCU', 'FOCU', 'DUCU', 'DMCU', 'DOKU', 'AOCU', 'DOCH', 'DOCS', 'DORU', 'DOCZ', 'DRCU', 'DTCU', 'SOCU', 'DOCK', 'DOCR', 'COCU', 'VOCU', 'DONU', 'DLCU', 'DOQU', 'LOCU', 'DOCV', 'XOCU', 'MOCU', 'KOCU', 'DOCM', 'DOUU', 'DOCP', 'DSCU', 'DYCU', 'YOCU', 'NOCU', 'UOCU', 'DOCE', 'DXCU', 'HOCU', 'DVCU', 'EOCU', 'DOCT', 'DOXU', 'TOCU', 'DOVU', 'DOCX', 'ROCU', 'QOCU', 'DOFU', 'DOCA', 'DOMU', 'DOIU', 'GOCU', 'DGCU', 'DOCC', 'DODU', 'DOTU', 'DOOU', 'DOCJ', 'DDCU', 'DOJU', 'DOAU', 'DOCY', 'DWCU', 'DHCU', 'DOHU', 'JOCU', 'DJCU', 'DACU', 'DOLU', 'IOCU', 'DOCO', 'POCU', 'DOWU', 'DOPU', 'DKCU', 'DBCU', 'WOCU', 'ZOCU', 'DOCQ', 'DCCU', 'DOCF', 'DOCN', 'DECU', 'DFCU', 'DOYU', 'DOCD', 'DOCB', 'DOEU', 'DOSU', 'DICU', 'DOCW', 'OOCU', 'DOCI', 'DNCU', 'DZCU']
# Grupo 26: ['NFLX', 'NLLX', 'NFLJ', 'NFHX', 'RFLX', 'NFWX', 'KFLX', 'NFLW', 'NFLS', 'NFLH', 'MFLX', 'NQLX', 'NYLX', 'HFLX', 'NFLO', 'NDLX', 'NFAX', 'NULX', 'NBLX', 'JFLX', 'NFLA', 'AFLX', 'NALX', 'NFSX', 'NFLI', 'NFLL', 'NFQX', 'EFLX', 'NRLX', 'NELX', 'NFLD', 'NKLX', 'NFYX', 'VFLX', 'NFLY', 'CFLX', 'NFLC', 'YFLX', 'PFLX', 'SFLX', 'NFCX', 'NMLX', 'NFMX', 'NFBX', 'NFZX', 'NFLB', 'NFXX', 'NFJX', 'NPLX', 'GFLX', 'NFNX', 'NFTX', 'BFLX', 'NCLX', 'NXLX', 'NFIX', 'NFLN', 'NFLF', 'NFLR', 'NNLX', 'NFDX', 'NFGX', 'NFEX', 'IFLX', 'QFLX', 'ZFLX', 'NJLX', 'NFKX', 'NTLX', 'NFUX', 'NFLG', 'NFLK', 'NFLV', 'NGLX', 'OFLX', 'NFOX', 'NFPX', 'NSLX', 'NFLQ', 'NFLT', 'NHLX', 'DFLX', 'NVLX', 'NZLX', 'NWLX', 'XFLX', 'NFLZ', 'NFRX', 'UFLX', 'NOLX', 'LFLX', 'FFLX', 'NILX', 'TFLX', 'NFVX', 'NFLP', 'NFLU', 'NFLE', 'WFLX']
# Grupo 27: ['CRM', 'SRM', 'CRN', 'CQM', 'CRQ', 'CRX', 'CHM', 'CRG', 'CRA', 'CDM', 'DRM', 'CRO', 'URM', 'TRM', 'ORM', 'CRE', 'CRJ', 'YRM', 'LRM', 'CGM', 'CTM', 'CRP', 'CRB', 'PRM', 'CEM', 'CMM', 'WRM', 'XRM', 'JRM', 'GRM', 'NRM', 'COM', 'CRK', 'CRT', 'CRS', 'CNM', 'CXM', 'CCM', 'RRM', 'CRW', 'CRD', 'MRM', 'CJM', 'CWM', 'CRC', 'CRH', 'ERM', 'CRU', 'CRL', 'CRF', 'HRM', 'CPM', 'KRM', 'CSM', 'CRV', 'CRI', 'CRR', 'CKM', 'QRM', 'CRZ', 'CRY', 'CLM', 'CYM', 'FRM', 'CUM', 'CFM']
# Grupo 28: ['AMZN', 'BMZN', 'AMZB', 'AFZN', 'AMZP', 'WMZN', 'NMZN', 'AMUN', 'UMZN', 'AMLN', 'AHZN', 'AMZL', 'LMZN', 'KMZN', 'AMZG', 'AGZN', 'AMEN', 'GMZN', 'ALZN', 'AAZN', 'AMPN', 'TMZN', 'AQZN', 'AMZH', 'AMKN', 'AZZN', 'HMZN', 'AMRN', 'AMCN', 'RMZN', 'AMZA', 'AMZE', 'AMVN', 'DMZN', 'AMZQ', 'QMZN', 'AMZY', 'AMFN', 'VMZN', 'AMIN', 'FMZN', 'AMZF', 'ARZN', 'AMMN', 'AMZS', 'AMZK', 'AMON', 'AVZN', 'AMWN', 'AUZN', 'AMGN', 'AMAN', 'PMZN', 'ADZN', 'AMBN', 'ACZN', 'AMZT', 'AIZN', 'ABZN', 'AMZW', 'AMYN', 'AMZJ', 'AMZV', 'AYZN', 'AMZU', 'AMJN', 'SMZN', 'AMZC', 'AJZN', 'AMTN', 'IMZN', 'AMXN', 'AMZR', 'EMZN', 'AMHN', 'AMZZ', 'APZN', 'MMZN', 'AKZN', 'AWZN', 'CMZN', 'AMZO', 'ANZN', 'ATZN', 'YMZN', 'AMSN', 'AMQN', 'AMNN', 'AMZX', 'AOZN', 'JMZN', 'OMZN']
# Grupo 29: ['UBER', 'UBJR', 'UBEF', 'UKER', 'UBEP', 'UBEQ', 'GBER', 'OBER', 'TBER', 'IBER', 'UZER', 'UBQR', 'UBKR', 'UBED', 'MBER', 'UBVR', 'UBFR', 'UBNR', 'UGER', 'UBEI', 'UBES', 'LBER', 'UYER', 'UBET', 'UBEK', 'SBER', 'UBEY', 'UIER', 'FBER', 'UBZR', 'RBER', 'UQER', 'UAER', 'UBEB', 'UBPR', 'UFER', 'UBEX', 'ULER', 'UBMR', 'UBEH', 'UBBR', 'JBER', 'USER', 'UEER', 'UVER', 'ZBER', 'KBER', 'QBER', 'UPER', 'UBWR', 'UBEW', 'UBEV', 'UUER', 'UMER', 'UCER', 'UBEJ', 'UWER', 'UBHR', 'UBDR', 'UBEE', 'UBEZ', 'UBEA', 'YBER', 'UOER', 'UDER', 'NBER', 'UBEN', 'URER', 'UBEG', 'UBEM', 'UBEU', 'UNER', 'UBGR', 'UBRR', 'UBOR', 'WBER', 'VBER', 'HBER', 'XBER', 'UBLR', 'UHER', 'UBEL', 'UBCR', 'UXER', 'UBEC', 'UBSR', 'UBEO', 'UTER', 'PBER', 'UJER', 'EBER', 'UBTR', 'BBER', 'UBAR', 'UBUR']
# Grupo 30: ['IXTU', 'IZTU', 'ICTU', 'ISTU', 'IFTU', 'INXU', 'IATU', 'IGTU', 'IBTU', 'IVTU', 'ITTU', 'IUTU', 'IQTU', 'XNTU', 'IJTU', 'IMTU', 'ILTU', 'IITU', 'IYTU', 'IRTU', 'IOTU', 'IWTU', 'IDTU', 'IPTU']
# Grupo 31: ['MNTU', 'JNTU', 'HNTU', 'LNTU', 'FNTU', 'BNTU', 'PNTU', 'ANTU', 'TNTU', 'ENTU', 'KNTU', 'GNTU', 'DNTU', 'QNTU', 'RNTU', 'WNTU', 'ZNTU', 'YNTU', 'ONTU', 'UNTU', 'NNTU', 'VNTU', 'CNTU']
# Grupo 32: ['INDU', 'INQU', 'INHU', 'INRU', 'INIU', 'INAU', 'INFU', 'INUU', 'INWU', 'INNU', 'INOU', 'INZU', 'INYU', 'INBU', 'INJU', 'INVU', 'INEU', 'INLU', 'INMU', 'INGU', 'INPU', 'INKU']

# %% [markdown]
# -> Agora, podemos notar que esse algoritmo nos retornou 32 grupos de palavra, entretanto, sabemos que são 30 empresas. Apesar do algoritmo auxiliar bastante nesse processo, ele ainda comete algumas falhas, devido ao alto grau de semelhança entre algumas palavras.
#
# -> A partir disso, é necessário que realizemos uma espécie de inspeção manual, para corrigir algumas poucas falhas desse algoritmo.
#
# -> Esse processo ocorrerá analisando cada linha desse grupo de siglas e realocando manualmente para o outro grupo, além de excluir do grupo errado

# %%
#Removendo os nomes dos grupos errados e atribuindo nos grupos corretos

grupos_siglas[18].extend(['BMW', 'IMW', 'ZMW'])
grupos_siglas[26].extend(['ZRM','CZM', 'ARM', 'CAM', 'BRM', 'CVM'])
grupos_siglas[27].extend(['AMZM', 'ZMZN', 'AMDN', 'AMZD'])
grupos_siglas[16].extend(['IZM','ZBM', 'ABM', 'IAM'])
grupos_siglas[8].append('ZMD')

palavras_removidas = ['ZMW', 'ZRM', 'CZM', 'AMZM', 'ZMZN', 'IZM', 'ZBM','ZMD']
grupos_siglas[0] = [s for s in grupos_siglas[0] if s not in palavras_removidas]

grupos_siglas[6].extend(['SNQP', 'SQAP','SNAQ'])
grupos_siglas[17].extend(['SPQT', 'SQOT', 'SPOQ', 'SCOT'])
grupos_siglas[13].extend(['TSLQ', 'TSQA', 'TSNA'])
grupos_siglas[9].extend(['CSQO', 'CSCQ', 'CSHO'])
grupos_siglas[3].extend(['SHOQ', 'SHQP', 'SQOP'])
grupos_siglas[22].extend(['MSQT', 'MSOT', 'MSPT'])

palavras_removidas = ['SQOP', 'SNQP', 'SPQT', 'SQAP', 'SQOT', 'TSLQ', 'TSQA', 'MSQT', 'SPOQ', 'CSQO', 'CSCQ', 'SHOQ', 'SHQP', 'SNAQ']
grupos_siglas[1] = [s for s in grupos_siglas[1] if s not in palavras_removidas]

grupos_siglas[11].extend(['APPL', 'NAPL'])
grupos_siglas[2].remove('APPL')
grupos_siglas[3].remove('CSHO')
grupos_siglas[6].remove('TSNA')
grupos_siglas[6].remove('NAPL')

grupos_siglas[20].append('TWOR')
grupos_siglas[10].extend(['ORKL','ORCK'])

palavras_removidas = ['TWOR','ORKL','ORCK']

grupos_siglas[7] = [s for s in grupos_siglas[7] if s not in palavras_removidas]

palavras_removidas = ['ABM', 'IAM', 'ARM', 'CAM', 'AMDN', 'AMZD']

grupos_siglas[8] = [s for s in grupos_siglas[8] if s not in palavras_removidas]

grupos_siglas[9].remove('SCOT')

grupos_siglas[24].append('DOCL')
grupos_siglas[10].remove('DOCL')

grupos_siglas[29].extend(['INTU','INSU','INDU', 'INQU', 'INHU', 'INRU', 'INIU', 'INAU', 'INFU', 'INUU', 'INWU', 'INNU', 'INOU', 'INZU', 'INYU', 'INBU', 'INJU', 'INVU', 'INEU', 'INLU', 'INMU', 'INGU', 'INPU', 'INKU', 'MNTU', 'JNTU', 'HNTU', 'LNTU', 'FNTU', 'BNTU', 'PNTU', 'ANTU', 'TNTU', 'ENTU', 'KNTU', 'GNTU', 'DNTU', 'QNTU', 'RNTU', 'WNTU', 'ZNTU', 'YNTU', 'ONTU', 'UNTU', 'NNTU', 'VNTU', 'CNTU'])
grupos_siglas[12].remove('INTU')

grupos_siglas[22].append('MLFT')
grupos_siglas[15].remove('MLFT')

palavras_removidas = ['BMW','IMW','BRM']
grupos_siglas[16] = [s for s in grupos_siglas[16] if s not in palavras_removidas]

grupos_siglas[17].remove('MSOT')
grupos_siglas[17].remove('MSPT')
grupos_siglas[18].remove('CVM')

grupos_siglas[28].extend(['DBER','ABER'])
grupos_siglas[19].remove('DBER')
grupos_siglas[19].remove('ABER')
grupos_siglas[29].append('INSU')
grupos_siglas[21].remove('INSU')

del grupos_siglas[31]
del grupos_siglas[30]

# %% [markdown]
# -> Uma vez realizada a seleção manual, vamos rever como está nossos grupos de siglas no momento

# %%
for i, grupo in enumerate(grupos_siglas, 1):
        print(f"Grupo {i}: {grupo}")
# Out:
# Grupo 1: ['ZM']
# Grupo 2: ['SQ']
# Grupo 3: ['PYPL', 'BYPL', 'XYPL', 'PBPL', 'PXPL', 'PYPM', 'PYPS', 'WYPL', 'PTPL', 'PAPL', 'PLPL', 'PYDL', 'HYPL', 'GYPL', 'PRPL', 'PYPT', 'PYPQ', 'PYPW', 'PYPB', 'PUPL', 'PQPL', 'PYYL', 'PYPF', 'PYTL', 'ZYPL', 'PYEL', 'RYPL', 'YYPL', 'PMPL', 'PNPL', 'DYPL', 'PYIL', 'YAPL', 'PHPL', 'PYPX', 'PGPL', 'PEPL', 'PPPL', 'PYUL', 'PIPL', 'PWPL', 'UYPL', 'PYPY', 'PYPN', 'PYVL', 'PYCL', 'POPL', 'PDPL', 'QYPL', 'PYAL', 'TYPL', 'PCPL', 'PYHL', 'PYPZ', 'PYPC', 'PYKL', 'PZPL', 'PYPV', 'KYPL', 'PYPO', 'PYLL', 'PJPL', 'PYPU', 'PVPL', 'PYWL', 'IYPL', 'PYOL', 'EYPL', 'PYNL', 'MYPL', 'PYPH', 'PYJL', 'PYRL', 'PYPG', 'PFPL', 'LYPL', 'JYPL', 'PKPL', 'PYPA', 'VYPL', 'FYPL', 'PYFL', 'NYPL', 'PYPR', 'PYPE', 'PYBL', 'PYPI', 'AYPL', 'PYXL', 'SYPL', 'PSPL', 'PYSL', 'PYQL', 'PYPK', 'CYPL', 'OYPL', 'PYZL', 'PYPJ']
# Grupo 4: ['SHOP', 'SHHP', 'SHOT', 'SHLP', 'SHUP', 'SHOB', 'SHOW', 'DHOP', 'SHOK', 'SNOP', 'IHOP', 'SBOP', 'YHOP', 'SKOP', 'SHXP', 'SHOX', 'LHOP', 'SPOP', 'JHOP', 'SHOO', 'AHOP', 'ZHOP', 'SHWP', 'SXOP', 'SHOG', 'CHOP', 'SHDP', 'SMOP', 'HHOP', 'SLOP', 'UHOP', 'SHYP', 'SFOP', 'SHTP', 'SOOP', 'SUOP', 'SHZP', 'OHOP', 'SHVP', 'SHEP', 'BHOP', 'SCOP', 'SHOF', 'XHOP', 'SHOH', 'SHOJ', 'EHOP', 'NHOP', 'SHOE', 'SDOP', 'SNHP', 'PHOP', 'SHOY', 'SHFP', 'SSOP', 'SVOP', 'SZOP', 'SYOP', 'KHOP', 'SHPP', 'SHIP', 'SHON', 'SHJP', 'SHOA', 'SHBP', 'SHCP', 'SGOP', 'SHOC', 'SHOI', 'FHOP', 'SHAP', 'SHOD', 'SHOR', 'SHMP', 'SHKP', 'SWOP', 'SAOP', 'SHGP', 'SHNP', 'SROP', 'THOP', 'SHSP', 'SEOP', 'SHOL', 'SHOU', 'MHOP', 'WHOP', 'SHRP', 'GHOP', 'SHOS', 'VHOP', 'STOP', 'SJOP', 'SHOM', 'SHOV', 'SOAP', 'SHOZ', 'SHOQ', 'SHQP', 'SQOP']
# Grupo 5: ['META', 'TETA', 'MOTA', 'MEDA', 'MKTA', 'MEBA', 'METE', 'MEOA', 'METH', 'MATA', 'MEWA', 'METM', 'BETA', 'METY', 'MNTA', 'METG', 'CETA', 'MEGA', 'EETA', 'METF', 'MBTA', 'METR', 'MEUA', 'RETA', 'XETA', 'SETA', 'MENA', 'MTTA', 'MGTA', 'MDTA', 'MELA', 'GETA', 'JETA', 'METK', 'MEIA', 'AETA', 'YETA', 'QETA', 'MEXA', 'ZETA', 'METB', 'METS', 'MEPA', 'MERA', 'MEHA', 'MEFA', 'MWTA', 'METJ', 'MHTA', 'MSTA', 'METU', 'MEMA', 'METW', 'MXTA', 'LETA', 'NETA', 'MEZA', 'MRTA', 'MEJA', 'HETA', 'WETA', 'MEYA', 'METN', 'MESA', 'METI', 'IETA', 'MEAA', 'METT', 'METL', 'MVTA', 'MEVA', 'METO', 'MLTA', 'METP', 'DETA', 'MECA', 'MITA', 'METQ', 'MCTA', 'METD', 'OETA', 'MYTA', 'MEFT', 'MEKA', 'PETA', 'KETA', 'FETA', 'METX', 'MSET', 'MJTA', 'MZTA', 'METZ', 'MUTA', 'MMTA', 'METV', 'MPTA', 'VETA', 'MFTA', 'METC', 'UETA']
# Grupo 6: ['BABA', 'BABT', 'BABS', 'BYBA', 'BHBA', 'BABJ', 'GABA', 'BAZA', 'BABI', 'BABQ', 'TABA', 'UABA', 'BBBA', 'BAEA', 'XABA', 'BPBA', 'BAMA', 'BAHA', 'FABA', 'OABA', 'RABA', 'ZABA', 'PABA', 'YABA', 'BABD', 'BEBA', 'BABL', 'BABF', 'BAVA', 'BABU', 'BNBA', 'BABE', 'BABG', 'QABA', 'BGBA', 'BRBA', 'BANA', 'BMBA', 'BABN', 'BTBA', 'BOBA', 'BATA', 'BABO', 'BABZ', 'BVBA', 'BAFA', 'SABA', 'BIBA', 'BABK', 'BAYA', 'VABA', 'BAXA', 'BASA', 'BABV', 'BAWA', 'BWBA', 'BFBA', 'MABA', 'BABR', 'BABP', 'BAAA', 'BAGA', 'BARA', 'BCBA', 'AABA', 'BDBA', 'BAOA', 'BAIA', 'WABA', 'BADA', 'HABA', 'DABA', 'BABX', 'BXBA', 'BABC', 'EABA', 'BALA', 'BQBA', 'BAPA', 'BAJA', 'ADBA', 'LABA', 'BABH', 'BKBA', 'BABM', 'BABY', 'BAUA', 'BABW', 'IABA', 'NABA', 'BACA', 'JABA', 'BLBA', 'KABA', 'BUBA', 'BABB']
# Grupo 7: ['SNAP', 'YNAP', 'SNDP', 'SDAP', 'SWAP', 'SNWP', 'SNGP', 'SNAC', 'SNAA', 'SSAP', 'SRAP', 'HNAP', 'CNAP', 'ONAP', 'GNAP', 'SNAG', 'SNAW', 'SNMP', 'SNAU', 'WNAP', 'FNAP', 'TNAP', 'ANAP', 'SGAP', 'SNTP', 'SYAP', 'SNPP', 'SEAP', 'SNCP', 'SNAS', 'PNAP', 'SMAP', 'UNAP', 'SNVP', 'SNZP', 'STAP', 'SNXP', 'SNNP', 'SNAI', 'SNKP', 'SNAT', 'SNBP', 'SNAL', 'SCAP', 'SNAZ', 'SNAE', 'SNAJ', 'SNAN', 'RNAP', 'SNUP', 'LNAP', 'SUAP', 'SPAP', 'DNAP', 'SNSP', 'VNAP', 'SNAR', 'SNAH', 'SNAM', 'SLAP', 'SNLP', 'SNAO', 'SNAB', 'ENAP', 'SNRP', 'XNAP', 'SIAP', 'SJAP', 'SNFP', 'SNEP', 'SAAP', 'SVAP', 'SNAK', 'SKAP', 'SNIP', 'SBAP', 'INAP', 'KNAP', 'NNAP', 'QNAP', 'BNAP', 'ZNAP', 'SXAP', 'SAPL', 'SNAX', 'SZAP', 'SNYP', 'SNAY', 'JNAP', 'SNAD', 'MNAP', 'SFAP', 'SNAF', 'SNAV', 'SNQP', 'SQAP', 'SNAQ']
# Grupo 8: ['WORK', 'GORK', 'DORK', 'WYRK', 'AORK', 'WRRK', 'WXRK', 'VORK', 'WORW', 'WPRK', 'XORK', 'WOGK', 'WOOK', 'WDRK', 'EORK', 'WORA', 'WARK', 'WOMK', 'WORC', 'WSRK', 'WODK', 'WOZK', 'WORY', 'WORI', 'WJRK', 'WOQK', 'FORK', 'WOTK', 'WOYK', 'WOAK', 'WORD', 'WERK', 'MORK', 'WORL', 'WURK', 'WTRK', 'WVRK', 'WORZ', 'WLRK', 'CORK', 'WOSK', 'WOCK', 'WKRK', 'WORV', 'WOPK', 'WBRK', 'WNRK', 'WOJK', 'WOHK', 'WORU', 'RORK', 'TORK', 'WOVK', 'ZORK', 'WFRK', 'WORR', 'WOEK', 'SORK', 'WZRK', 'WORQ', 'WIRK', 'KORK', 'QORK', 'WGRK', 'WORF', 'NORK', 'WOIK', 'WOUK', 'WQRK', 'WOWK', 'WCRK', 'LORK', 'WOBK', 'WORB', 'WWRK', 'WORT', 'IORK', 'WOXK', 'WORN', 'WHRK', 'UORK', 'PORK', 'WORP', 'WORS', 'WOLK', 'HORK', 'YORK', 'WORH', 'WORX', 'WOFK', 'WORJ', 'WORO', 'WORG', 'WORE', 'BORK', 'WMRK', 'OORK', 'WONK', 'WORM']
# Grupo 9: ['AMD', 'EMD', 'VMD', 'AMW', 'AMZ', 'DMD', 'AHD', 'AMK', 'AMJ', 'AMQ', 'IMD', 'PMD', 'RMD', 'APD', 'AMP', 'AVD', 'ABD', 'AMN', 'AQD', 'ARD', 'AMC', 'AMR', 'HMD', 'OMD', 'NMD', 'AWD', 'FMD', 'AUD', 'WMD', 'AYD', 'JMD', 'AMG', 'AMM', 'AFD', 'ASD', 'ATD', 'ALD', 'AED', 'AOD', 'AJD', 'AME', 'AMH', 'AID', 'QMD', 'ACD', 'AZD', 'AGD', 'AND', 'AMF', 'CMD', 'AMT', 'AML', 'UMD', 'LMD', 'AKD', 'AXD', 'AMB', 'AMA', 'SMD', 'AMY', 'ADD', 'TMD', 'AMX', 'GMD', 'AMI', 'AAD', 'MMD', 'AMO', 'AMV', 'AMU', 'YMD', 'XMD', 'KMD', 'AMS', 'ZMD']
# Grupo 10: ['CSCO', 'CSRO', 'CSXO', 'WSCO', 'CSCY', 'XSCO', 'CMCO', 'PSCO', 'KSCO', 'CSCP', 'CRCO', 'CSVO', 'CSCT', 'DSCO', 'CPCO', 'CSCF', 'CSCI', 'BSCO', 'CSCU', 'CFCO', 'CBCO', 'CSUO', 'CSWO', 'CACO', 'CSDO', 'RSCO', 'JSCO', 'MSCO', 'CSEO', 'CQCO', 'CSCX', 'SSCO', 'CSCS', 'HSCO', 'CSCB', 'CSCD', 'CSYO', 'CSAO', 'QSCO', 'CYCO', 'CSCG', 'CSCM', 'CSBO', 'CSTO', 'TSCO', 'CSCL', 'CSIO', 'CSCR', 'YSCO', 'ISCO', 'CSCN', 'CSCK', 'CSCA', 'CSCV', 'CSFO', 'CSKO', 'CSCE', 'CLCO', 'LSCO', 'ZSCO', 'NSCO', 'CECO', 'CTCO', 'CSLO', 'CSCH', 'CSCW', 'ASCO', 'CSCJ', 'GSCO', 'CNCO', 'CSSO', 'CDCO', 'ESCO', 'CSMO', 'CCCO', 'COCO', 'CSGO', 'CSOO', 'CHCO', 'CZCO', 'OSCO', 'CWCO', 'CVCO', 'USCO', 'CSPO', 'CXCO', 'FSCO', 'CSZO', 'CSJO', 'CSNO', 'CICO', 'CSCC', 'CSCZ', 'CKCO', 'CUCO', 'VSCO', 'CJCO', 'CGCO', 'CSQO', 'CSCQ', 'CSHO']
# Grupo 11: ['ORCL', 'OUCL', 'ORML', 'YRCL', 'OYCL', 'ORCT', 'ORWL', 'PRCL', 'IRCL', 'ORCJ', 'OPCL', 'ORCW', 'ONCL', 'ORAL', 'ORCP', 'ORCG', 'OXCL', 'OREL', 'ZRCL', 'ORSL', 'CRCL', 'ORCQ', 'OCCL', 'ORCD', 'HRCL', 'GRCL', 'ORFL', 'ORCF', 'ORRL', 'WRCL', 'NRCL', 'OHCL', 'FRCL', 'ORCZ', 'BRCL', 'OJCL', 'ORNL', 'OGCL', 'LRCL', 'OFCL', 'ORTL', 'OTCL', 'ORCA', 'ORCM', 'ORIL', 'OECL', 'OKCL', 'ORXL', 'ORCS', 'ORCI', 'OWCL', 'ORCY', 'ORPL', 'ODCL', 'SRCL', 'DRCL', 'OROL', 'ORLL', 'ORCX', 'OQCL', 'OSCL', 'ARCL', 'QRCL', 'ORCC', 'ORCH', 'OZCL', 'ORDL', 'ORCR', 'XRCL', 'VRCL', 'ORBL', 'OOCL', 'JRCL', 'OACL', 'ORVL', 'OICL', 'OLCL', 'MRCL', 'ORCV', 'RRCL', 'OMCL', 'KRCL', 'ORHL', 'ERCL', 'OBCL', 'ORUL', 'ORGL', 'ORJL', 'URCL', 'ORCN', 'ORYL', 'ORCU', 'ORCB', 'ORCE', 'ORCO', 'ORKL', 'ORCK']
# Grupo 12: ['AAPL', 'IAPL', 'AAPH', 'XAPL', 'AQPL', 'MAPL', 'JAPL', 'AAPC', 'ATPL', 'AAUL', 'AARL', 'AHPL', 'ACPL', 'AAFL', 'AZPL', 'QAPL', 'AAIL', 'BAPL', 'LAPL', 'AAHL', 'AADL', 'AGPL', 'AAPF', 'AAPV', 'ANPL', 'AJPL', 'ABPL', 'AAPN', 'RAPL', 'AASL', 'AAVL', 'AANL', 'AAAL', 'AAPK', 'AAPS', 'ARPL', 'AAPT', 'AAOL', 'AAPB', 'AAKL', 'ADPL', 'AAPQ', 'AKPL', 'AAPY', 'FAPL', 'AAZL', 'CAPL', 'AABL', 'UAPL', 'AAQL', 'WAPL', 'AAML', 'AUPL', 'AAYL', 'AFPL', 'ASPL', 'ZAPL', 'AAPU', 'AWPL', 'AAEL', 'AAPG', 'AAPE', 'AAPX', 'AAPO', 'AOPL', 'HAPL', 'AAPJ', 'KAPL', 'AAXL', 'AALL', 'AAPZ', 'EAPL', 'AAPM', 'AVPL', 'AXPL', 'AAPD', 'AAPI', 'AAWL', 'OAPL', 'AAPW', 'TAPL', 'AMPL', 'AATL', 'AACL', 'AAGL', 'AAPP', 'DAPL', 'AAPR', 'GAPL', 'AAPA', 'APPL', 'NAPL']
# Grupo 13: ['INTC', 'INTF', 'INTV', 'INTT', 'INTB', 'INTA', 'INLC', 'BNTC', 'INTH', 'INTS', 'INTP', 'INTI', 'INTM', 'UNTC', 'INTY', 'INTZ', 'INPC', 'INTX', 'INVC', 'INTG', 'INAC', 'INXC', 'INKC', 'LNTC', 'ANTC', 'INTD', 'INTJ', 'IBTC', 'INGC', 'INTO', 'INTR', 'JNTC', 'INDC', 'INBC', 'PINT', 'INTE', 'INRC', 'PINC', 'IXTC', 'INYC', 'ONTC', 'INEC', 'IFTC', 'INTK', 'INTN', 'INTL', 'INWC', 'ZNTC', 'INTW', 'INUC', 'SNTC', 'IMTC', 'DNTC', 'INCU', 'INQC', 'IOTC', 'IETC', 'INCC', 'VNTC', 'RNTC', 'KNTC', 'IKTC', 'TNTC', 'INZC', 'IPTC', 'INTQ', 'INNC', 'FNTC', 'ISTC', 'INOC', 'ENTC', 'IATC', 'IGTC', 'INIC', 'INSC', 'PNTC', 'INHC', 'GNTC', 'ICTC', 'IQTC', 'ILTC', 'YNTC', 'HNTC', 'IZTC', 'IJTC', 'XNTC', 'CNTC', 'IUTC', 'IRTC', 'INJC', 'IDTC', 'IYTC', 'IWTC', 'INMC', 'IITC', 'IHTC', 'QNTC', 'ITTC', 'NNTC', 'WNTC']
# Grupo 14: ['TSLA', 'TSLJ', 'TSUA', 'TSLR', 'TXLA', 'TILA', 'TSLN', 'FSLA', 'TSEA', 'TSGA', 'TSHA', 'TSLM', 'TVLA', 'CSLA', 'TULA', 'TSPA', 'TSLP', 'TELA', 'PSLA', 'TSLD', 'TSLW', 'USLA', 'TCLA', 'TWLA', 'NSLA', 'TSFA', 'TSLF', 'TTLA', 'KSLA', 'TJLA', 'TSLL', 'TFLA', 'TSLX', 'MSLA', 'TSLZ', 'TSLT', 'RSLA', 'TMLA', 'JSLA', 'TSLU', 'TNLA', 'TSLS', 'TSDA', 'ISLA', 'TSCA', 'THLA', 'TALA', 'TSLE', 'TSLV', 'YSLA', 'TSLY', 'ZSLA', 'TKLA', 'TGLA', 'OSLA', 'TLLA', 'TOLA', 'TQLA', 'TSZA', 'DSLA', 'TSXA', 'TSLI', 'TSLK', 'TSLC', 'TSTA', 'TSLH', 'ASLA', 'TSLO', 'ESLA', 'TRLA', 'TSYA', 'TYLA', 'TBLA', 'HSLA', 'TSLB', 'SSLA', 'TSIA', 'GSLA', 'TSRA', 'TSLG', 'TSOA', 'TSBA', 'TSVA', 'LSLA', 'TSWA', 'TSAA', 'TSKA', 'TSMA', 'TSJA', 'TDLA', 'TSSA', 'QSLA', 'TPLA', 'WSLA', 'XSLA', 'BSLA', 'TSLQ', 'TSQA', 'TSNA']
# Grupo 15: ['NVDA', 'NVJA', 'NZDA', 'FVDA', 'GVDA', 'NVQA', 'NVMA', 'JVDA', 'OVDA', 'NVDS', 'YVDA', 'NVDY', 'MVDA', 'NVDB', 'NVDJ', 'NJDA', 'NVLA', 'VVDA', 'NFDA', 'NGDA', 'NVIA', 'NQDA', 'NVHA', 'NVNA', 'NKDA', 'EVDA', 'HVDA', 'CVDA', 'NCDA', 'NVDX', 'NVZA', 'NVCA', 'NYDA', 'NVDP', 'NVDE', 'DVDA', 'NVVA', 'NADA', 'NRDA', 'PVDA', 'SVDA', 'NSDA', 'IVDA', 'NVDK', 'LVDA', 'NVDM', 'NVDU', 'NVDO', 'NVFA', 'NIDA', 'NPDA', 'NVUA', 'NVDQ', 'BVDA', 'NVDD', 'NWDA', 'NLDA', 'XVDA', 'NEDA', 'NBDA', 'NVRA', 'NVDH', 'NVBA', 'NVDZ', 'NTDA', 'NUDA', 'NMDA', 'NVDG', 'KVDA', 'QVDA', 'NVOA', 'NVDR', 'NVEA', 'NVDI', 'NVXA', 'NDDA', 'NVDN', 'NVDL', 'UVDA', 'NVDW', 'WVDA', 'RVDA', 'NVWA', 'NVDT', 'NVDV', 'NVGA', 'NODA', 'NVDF', 'NXDA', 'AVDA', 'NVSA', 'NVAA', 'NVYA', 'ZVDA', 'NHDA', 'NVKA']
# Grupo 16: ['LYFT', 'LFFT', 'CYFT', 'LEFT', 'LYFO', 'LSFT', 'LYWT', 'YSFT', 'VYFT', 'WYFT', 'LGFT', 'LYFG', 'UYFT', 'LYCT', 'LYFZ', 'LYFM', 'LYZT', 'LHFT', 'LYFF', 'LCFT', 'MYFT', 'LLFT', 'LIFT', 'LOFT', 'LYFX', 'LVFT', 'PYFT', 'LYIT', 'LYNT', 'LYFS', 'LMFT', 'QYFT', 'ZYFT', 'LDFT', 'LYFV', 'YYFT', 'FYFT', 'LYFC', 'NYFT', 'TYFT', 'LYET', 'LYFA', 'LYQT', 'LYDT', 'LYFI', 'EYFT', 'LYFK', 'LYUT', 'LXFT', 'LNFT', 'LYFY', 'DYFT', 'BYFT', 'LYFJ', 'XYFT', 'LYFW', 'LYJT', 'LYFL', 'LBFT', 'LYOT', 'LYYT', 'HYFT', 'SYFT', 'LYBT', 'LYVT', 'LUFT', 'LYGT', 'LYTT', 'LWFT', 'LYKT', 'LPFT', 'AYFT', 'LYHT', 'LAFT', 'GYFT', 'LRFT', 'LYMT', 'LQFT', 'LYFB', 'JYFT', 'IYFT', 'LTFT', 'LYFH', 'LYFP', 'LZFT', 'LYFN', 'LYFQ', 'LYLT', 'LYST', 'LYPT', 'LYFD', 'LYXT', 'RYFT', 'KYFT', 'LKFT', 'LYFE', 'LJFT', 'LYRT', 'LYFR']
# Grupo 17: ['IBM', 'RBM', 'IRM', 'IDM', 'IXM', 'WBM', 'IBY', 'JBM', 'IBN', 'IBD', 'UBM', 'IEM', 'IBZ', 'ISM', 'FBM', 'IBK', 'IBF', 'ILM', 'CBM', 'IBE', 'IBC', 'IBU', 'IBQ', 'VBM', 'IBB', 'IBL', 'IUM', 'KBM', 'MBM', 'IPM', 'IWM', 'BBM', 'IIM', 'IMM', 'IOM', 'IBI', 'ITM', 'YBM', 'IBJ', 'OBM', 'IFM', 'IYM', 'IBG', 'IBT', 'GBM', 'INM', 'IKM', 'IQM', 'EBM', 'PBM', 'DBM', 'IBR', 'IBV', 'XBM', 'ICM', 'SBM', 'IJM', 'IBO', 'IBP', 'TBM', 'QBM', 'IBX', 'IVM', 'IBH', 'LBM', 'IGM', 'IBA', 'IHM', 'IBS', 'HBM', 'NBM', 'IBW', 'IZM', 'ZBM', 'ABM', 'IAM']
# Grupo 18: ['SPOT', 'SAOT', 'SPOH', 'SPYT', 'SDOT', 'SPOF', 'UPOT', 'SPPT', 'SPON', 'SPOJ', 'SROT', 'DPOT', 'SPOB', 'OPOT', 'SPZT', 'SKOT', 'QPOT', 'SOOT', 'SPTT', 'SMOT', 'SPOY', 'SPUT', 'SYOT', 'SPKT', 'SPCT', 'SPMT', 'SPOM', 'SPOV', 'WPOT', 'SPGT', 'SPOD', 'RPOT', 'SPOZ', 'SEOT', 'JPOT', 'STOT', 'SPXT', 'EPOT', 'SPRT', 'SPOR', 'MPOT', 'SPVT', 'SIOT', 'SPOC', 'SJOT', 'SPNT', 'XPOT', 'SPOI', 'SPOU', 'SXOT', 'SZOT', 'SPST', 'SPOE', 'VPOT', 'SPOS', 'SPBT', 'GPOT', 'TPOT', 'PPOT', 'SPIT', 'SSOT', 'SWOT', 'SPHT', 'SVOT', 'SFOT', 'BPOT', 'SPAT', 'SBOT', 'FPOT', 'KPOT', 'SPLT', 'SPOO', 'NPOT', 'CPOT', 'SPOG', 'SPOX', 'SPET', 'SPOK', 'SPWT', 'SNOT', 'ZPOT', 'SLOT', 'SPOW', 'IPOT', 'LPOT', 'SPOA', 'SPDT', 'SGOT', 'SUOT', 'SPFT', 'SPOL', 'SPQT', 'SQOT', 'SPOQ', 'SCOT']
# Grupo 19: ['VMW', 'KMW', 'VLW', 'VMN', 'PMW', 'VMZ', 'CMW', 'VOW', 'VMO', 'VVW', 'FMW', 'VMF', 'VPW', 'JMW', 'VWW', 'RMW', 'VIW', 'VME', 'VSW', 'VMX', 'VNW', 'VRW', 'VMU', 'SMW', 'XMW', 'VMH', 'VEW', 'DMW', 'VMI', 'VMJ', 'VMG', 'OMW', 'NMW', 'EMW', 'VMT', 'WMW', 'VKW', 'VXW', 'QMW', 'VMC', 'VMA', 'VMP', 'VMK', 'VDW', 'MMW', 'VCW', 'VMV', 'HMW', 'LMW', 'TMW', 'VBW', 'VMB', 'VMQ', 'VYW', 'VMR', 'VJW', 'VTW', 'VAW', 'VMY', 'VGW', 'VFW', 'YMW', 'VML', 'VRM', 'VZW', 'VUW', 'VHW', 'UMW', 'VQW', 'BMW', 'IMW', 'ZMW']
# Grupo 20: ['ADBE', 'ADFE', 'ADBM', 'AUBE', 'KDBE', 'WDBE', 'ADUE', 'CDBE', 'ADQE', 'ABBE', 'ADOE', 'ADGE', 'EDBE', 'AGBE', 'AABE', 'AQBE', 'DDBE', 'ADSE', 'PDBE', 'AHBE', 'ADBW', 'IDBE', 'ADJE', 'ADIE', 'ADZE', 'ACBE', 'ADBN', 'ALBE', 'XDBE', 'ADBD', 'NDBE', 'ADBQ', 'AXBE', 'ARBE', 'AKBE', 'ADVE', 'AVBE', 'ADTE', 'ADBF', 'ADXE', 'AMBE', 'RDBE', 'ADBU', 'AJBE', 'BDBE', 'FDBE', 'ADBO', 'ODBE', 'AIBE', 'ADBL', 'ADLE', 'ADPE', 'MDBE', 'ADAE', 'ADBY', 'TDBE', 'JDBE', 'GDBE', 'ADBS', 'ATBE', 'AYBE', 'ADBK', 'AWBE', 'AFBE', 'LDBE', 'UDBE', 'APBE', 'ADYE', 'QDBE', 'ADHE', 'AOBE', 'ADBB', 'ASBE', 'VDBE', 'ADEE', 'ZDBE', 'YDBE', 'ADBJ', 'ADBP', 'ADBH', 'AZBE', 'ANBE', 'AEBE', 'ADBR', 'ADBZ', 'ADNE', 'ADBT', 'ADRE', 'ADDE', 'HDBE', 'SDBE', 'ADCE', 'ADBX', 'ADBV', 'ADWE']
# Grupo 21: ['TWTR', 'WWTR', 'YWTR', 'TWTN', 'TWER', 'TGTR', 'UWTR', 'TOTR', 'TWYR', 'TWTU', 'MWTR', 'GWTR', 'TWUR', 'TWTP', 'TWTA', 'TWTL', 'TWSR', 'AWTR', 'TWPR', 'VWTR', 'TWAR', 'TWXR', 'TWTX', 'TWQR', 'HWTR', 'TWTZ', 'BWTR', 'TWGR', 'TWTB', 'TWTF', 'TWTQ', 'QWTR', 'TWTT', 'TWTO', 'TWNR', 'TWHR', 'TMTR', 'TWTM', 'NWTR', 'TWTJ', 'TVTR', 'TYTR', 'TWDR', 'TWTD', 'TDTR', 'TWCR', 'TWTH', 'JWTR', 'TWRR', 'TWTW', 'TCTR', 'TWTV', 'TWWR', 'TETR', 'RWTR', 'TZTR', 'TNTR', 'TRTR', 'TWTI', 'TQTR', 'OWTR', 'TWBR', 'TWTK', 'TWTC', 'TXTR', 'TWTS', 'KWTR', 'PWTR', 'TUTR', 'TWLR', 'TPTR', 'THTR', 'TWJR', 'DWTR', 'CWTR', 'XWTR', 'LWTR', 'TFTR', 'ZWTR', 'TWVR', 'TWIR', 'TWFR', 'TWZR', 'TWTY', 'TSTR', 'EWTR', 'TWKR', 'TJTR', 'TWMR', 'TATR', 'TTTR', 'SWTR', 'TKTR', 'TITR', 'FWTR', 'TWTG', 'TWOR']
# Grupo 22: ['PINS', 'PINL', 'PBNS', 'PPNS', 'PIXS', 'PIQS', 'PIRS', 'PIWS', 'PINY', 'PUNS', 'PMNS', 'LINS', 'PFNS', 'PZNS', 'OINS', 'NINS', 'PINO', 'PYNS', 'PINZ', 'PINE', 'PIOS', 'PINP', 'PINJ', 'PITS', 'YINS', 'PIYS', 'PINR', 'PINU', 'PONS', 'EINS', 'PENS', 'PCNS', 'PIKS', 'WINS', 'BINS', 'PTNS', 'PQNS', 'PKNS', 'XINS', 'PIGS', 'PINH', 'PIUS', 'PINK', 'PISS', 'TINS', 'PILS', 'PVNS', 'PWNS', 'PIHS', 'PINN', 'PXNS', 'CINS', 'PLNS', 'PINI', 'VINS', 'PJNS', 'GINS', 'PINA', 'AINS', 'JINS', 'PINM', 'RINS', 'MINS', 'PGNS', 'PIPS', 'PSNS', 'PIES', 'PINX', 'PINV', 'PANS', 'IINS', 'PRNS', 'PDNS', 'PIBS', 'PIIS', 'PINQ', 'PIVS', 'KINS', 'UINS', 'PIDS', 'PINB', 'PICS', 'SINS', 'PIND', 'QINS', 'ZINS', 'DINS', 'PIAS', 'PIJS', 'PIZS', 'PNNS', 'PIMS', 'PINF', 'PIFS', 'HINS', 'PING', 'PINW']
# Grupo 23: ['MSFT', 'MSRT', 'MSUT', 'MSFM', 'DSFT', 'CSFT', 'MWFT', 'ESFT', 'MMFT', 'MSFJ', 'MSFY', 'XSFT', 'VSFT', 'MCFT', 'MSFS', 'MTFT', 'MSFO', 'MSNT', 'MUFT', 'MSMT', 'MSFL', 'MKFT', 'ISFT', 'PSFT', 'RSFT', 'MSFE', 'MIFT', 'QSFT', 'MSFK', 'MSJT', 'MSKT', 'MSFR', 'NSFT', 'MSFB', 'MSHT', 'MSFF', 'MSTT', 'GSFT', 'MBFT', 'MRFT', 'MSVT', 'MSCT', 'MSFC', 'MSFX', 'MSDT', 'MGFT', 'MAFT', 'MSLT', 'KSFT', 'MSFV', 'MVFT', 'MSAT', 'MSFN', 'MSFD', 'MPFT', 'MHFT', 'MJFT', 'ASFT', 'JSFT', 'MSFP', 'ZSFT', 'TSFT', 'MSYT', 'FSFT', 'MZFT', 'MSIT', 'BSFT', 'MSFG', 'MOFT', 'MSFI', 'MQFT', 'USFT', 'MSBT', 'MSFA', 'MSFZ', 'MSZT', 'MDFT', 'MSWT', 'MFFT', 'MSFU', 'WSFT', 'OSFT', 'MSXT', 'HSFT', 'MSFW', 'SSFT', 'MSST', 'MSQT', 'MSOT', 'MSPT', 'MLFT']
# Grupo 24: ['GOOG', 'GTOG', 'HOOG', 'GROG', 'GJOG', 'JOOG', 'EOOG', 'GODG', 'GOQG', 'GBOG', 'GOOZ', 'GOTG', 'GOCG', 'GORG', 'GCOG', 'NOOG', 'GOBG', 'GOOV', 'GOVG', 'GLOG', 'GOLG', 'GOEG', 'GOGG', 'GOOO', 'GOOB', 'GOIG', 'GOOD', 'GPOG', 'GYOG', 'GOWG', 'OOOG', 'GXOG', 'GOOC', 'LOOG', 'GZOG', 'GOOY', 'GOYG', 'GOOI', 'GEOG', 'GOMG', 'XOOG', 'GOXG', 'GOOQ', 'TOOG', 'GOOA', 'GMOG', 'GOOJ', 'GDOG', 'GOOP', 'SOOG', 'GOSG', 'BOOG', 'IOOG', 'POOG', 'COOG', 'ZOOG', 'GOOT', 'GONG', 'GKOG', 'GWOG', 'DOOG', 'GOFG', 'GHOG', 'GGOG', 'GOOS', 'GOOE', 'GAOG', 'GOOM', 'GOON', 'GIOG', 'GOOK', 'GOUG', 'GQOG', 'GOAG', 'GNOG', 'GVOG', 'YOOG', 'GOKG', 'UOOG', 'GOZG', 'GOHG', 'AOOG', 'GOPG', 'GOOR', 'GOOF', 'WOOG', 'FOOG', 'GOOL', 'GOOU', 'GOOH', 'GFOG', 'GOOX', 'GOJG', 'VOOG', 'GUOG', 'QOOG', 'KOOG', 'GSOG']
# Grupo 25: ['DOCU', 'DOCG', 'DPCU', 'BOCU', 'FOCU', 'DUCU', 'DMCU', 'DOKU', 'AOCU', 'DOCH', 'DOCS', 'DORU', 'DOCZ', 'DRCU', 'DTCU', 'SOCU', 'DOCK', 'DOCR', 'COCU', 'VOCU', 'DONU', 'DLCU', 'DOQU', 'LOCU', 'DOCV', 'XOCU', 'MOCU', 'KOCU', 'DOCM', 'DOUU', 'DOCP', 'DSCU', 'DYCU', 'YOCU', 'NOCU', 'UOCU', 'DOCE', 'DXCU', 'HOCU', 'DVCU', 'EOCU', 'DOCT', 'DOXU', 'TOCU', 'DOVU', 'DOCX', 'ROCU', 'QOCU', 'DOFU', 'DOCA', 'DOMU', 'DOIU', 'GOCU', 'DGCU', 'DOCC', 'DODU', 'DOTU', 'DOOU', 'DOCJ', 'DDCU', 'DOJU', 'DOAU', 'DOCY', 'DWCU', 'DHCU', 'DOHU', 'JOCU', 'DJCU', 'DACU', 'DOLU', 'IOCU', 'DOCO', 'POCU', 'DOWU', 'DOPU', 'DKCU', 'DBCU', 'WOCU', 'ZOCU', 'DOCQ', 'DCCU', 'DOCF', 'DOCN', 'DECU', 'DFCU', 'DOYU', 'DOCD', 'DOCB', 'DOEU', 'DOSU', 'DICU', 'DOCW', 'OOCU', 'DOCI', 'DNCU', 'DZCU', 'DOCL']
# Grupo 26: ['NFLX', 'NLLX', 'NFLJ', 'NFHX', 'RFLX', 'NFWX', 'KFLX', 'NFLW', 'NFLS', 'NFLH', 'MFLX', 'NQLX', 'NYLX', 'HFLX', 'NFLO', 'NDLX', 'NFAX', 'NULX', 'NBLX', 'JFLX', 'NFLA', 'AFLX', 'NALX', 'NFSX', 'NFLI', 'NFLL', 'NFQX', 'EFLX', 'NRLX', 'NELX', 'NFLD', 'NKLX', 'NFYX', 'VFLX', 'NFLY', 'CFLX', 'NFLC', 'YFLX', 'PFLX', 'SFLX', 'NFCX', 'NMLX', 'NFMX', 'NFBX', 'NFZX', 'NFLB', 'NFXX', 'NFJX', 'NPLX', 'GFLX', 'NFNX', 'NFTX', 'BFLX', 'NCLX', 'NXLX', 'NFIX', 'NFLN', 'NFLF', 'NFLR', 'NNLX', 'NFDX', 'NFGX', 'NFEX', 'IFLX', 'QFLX', 'ZFLX', 'NJLX', 'NFKX', 'NTLX', 'NFUX', 'NFLG', 'NFLK', 'NFLV', 'NGLX', 'OFLX', 'NFOX', 'NFPX', 'NSLX', 'NFLQ', 'NFLT', 'NHLX', 'DFLX', 'NVLX', 'NZLX', 'NWLX', 'XFLX', 'NFLZ', 'NFRX', 'UFLX', 'NOLX', 'LFLX', 'FFLX', 'NILX', 'TFLX', 'NFVX', 'NFLP', 'NFLU', 'NFLE', 'WFLX']
# Grupo 27: ['CRM', 'SRM', 'CRN', 'CQM', 'CRQ', 'CRX', 'CHM', 'CRG', 'CRA', 'CDM', 'DRM', 'CRO', 'URM', 'TRM', 'ORM', 'CRE', 'CRJ', 'YRM', 'LRM', 'CGM', 'CTM', 'CRP', 'CRB', 'PRM', 'CEM', 'CMM', 'WRM', 'XRM', 'JRM', 'GRM', 'NRM', 'COM', 'CRK', 'CRT', 'CRS', 'CNM', 'CXM', 'CCM', 'RRM', 'CRW', 'CRD', 'MRM', 'CJM', 'CWM', 'CRC', 'CRH', 'ERM', 'CRU', 'CRL', 'CRF', 'HRM', 'CPM', 'KRM', 'CSM', 'CRV', 'CRI', 'CRR', 'CKM', 'QRM', 'CRZ', 'CRY', 'CLM', 'CYM', 'FRM', 'CUM', 'CFM', 'ZRM', 'CZM', 'ARM', 'CAM', 'BRM', 'CVM']
# Grupo 28: ['AMZN', 'BMZN', 'AMZB', 'AFZN', 'AMZP', 'WMZN', 'NMZN', 'AMUN', 'UMZN', 'AMLN', 'AHZN', 'AMZL', 'LMZN', 'KMZN', 'AMZG', 'AGZN', 'AMEN', 'GMZN', 'ALZN', 'AAZN', 'AMPN', 'TMZN', 'AQZN', 'AMZH', 'AMKN', 'AZZN', 'HMZN', 'AMRN', 'AMCN', 'RMZN', 'AMZA', 'AMZE', 'AMVN', 'DMZN', 'AMZQ', 'QMZN', 'AMZY', 'AMFN', 'VMZN', 'AMIN', 'FMZN', 'AMZF', 'ARZN', 'AMMN', 'AMZS', 'AMZK', 'AMON', 'AVZN', 'AMWN', 'AUZN', 'AMGN', 'AMAN', 'PMZN', 'ADZN', 'AMBN', 'ACZN', 'AMZT', 'AIZN', 'ABZN', 'AMZW', 'AMYN', 'AMZJ', 'AMZV', 'AYZN', 'AMZU', 'AMJN', 'SMZN', 'AMZC', 'AJZN', 'AMTN', 'IMZN', 'AMXN', 'AMZR', 'EMZN', 'AMHN', 'AMZZ', 'APZN', 'MMZN', 'AKZN', 'AWZN', 'CMZN', 'AMZO', 'ANZN', 'ATZN', 'YMZN', 'AMSN', 'AMQN', 'AMNN', 'AMZX', 'AOZN', 'JMZN', 'OMZN', 'AMZM', 'ZMZN', 'AMDN', 'AMZD']
# Grupo 29: ['UBER', 'UBJR', 'UBEF', 'UKER', 'UBEP', 'UBEQ', 'GBER', 'OBER', 'TBER', 'IBER', 'UZER', 'UBQR', 'UBKR', 'UBED', 'MBER', 'UBVR', 'UBFR', 'UBNR', 'UGER', 'UBEI', 'UBES', 'LBER', 'UYER', 'UBET', 'UBEK', 'SBER', 'UBEY', 'UIER', 'FBER', 'UBZR', 'RBER', 'UQER', 'UAER', 'UBEB', 'UBPR', 'UFER', 'UBEX', 'ULER', 'UBMR', 'UBEH', 'UBBR', 'JBER', 'USER', 'UEER', 'UVER', 'ZBER', 'KBER', 'QBER', 'UPER', 'UBWR', 'UBEW', 'UBEV', 'UUER', 'UMER', 'UCER', 'UBEJ', 'UWER', 'UBHR', 'UBDR', 'UBEE', 'UBEZ', 'UBEA', 'YBER', 'UOER', 'UDER', 'NBER', 'UBEN', 'URER', 'UBEG', 'UBEM', 'UBEU', 'UNER', 'UBGR', 'UBRR', 'UBOR', 'WBER', 'VBER', 'HBER', 'XBER', 'UBLR', 'UHER', 'UBEL', 'UBCR', 'UXER', 'UBEC', 'UBSR', 'UBEO', 'UTER', 'PBER', 'UJER', 'EBER', 'UBTR', 'BBER', 'UBAR', 'UBUR', 'DBER', 'ABER']
# Grupo 30: ['IXTU', 'IZTU', 'ICTU', 'ISTU', 'IFTU', 'INXU', 'IATU', 'IGTU', 'IBTU', 'IVTU', 'ITTU', 'IUTU', 'IQTU', 'XNTU', 'IJTU', 'IMTU', 'ILTU', 'IITU', 'IYTU', 'IRTU', 'IOTU', 'IWTU', 'IDTU', 'IPTU', 'INTU', 'INSU', 'INDU', 'INQU', 'INHU', 'INRU', 'INIU', 'INAU', 'INFU', 'INUU', 'INWU', 'INNU', 'INOU', 'INZU', 'INYU', 'INBU', 'INJU', 'INVU', 'INEU', 'INLU', 'INMU', 'INGU', 'INPU', 'INKU', 'MNTU', 'JNTU', 'HNTU', 'LNTU', 'FNTU', 'BNTU', 'PNTU', 'ANTU', 'TNTU', 'ENTU', 'KNTU', 'GNTU', 'DNTU', 'QNTU', 'RNTU', 'WNTU', 'ZNTU', 'YNTU', 'ONTU', 'UNTU', 'NNTU', 'VNTU', 'CNTU', 'INSU']

# %% [markdown]
# -> Agora que temos os grupos separados, iremos pegar os nomes corretos das empresas, o que servirá para realizarmos a correção de modo automático.

# %%
#Nessa etapa do código, estamos colocando em um vetor as siglas corretas, as quais serão utéis para substituição das siglas erradas mais a frente
nomes_empresas = variacoes_siglas['variacao']
nomes_corretos_empresas = []

for i in range(30):
    nome = nomes_empresas[i]

    nomes_corretos_empresas.append(nome)

nomes_corretos_empresas.remove('INTU')
nomes_corretos_empresas.append('INTU')
print(nomes_corretos_empresas)
# Out:
# ['ZM', 'SQ', 'PYPL', 'SHOP', 'META', 'BABA', 'SNAP', 'WORK', 'AMD', 'CSCO', 'ORCL', 'AAPL', 'INTC', 'TSLA', 'NVDA', 'LYFT', 'IBM', 'SPOT', 'VMW', 'ADBE', 'TWTR', 'PINS', 'MSFT', 'GOOG', 'DOCU', 'NFLX', 'CRM', 'AMZN', 'UBER', 'INTU']

# %% [markdown]
# -> Agora, basta rodarmos o algoritmo abaixo e todas as siglas serão corrigidas

# %%
def padronizar_siglas_por_grupo(df, coluna, nomes_corretos, grupos):

    mapa = {}
    for sigla_correta, grupo in zip(nomes_corretos, grupos):
        for variacao in grupo:
            mapa[variacao] = sigla_correta

    df[coluna] = df[coluna].map(mapa).fillna(df[coluna])
    return df

# %%
base1_tempp = padronizar_siglas_por_grupo(base_tmp1, 'Ticker', nomes_corretos_empresas, grupos_siglas)

variacoes_siglas = base_tmp1['Ticker'].value_counts().reset_index()
variacoes_siglas.columns = ['variacao', 'frequencia']
print(variacoes_siglas)
# Out:
#    variacao  frequencia
# 0      PYPL        6805
# 1      SHOP        6784
# 2      BABA        6775
# 3      META        6767
# 4        ZM        6747
# 5      INTC        6742
# 6      SNAP        6731
# 7      WORK        6728
# 8       AMD        6718
# 9      CSCO        6715
# 10       SQ        6694
# 11     AAPL        6693
# 12      IBM        6688
# 13     ORCL        6681
# 14     TSLA        6679
# 15     NVDA        6667
# 16     SPOT        6666
# 17     LYFT        6661
# 18     ADBE        6643
# 19     PINS        6635
# 20     TWTR        6635
# 21      VMW        6624
# 22     GOOG        6605
# 23     NFLX        6605
# 24     MSFT        6599
# 25      CRM        6593
# 26     DOCU        6592
# 27     AMZN        6564
# 28     INTU        6517
# 29     UBER        6447

# %% [markdown]
# -> Podemos notar que agora em nosso dataset só há 30 siglas, o que corresponde exatamente a nosso quantitativo de empresas, facilitando extrair insights de cada empresa.

# %% [markdown]
# ---
# #### **Tratamento da coluna Volume**

# %% [markdown]
# -> Aqui faremos a padronização da coluna volume. Ao analisarmos, notamos as seguintes distinções:
#
#  * Números terminando com letras/palavras (M, B, K, b, Billion)
#  * Números com "," como separador decimal
#
#
#  -> Logo, padronizaremos para que fiquem apenas os valores e convertê-los, de modo a facilitar a extração de insights mais na frente.

# %%
base_tmp1['Volume'] = base_tmp1['Volume'].str.replace(',','') #Tirando a vírgula como separador decimal para facilitar a conversão para número mais a frente
base_tmp1['Volume'].head()
# Out:
# 0    8846040350
# 1    7346935699
# 2    8027589419
# 3       1939.5M
# 4    8984007687
# Name: Volume, dtype: object

# %% [markdown]
# -> Logo de cara, conseguimos notar que há letras acompanhando os números, o que nos sugere uma possível multiplicação para que possamos padronizar essa coluna. Com isso em mente, vamos analisar todos os sufixos presentes na tabela

# %%
def extrair_sufixos_unicos(coluna):
    sufixos = set()

    for valor in coluna.dropna():
        # Extrai a parte não numérica (sufixo) após os números e pontos
        match = re.findall(r'(?:\d+\.?\d*\s*)([a-zA-Z]+)', str(valor))
        sufixos.update([m.strip() for m in match])

    return sorted(sufixos)

sufixos_volume = extrair_sufixos_unicos(base_tmp1['Volume'])
print(sufixos_volume)
# Out:
# ['Billion', 'K', 'M', 'MK', 'Mb', 'b']

# %% [markdown]
# -> Podemos notar a quantidade de sufixos distintos, entretanto, ao dar uma analisada visual na tabela, notamos que nem sempre essa multiplicação deve ocorrer, uma vez que algumas multiplicações acabaria nos retornando resultados que destoam do normal dessa coluna. Vejamos:

# %%
def contar_tamanhos_inteiros_com_sufixo(coluna):

    resultados = set()

    for valor in coluna.dropna():
        # Ex: '123M', '4.5B', '100 K', '8 billion'
        matches = re.findall(r'(\d+)(?:\.\d+)?\s*([a-zA-Z]+)', str(valor))
        for numero, sufixo in matches:
            resultados.add((len(numero), sufixo))

    return resultados

contar_tamanhos_inteiros_com_sufixo(base_tmp1['Volume'])
# Out:
# {(1, 'M'),
#  (2, 'M'),
#  (2, 'MK'),
#  (2, 'Mb'),
#  (3, 'M'),
#  (3, 'MK'),
#  (3, 'Mb'),
#  (4, 'M'),
#  (4, 'MK'),
#  (4, 'Mb'),
#  (7, 'Billion'),
#  (7, 'b'),
#  (8, 'Billion'),
#  (8, 'K'),
#  (8, 'b'),
#  (9, 'Billion'),
#  (9, 'K'),
#  (9, 'b'),
#  (10, 'Billion'),
#  (10, 'K'),
#  (10, 'b')}

# %% [markdown]
# -> Essa função nos retorna as variações que encontramos na coluna de números inteiro e os sufixos que as acompanham.
#
# -> Podemos notar que algumas multiplicações iriam extrapolar o número de dígitos médios (que é 10), então faremos uma verificação do sufixo e o resultado da multiplicação de acordo com o sufixo, se não extrapolar o número médio de dígitos.
#
# -> Em outros casos, basta a remoção do sufixo para ficar no padrão desejado, além da conversão de float. Utilizaremos a função abaixo, que fará isso tudo:

# %%
def converter_volume(base, coluna):
    multiplicadores = {
        'K': 1_000,
        'M': 1000_000,
        'B': 1000_000_000,
        'b': 1000_000_000,
        'billion': 1000_000_000,
        'MK': 1000_000,
        'Mb': 1000_000
    }

    def aplica(valor):
        match = re.search(r'(\d+(?:\.\d+)?)\s*([a-zA-Z]+)', str(valor))
        if match:
            numero = float(match.group(1))
            sufixo = match.group(2)
            fator = multiplicadores.get(sufixo, 1)
            res_mult = numero * fator
            if numero >=1e7 or res_mult > 1e10:
                return int(numero)
            else:
                return int(res_mult)
        else:
            return int(valor)

    base[coluna] = base[coluna].apply(aplica)
    return base

# %%
base_tmp1 = converter_volume(base_tmp1, 'Volume') #Realizando a correção da coluna volume

# %% [markdown]
# -> Agora, iremos realizar o teste para ver se os sufixos sumiram

# %%
teste = extrair_sufixos_unicos(base_tmp1['Volume'])
print(teste)
# Out:
# []

# %% [markdown]
# -> Não há mais sufixos nessa coluna, agora iremos realizar a contagem de quantos números de quantos dígitos existem nessa coluna

# %%
from collections import Counter

def contar_inteiros_por_digitos(lista):

    contador = Counter()

    for item in lista:
        if isinstance(item, int):
            num_digitos = len(str(item))
            contador[num_digitos] += 1

    return dict(contador)

contador = contar_inteiros_por_digitos(base_tmp1['Volume'])
print(contador)
# Out:
# {10: 179972, 9: 18050, 7: 196, 8: 1782}

# %% [markdown]
# -> Podemos ver que agora só há números com 7 ou mais dígitos, o que corresponde a realidade de um volume, tornando nossa tabela coerente.

# %% [markdown]
# ---
# #### **Tratamento da coluna Split Ratio**

# %% [markdown]
# ->  Aqui faremos a padronização da coluna Split Ratio, deixando-a padronizada no formato "x:y", onde x e y são números inteiros. Demos uma varrida visualmente nos dados e percebemos que as principais diferenças em relação a padronização foram:
#
# - Uso de "/" e outros caracteres para separação
# - Letras no lugar de números
# - Muitos dados nulos
#
# -> Assim, discutimos que a padronização de dados nulos e com letras no lugar de números será feita substituindo-os pelo valor modal de split ratio do respectivo Ticker de cada um
#
# -> Primeiramente, padronizaremos apenas os valores com caracter separando os números

# %%
# função para a padronização
def padronizar_split_ratio(valor):
    valor_str = str(valor).strip()

    # verifica se há dois números separados por caractere
    if re.match(r'^\d+[^\d]\d+$', valor_str):
        novo_valor = re.sub(r'(?<=\d)[^\d](?=\d)', ':', valor_str)
        # conta como alteração só se o valor mudou
        if novo_valor != valor_str:
            return novo_valor, True
    return valor_str, False


# inicializa contador
contador_alteracoes = 0

# lista que armazena os novos valores
novos_valores = []

for valor in base_tmp1['Split Ratio']:
    novo_valor, alterado = padronizar_split_ratio(valor)
    novos_valores.append(novo_valor)
    if alterado:
        contador_alteracoes += 1

# atualização da coluna
base_tmp1['Split Ratio'] = novos_valores

print(f'Número de valores corrigidos na coluna "Split Ratio": {contador_alteracoes}')
# Out:
# Número de valores corrigidos na coluna "Split Ratio": 2592

# %% [markdown]
# ---
#
# -> Agora, substituiremos os valores nulos e com letras no lugar de números pelo valor modal de split ratio do respectivo Ticker de cada um

# %%
# função que verifica se o valor está no padrão "int:int"
def split_ratio_valido(valor):
    if pd.isnull(valor):
        return False
    return bool(re.match(r'^\d+:\d+$', str(valor).strip()))

# função que calcula moda válida do split ratio por Ticker
moda_por_ticker = (
    base_tmp1[base_tmp1['Split Ratio'].apply(split_ratio_valido)]
    .groupby('Ticker')['Split Ratio']
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
)

# função que substitui valores inválidos ou nulos pela moda do ticker
def substituir_split_ratio(row):
    valor = row['Split Ratio']
    if not split_ratio_valido(valor):
        return moda_por_ticker.get(row['Ticker'], valor)
    return valor

# contagem das substituições
split_ratio_antes = base_tmp1['Split Ratio'].copy()
base_tmp1['Split Ratio'] = base_tmp1.apply(substituir_split_ratio, axis=1)
substituicoes = (split_ratio_antes != base_tmp1['Split Ratio']).sum()

print(f"Número de substituições feitas na coluna 'Split Ratio': {substituicoes}")
# Out:
# Número de substituições feitas na coluna 'Split Ratio': 54848

# %% [markdown]
# ---
#
# -> Agora, verificaremos se ainda há dados não padronizados nessa coluna

# %%
# Função para verificar se o valor está no formato correto
def formato_split_ratio_invalido(valor):
    if pd.isnull(valor):
        return True  # Nulos são considerados inválidos
    return not bool(re.match(r'^\d+:\d+$', str(valor).strip()))

# Aplica a função para identificar os inválidos
filtro_invalidos = base_tmp1['Split Ratio'].apply(formato_split_ratio_invalido)

# Conta quantos são inválidos
quantidade_invalidos = filtro_invalidos.sum()

# Lista os valores inválidos únicos e suas ocorrências
valores_invalidos = base_tmp1.loc[filtro_invalidos, 'Split Ratio'].value_counts(dropna=False)

# Exibe os resultados
print(f"Quantidade de valores fora do padrão x:y: {quantidade_invalidos}\n")
print("Valores inválidos encontrados:")
print(valores_invalidos)
# Out:
# Quantidade de valores fora do padrão x:y: 0
#
# Valores inválidos encontrados:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ---
#
# -> Assim, podemos copiar todas as modificações realizadas na base temporária para a original

# %%
base1 = base_tmp1.copy()

# %% [markdown]
# #### **Visualização final da padronização e limpeza da Base 1**

# %%
base1.head()
# Out:
#    ID       Date Ticker    Open     High     Low   Close  Adj Close  \
# 0   1 2023-09-03   META  909.63  1380.05  258.44  595.86      61.54
# 1   2 2024-08-28   NVDA  678.96   725.03  185.51  295.83     843.78
# 2   3 2022-05-10   INTU  831.86  1348.94  215.00  874.05     336.19
# 3   4 2017-12-26   NVDA  508.65  1111.85  186.39  511.49     952.63
# 4   5 2022-01-20   WORK  692.20  1425.94  340.75  378.58    1493.44
#
#        Volume  Dividend Split Ratio
# 0  8846040350      3.57         1:1
# 1  7346935699      2.85         3:2
# 2  8027589419      2.28         2:1
# 3  1939500000      4.51         3:2
# 4  8984007687      1.93         3:2

# %% [markdown]
# ---
# ### **Base stock_part2**

# %% [markdown]
# #### **Análise de dados faltantes**

# %% [markdown]
# -> Primeiro vamos verificar se existem valores nulos na nossa base

# %%
null_counts = base2.isnull().sum()

print(null_counts)

columns_with_nulls = null_counts[null_counts > 0]
print(columns_with_nulls)
# Out:
# ID                0
# Sector            0
# Industry          0
# Exchange          0
# Currency          0
# MarketCap         0
# PE Ratio          0
# EPS               0
# Next Earnings     0
# Previous Close    0
# Day Range         0
# dtype: int64
# Series([], dtype: int64)

# %% [markdown]
# -> Como a base 2 não possui nenhum valor nulo aparente, vamos continuar com o tratamento das colunas
#
# ---

# %% [markdown]
# #### **Análises de linhas duplicadas**

# %%
# Retorna o número de linhas duplicadas
base2.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# -> Notamos que não haverá preocupação em excluir linhas duplicadas
#
# ---

# %% [markdown]
# #### **Funções generalizadas para facilitar o tratamento das colunas**

# %% [markdown]
# ##### **Verifica_Categorias_Base:**
#
# -> Essa função foi criada com um intuito bem interessante, a ideia dela era usar a biblioteca thefuzz para poder agrupar e juntar possiveis palavras que estavam na mesma categoria, porem estavam com gramatica errada, exemplo: Healthcare e realtcare
#
# -> Com isso, ela foi usada tanto na 1 quanto na 2 base, conseguindo nos dar um guia nas colunas em que valores estariamos tratando, evitando se perder nos erros gramaticais
#
# -> Esses grupos foram usados de diferentes formas, mas a ideia era apenas que ela conseguisse gerar um caminho de nomes a se seguir, evitando que usassemos palavras que não existiam nas colunas

# %%
def Verifica_Categorias_base(dataframe, categoria):

  if categoria not in dataframe.columns:
        print(f"Erro: a categoria '{categoria}' não foi encontrada no DataFrame.")
        return

  valores = dataframe[categoria].dropna().astype(str).str.strip().unique().tolist()#Aqui estou pegando todos  os nomes da lista Sector
  grupos = []

  while valores:
      base = valores.pop(0)
      grupo = [base]
      similares = []

      for v in valores:
          if fuzz.ratio(base, v) >= 60:#Pega apenas os valores mais proxios para comparação
              grupo.append(v)
              similares.append(v)

      # Remove os que já foram agrupados
      valores = [v for v in valores if v not in similares]
      grupos.append(grupo)

  # Exibe os grupos
  for i, grupo in enumerate(grupos, 1):
      print(f"Grupo {i}: {grupo}")

# %% [markdown]
# -> Essa função é um complemento da função de cima, ela tambem usa thefuzz mas ela ja aplica as mudanças das categorias, tais categorias precisam ser dadas pelo usuario por meio de categorias_corrertas
#
# -> Categorias_corretas é uma lista que, de forma manual, é feita com os nomes que vieram da função Verifica_Categorias_base e foram analisadas por nos

# %%
def corrigir_coluna_categoria(dataframe, coluna, categorias_corretas, limite_score=80):
    if coluna not in dataframe.columns:#tratamento de erro
        print(f"Erro: a coluna '{coluna}' não existe no DataFrame.")
        return dataframe  # retorna sem alteração

    def corrigir(valor):#utiliza a biblioteca thefuzz para poder categorizar os valores em proximidade
        valor = str(valor).lower().strip()
        correspondencia, score = process.extractOne(valor, categorias_corretas)
        return correspondencia if score >= limite_score else valor

    dataframe[coluna] = dataframe[coluna].apply(corrigir)#Aqui é onde acontece a aplicação do tratamento propriamente dito, aplicando o algoritmo
    return dataframe

# %% [markdown]
# -> encontrar_simbolos e extrair_sufixos_unicos tem ideias parecidas, ambas tentam procurar nas colunas valores que são diferentes de inteiros paara assim termos uma ideia do que tratar em colunas como a MarketCap que tinha inteiros misturado com string e apenas estavamos precisando de inteiros
#
# -> A diferença é sutil, encontrar_simbolos pega qualquer coisa diferente de um inteiro.
# Já encontrar_simbolos vai atras de Letras que podem estar misturadas a coluna

# %%
def encontrar_simbolos(df, coluna):
    if coluna not in df.columns:
        print(f"Coluna '{coluna}' não encontrada.")
        return set()

    simbolos = set()
    valores = df[coluna].dropna().astype(str)

    for valor in valores:
        encontrados = re.findall(r'[^0-9\s]', valor)  # tudo que não for número nem espaço
        simbolos.update(encontrados)

    return simbolos

# %%
def extrair_sufixos_unicos(coluna):
    sufixos = set()

    for valor in coluna.dropna():
        # Extrai a parte não numérica (sufixo) após os números e pontos
        match = re.findall(r'(?:\d+\.?\d*\s*)([a-zA-Z]+)', str(valor))
        sufixos.update([m.strip() for m in match])

    return sorted(sufixos)

# %% [markdown]
# -> A função converter_market_cap apesar de contra intuitivo, não trata apenas MarketCap, como trata a Volume da base 1. A ideia dela é que os valores M, K, B etc.. que são encontrados por meio da extrair_sufixos_unicos tenham valores agregados
#
# -> Com esses valores o nosso papel foi então fazer uma logica que consiga manter o padrao de tamanho dos inteiros da MarketCap(13 inteiros) e Volume(10 inteiros)
#
# -> Desssa forma a função pega todos os valores da coluna e verifica se eles ja estao na zona ideal de tamanho.
# - Caso nao estejam eles são mutiplicados pelo sufixo
# - Apos a multiplicação é verificado se eles extrapolaram a zona ideal, estão na zona ideal ou a baixo
# - Se estrapolou, fica com o valor antigo
# - Se esta na zona ideala ou a baixo, fica com o valor multiplicado

# %%
def converter_market_cap(base, coluna):
    multiplicadores = {
        'K': 1000,
        'M': 1000000,
        'B': 1000000000,
        'b': 1000000000,
        'billion': 1000000000,
        'MK': 1000000,
        'Mb': 1000000
    }

    def aplica(valor):
        match = re.search(r'(\d+(?:\.\d+)?)\s*([a-zA-Z]+)', str(valor))
        if match:
            numero = float(match.group(1))
            sufixo = match.group(2)
            fator = multiplicadores.get(sufixo, 1)
            res_mult = numero * fator
            if numero >=1e10 or res_mult >= 1e10:
                return int(numero)
            else:
                return int(res_mult)
        else:
            return int(valor)

    base[coluna] = base[coluna].apply(aplica)
    return base

# %% [markdown]
# ---
# #### **Tratamento da coluna Sector e Industry**

# %% [markdown]
# ---
#
# -> Para essas colunas, percebemos que ao fazer o alinhamento do ID da base 1 com o ID da base 2, o Sector e Industry do Ticker correspondente estava inconsistente na grande maioria das linhas. Para correção disso, realizamos uma pesquisa de cada Ticker presente na base 1 e descrevemos seu Sector e Industry:

# %% [markdown]
# 1. Meta Platforms (META)
#
#    * Sector: Comunicação
#    * Industry: Mídia e Serviços Interativos
#
# 2. NVIDIA Corporation (NVDA)
#
#    * Sector: Tecnologia
#    * Industry: Semicondutores
#
# 3. Intuit Inc. (INTU)
#
#    * Sector: Tecnologia
#    * Industry: Software – Aplicativos
#
# 4. Slack Technologies (WORK)
#
#    * Sector: Tecnologia
#    * Industry: Software – Aplicativos
#
# 5. Alphabet Inc. (GOOG)
#
#    * Sector: Comunicação
#    * Industry: Serviços de Internet
#
# 6. Tesla Inc. (TSLA)
#
#    * Sector: Consumo Cíclico
#    * Industry: Veículos Automotores
#
# 7. Netflix Inc. (NFLX)
#
#    * Sector: Comunicação
#    * Industry: Entretenimento
#
# 8. Adobe Inc. (ADBE)
#
#    * Sector: Tecnologia
#    * Industry: Software – Aplicativos
#
# 9. PayPal Holdings Inc. (PYPL)
#
#    * Sector: Tecnologia
#    * Industry: Serviços de Pagamento
#
# 10. Uber Technologies Inc. (UBER)
#
#     * Sector: Serviços
#     * Industry: Serviços Profissionais
#
# 11. Snap Inc. (SNAP)
#
#     * Sector: Comunicação
#     * Industry: Mídia e Serviços Interativos
#
# 12. Amazon.com Inc. (AMZN)
#
#     * Sector: Consumo Cíclico
#     * Industry: Varejo de Internet
#
# 13. Oracle Corporation (ORCL)
#
#     * Sector: Tecnologia
#     * Industry: Software – Infraestrutura
#
# 14. Advanced Micro Devices Inc. (AMD)
#
#     * Sector: Tecnologia
#     * Industry: Semicondutores
#
# 15. Salesforce Inc. (CRM)
#
#     * Sector: Tecnologia
#     * Industry: Software – Aplicativos
#
# 16. Pinterest Inc. (PINS)
#
#     * Sector: Comunicação
#     * Industry: Mídia e Serviços Interativos
#
# 17. Shopify Inc. (SHOP)
#
#     * Sector: Tecnologia
#     * Industry: Software – Aplicativos
#
# 18. Block Inc. (SQ)
#
#     * Sector: Tecnologia
#     * Industry: Serviços de Pagamento
#
# 19. Intel Corporation (INTC)
#
#     * Sector: Tecnologia
#     * Industry: Semicondutores
#
# 20. Alibaba Group Holding Ltd. (BABA)
#
#     * Sector: Consumo Cíclico
#     * Industry: Varejo de Internet
#
# 21. Microsoft Corporation (MSFT)
#
#     * Sector: Tecnologia
#     * Industry: Software – Infraestrutura
#
# 22. Apple Inc. (AAPL)
#
#     * Sector: Tecnologia
#     * Industry: Hardware de Computador
#
# 23. Zoom Video Communications Inc. (ZM)
#
#     * Sector: Tecnologia
#     * Industry: Software – Aplicativos
#
# 24. Spotify Technology S.A. (SPOT)
#
#     * Sector: Comunicação
#     * Industry: Entretenimento
#
# 25. Lyft Inc. (LYFT)
#
#     * Sector: Serviços
#     * Industry: Serviços Profissionais
#
# 26. International Business Machines Corporation (IBM)
#
#     * Sector: Tecnologia
#     * Industry: Serviços de TI
#
# 27. Twitter Inc. (TWTR)
#
#     * Sector: Comunicação
#     * Industry: Mídia e Serviços Interativos
#
# 28. VMware Inc. (VMW)
#
#     * Sector: Tecnologia
#     * Industry: Software – Infraestrutura
#
# 29. DocuSign Inc. (DOCU)
#
#     * Sector: Tecnologia
#     * Industry: Software – Aplicativos
#
# 30. Cisco Systems Inc. (CSCO)
#
#     * Sector: Tecnologia
#     * Industry: Equipamentos de Comunicação
#
# ---

# %% [markdown]
# -> Baseado nisso, realizaremos uma limpeza das bases Sector e Industry da base2 e adicionaremos as mesmas colunas com dos dados corrigidos na base1 em relação ao ticker da base 1 correspondente

# %%
# dicionário com setor e indústria corretos por yicker
referencia_ticker = {
    'META':   {'Sector': 'Communication', 'Industry': 'Media & Interactive Services'},
    'NVDA':   {'Sector': 'Technology', 'Industry': 'Semiconductors'},
    'INTU':   {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'WORK':   {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'GOOG':   {'Sector': 'Communication', 'Industry': 'Internet Services'},
    'TSLA':   {'Sector': 'Consumer Cyclical', 'Industry': 'Auto Manufacturers'},
    'NFLX':   {'Sector': 'Communication', 'Industry': 'Entertainment'},
    'ADBE':   {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'PYPL':   {'Sector': 'Technology', 'Industry': 'Credit Services'},
    'UBER':   {'Sector': 'Services', 'Industry': 'Professional Services'},
    'SNAP':   {'Sector': 'Communication', 'Industry': 'Media & Interactive Services'},
    'AMZN':   {'Sector': 'Consumer Cyclical', 'Industry': 'Internet Retail'},
    'ORCL':   {'Sector': 'Technology', 'Industry': 'Software – Infrastructure'},
    'AMD':    {'Sector': 'Technology', 'Industry': 'Semiconductors'},
    'CRM':    {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'PINS':   {'Sector': 'Communication', 'Industry': 'Media & Interactive Services'},
    'SHOP':   {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'SQ':     {'Sector': 'Technology', 'Industry': 'Credit Services'},
    'INTC':   {'Sector': 'Technology', 'Industry': 'Semiconductors'},
    'BABA':   {'Sector': 'Consumer Cyclical', 'Industry': 'Internet Retail'},
    'MSFT':   {'Sector': 'Technology', 'Industry': 'Software – Infrastructure'},
    'AAPL':   {'Sector': 'Technology', 'Industry': 'Computer Hardware'},
    'ZM':     {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'SPOT':   {'Sector': 'Communication', 'Industry': 'Entertainment'},
    'LYFT':   {'Sector': 'Services', 'Industry': 'Professional Services'},
    'IBM':    {'Sector': 'Technology', 'Industry': 'Information Technology Services'},
    'TWTR':   {'Sector': 'Communication', 'Industry': 'Media & Interactive Services'},
    'VMW':    {'Sector': 'Technology', 'Industry': 'Software – Infrastructure'},
    'DOCU':   {'Sector': 'Technology', 'Industry': 'Software – Application'},
    'CSCO':   {'Sector': 'Technology', 'Industry': 'Communication Equipment'}
}


base_temppp = base1.copy()

base2.drop(columns=['Sector', 'Industry'], errors='ignore', inplace=True)

# Função para recuperar setor e indústria com base no ticker
def obter_sector_industry(ticker):
    if ticker in referencia_ticker:
        return pd.Series([referencia_ticker[ticker]['Sector'], referencia_ticker[ticker]['Industry']])
    else:
        return pd.Series([None, None])  # Caso o ticker não esteja no dicionário

# Aplica a função
base_temppp[['Sector', 'Industry']] = base_temppp['Ticker'].apply(obter_sector_industry)

# Exibe algumas linhas para verificação
base_temppp[['Ticker', 'Sector', 'Industry']].tail()
# Out:
#        Ticker             Sector                   Industry
# 199995   TSLA  Consumer Cyclical         Auto Manufacturers
# 199996    VMW         Technology  Software – Infrastructure
# 199997   AAPL         Technology          Computer Hardware
# 199998   DOCU         Technology     Software – Application
# 199999    CRM         Technology     Software – Application

# %% [markdown]
# ---
#
# -> Agora passaremos essas mudanças para a base original

# %%
base1 = base_temppp.copy()

# %% [markdown]
# ---
# #### **Tratamento da coluna Exchange**

# %% [markdown]
# -> Nessas colunas, o nosso desafio é simples, mas ao mesmo tempo complicado: temos basicamente os grupos que precisamos padronizar.
#
# -> No entanto, eles apresentam erros de ortografia. Para contornar essa situação e padronizar os valores, utilizaremos a biblioteca thefuzz, que permite identificar e agrupar nomes semelhantes com base em similaridade textual.

# %%
# Copia da base2 para garantir integridade da base enquando estou executando o tratamento
base2_temp = base2.copy()

# %%
Verifica_Categorias_base(base2_temp, 'Exchange')
# Out:
# Grupo 1: ['NYSE', 'NYQE', 'NYSZ', 'NFSE', 'NYSC', 'NTSE', 'SYSE', 'NYSA', 'NYFE', 'NYWE', 'NYTE', 'NYSP', 'NHSE', 'NYBE', 'NUSE', 'NYSU', 'NYSF', 'QYSE', 'MYSE', 'EYSE', 'IYSE', 'NYSL', 'NYJE', 'NYKE', 'NYOE', 'NYSD', 'NKSE', 'HYSE', 'NYSK', 'TYSE', 'NDSE', 'NASEAQ', 'NYAE', 'LYSE', 'KYSE', 'CYSE', 'NZSE', 'UYSE', 'NYGE', 'NYUE', 'NQSE', 'NYSJ', 'RYSE', 'NYST', 'NYNE', 'NBSE', 'NYSI', 'NYEE', 'BYSE', 'NVSE', 'NYXE', 'NRSE', 'XYSE', 'NSE', 'NYLE', 'NLSE', 'GYSE', 'NYME', 'YSE', 'NYHE', 'DYSE', 'YYSE', 'NYIE', 'NYZE', 'NCSE', 'NNSE', 'NESE', 'NASE', 'NYSB', 'NYSDAQ', 'NYSM', 'NYSH', 'NWSE', 'NYVE', 'NJSE', 'NYSN', 'NYSX', 'PYSE', 'NYSS', 'NGSE', 'NOSE', 'NYSY', 'AYSE', 'NYSQ', 'FYSE', 'WYSE', 'NYPE', 'NYSR', 'NSSE', 'NYCE', 'NMSE', 'NYRE', 'NYSW', 'NYSV', 'NASDAE', 'ZYSE', 'NASDEQ', 'NYSG', 'NYDE', 'JYSE', 'NYYE', 'NYSO', 'NXSE', 'NISE', 'VYSE', 'NPSE', 'OYSE']
# Grupo 2: ['TSE', 'LSE', 'TSX', 'SSE', 'VSE', 'TSQ', 'ISE', 'SFE', 'SGE', 'QSE', 'TSC', 'GSE', 'TSB', 'HSE', 'USE', 'TBE', 'TSJ', 'OSE', 'SEE', 'BSE', 'TSL', 'DSE', 'SPE', 'ZSE', 'TSO', 'TSG', 'TSW', 'SYE', 'TST', 'TSZ', 'RSE', 'TSD', 'TXE', 'TFE', 'TEX', 'TTE', 'TAE', 'TRE', 'SUE', 'TSS', 'ASE', 'TSH', 'MSE', 'TSK', 'WSE', 'SME', 'TIE', 'TSM', 'TUE', 'TSP', 'TSI', 'SRE', 'TSA', 'SHE', 'SXE', 'KSE', 'TWE', 'ESE', 'TSF', 'TSV', 'TSU', 'SBE', 'CSE', 'TQE', 'LTE', 'JSE', 'TEE', 'TSR', 'SDE', 'FSE', 'SKE', 'TSN', 'TYE', 'PSE', 'SIE', 'TSY', 'TGE', 'TME', 'SWE', 'XSE', 'TPE', 'SCE', 'TVE', 'SQE', 'SZE', 'TKE', 'SNE', 'TJE', 'STE', 'SJE', 'SVE', 'SAE', 'SLE', 'TCE', 'TLE', 'SOE', 'TNE', 'THE', 'TOE', 'TZE', 'TDE']
# Grupo 3: ['HKEX', 'HKRX', 'HFEX', 'HKEA', 'HKEI', 'HKEY', 'HWEX', 'HKEZ', 'HKAX', 'HMEX', 'QKEX', 'RKEX', 'HKBX', 'HOEX', 'HCEX', 'DKEX', 'HKTX', 'KKEX', 'CKEX', 'FKEX', 'HKOX', 'HKEQ', 'WKEX', 'HKED', 'HKUX', 'HKNX', 'ZKEX', 'HKHX', 'HKGX', 'HZEX', 'HKEH', 'HUEX', 'AKEX', 'HKCX', 'HKEP', 'HKEF', 'HQEX', 'HKEG', 'GKEX', 'HSEX', 'KMEX', 'HKJX', 'HKEB', 'HKEK', 'HKSX', 'HREX', 'HKET', 'HKIX', 'HHEX', 'UKEX', 'HKEL', 'XKEX', 'MKEX', 'HKER', 'HKEV', 'HKWX', 'HYEX', 'HKEJ', 'HAEX', 'HKEN', 'VKEX', 'HKZX', 'HKMX', 'HKYX', 'HPEX', 'HKQX', 'SKEX', 'HTEX', 'HEEX', 'HVEX', 'HKDX', 'PKEX', 'HXEX', 'HKKX', 'LKEX', 'HGEX', 'EKEX', 'HKEC', 'HKLX', 'YKEX', 'TKEX', 'AHEX', 'HKES', 'HKEE', 'HKEO', 'HLEX', 'HKVX', 'HKFX', 'NKEX', 'HKEM', 'HDEX', 'JKEX', 'IKEX', 'HKEW', 'BKEX', 'HKXX', 'HNEX', 'HIEX', 'OKEX', 'HBEX', 'HKPX', 'HJEX', 'HKEU']
# Grupo 4: ['NASDAQ', 'NASHAQ', 'NJSDAQ', 'NASNAQ', 'NASDVQ', 'RASDAQ', 'NASDAX', 'DASDAQ', 'CASDAQ', 'NARDAQ', 'NASWAQ', 'NNSDAQ', 'NASMAQ', 'ZASDAQ', 'NASBAQ', 'NAKDAQ', 'FASDAQ', 'NASDAN', 'NTSDAQ', 'NASDMQ', 'NAWDAQ', 'HASDAQ', 'GASDAQ', 'NASDPQ', 'NASDZQ', 'NAJDAQ', 'NAUDAQ', 'NASDAD', 'NAPDAQ', 'NACDAQ', 'VASDAQ', 'NKSDAQ', 'NASDAU', 'PASDAQ', 'NHSDAQ', 'NASKAQ', 'NASDWQ', 'NASDYQ', 'EASDAQ', 'NAIDAQ', 'NDSDAQ', 'NASDAH', 'NASYAQ', 'NASDAP', 'NZSDAQ', 'NADDAQ', 'NASZAQ', 'NMSDAQ', 'NASDUQ', 'NASDCQ', 'OASDAQ', 'NASDSQ', 'NASDAZ', 'NASDAB', 'NASOAQ', 'NASCAQ', 'NASDAW', 'NAQDAQ', 'TASDAQ', 'MASDAQ', 'NASDAS', 'NAMDAQ', 'NASSAQ', 'NASUAQ', 'SASDAQ', 'NAGDAQ', 'NASFAQ', 'NASDIQ', 'NASDJQ', 'NASDAO', 'NASDAY', 'NESDAQ', 'NABDAQ', 'NAEDAQ', 'NASPAQ', 'NASTAQ', 'YASDAQ', 'NAFDAQ', 'NRSDAQ', 'NASGAQ', 'NBSDAQ', 'NANDAQ', 'NASDAF', 'NASLAQ', 'NVSDAQ', 'NASDGQ', 'QASDAQ', 'WASDAQ', 'NQSDAQ', 'NASDAT', 'NASQAQ', 'NAXDAQ', 'BASDAQ', 'NASDDQ', 'NASDAC', 'NASDNQ', 'NASDXQ', 'NASIAQ', 'NAVDAQ', 'NATDAQ', 'NASDRQ', 'NWSDAQ', 'NASDFQ', 'UASDAQ', 'NASJAQ', 'JASDAQ', 'NGSDAQ', 'NSSDAQ', 'NASXAQ', 'NASDOQ', 'NISDAQ', 'NUSDAQ', 'NASDKQ', 'NASDHQ', 'KASDAQ', 'NASDAI', 'NCSDAQ', 'NAHDAQ', 'NASDAJ', 'NOSDAQ', 'NLSDAQ', 'NASDBQ', 'NPSDAQ', 'NALDAQ', 'NAYDAQ', 'NASDAV', 'LASDAQ', 'NAADAQ', 'NASDAA', 'NASDTQ', 'NASRAQ', 'AASDAQ', 'NASDAK', 'NASDQQ', 'NAODAQ', 'NFSDAQ', 'NASDAR', 'XASDAQ', 'NAZDAQ', 'NASDAG', 'NASDAM', 'IASDAQ', 'NASAAQ', 'NASVAQ', 'NXSDAQ', 'NASDLQ', 'NASDAL']
# Grupo 5: ['AMEX', 'AMWX', 'WMEX', 'AMOX', 'AMES', 'AMEB', 'AMHX', 'AMET', 'ALEX', 'AAEX', 'AMED', 'PMEX', 'AMEP', 'AFEX', 'VMEX', 'AMEM', 'ATEX', 'AMEU', 'AMEK', 'ASEX', 'AJEX', 'AMEA', 'AMEE', 'APEX', 'EMEX', 'AQEX', 'TMEX', 'AMZX', 'JMEX', 'AEEX', 'AMXX', 'ANEX', 'AMEN', 'ZMEX', 'AMYX', 'AMFX', 'FMEX', 'QMEX', 'AMBX', 'AMDX', 'BMEX', 'AMEW', 'RMEX', 'ACEX', 'AMCX', 'XMEX', 'AMLX', 'AMEI', 'AMTX', 'ADEX', 'AXEX', 'NMEX', 'OMEX', 'AMEG', 'AMQX', 'AWEX', 'AMEF', 'AMER', 'AMEZ', 'AMNX', 'AMEC', 'AMRX', 'AOEX', 'AMKX', 'AGEX', 'AMMX', 'AMEL', 'AMPX', 'AZEX', 'LMEX', 'AMJX', 'YMEX', 'AMEO', 'AMEJ', 'AMEY', 'AUEX', 'AIEX', 'AYEX', 'AMGX', 'AMSX', 'AREX', 'AMEQ', 'CMEX', 'UMEX', 'AMUX', 'ABEX', 'AMIX', 'SMEX', 'MMEX', 'AVEX', 'DMEX', 'AMVX', 'GMEX', 'AMEH', 'AMAX', 'IMEX', 'AMEV']
# Grupo 6: ['Euronext', 'EuronXxt', 'EuRonext', 'euronext', 'Duronext', 'EuroneWt', 'Luronext', 'EuronQxt', 'EuronexZ', 'eJronext', 'EuAonext', 'EuronexG', 'EurXnext', 'EuronRxt', 'EuroJext', 'EuronUxt', 'EuYonext', 'EEronext', 'EurVnext', 'EurInext', 'EFronext', 'EuronWxt', 'EurZnext', 'EuroMext', 'EuConext', 'EurGnext', 'EuroNext', 'eHronext', 'EuroDext', 'Huronext', 'Ruronext', 'EuronHxt', 'EuroneLt', 'EuBonext', 'EuroEext', 'EuronExt', 'euronexI', 'EuroneAt', 'EuronNxt', 'EuroneJt', 'EBronext', 'EuronVxt', 'Curonext', 'EuronexQ', 'Wuronext', 'EuronCxt', 'EuroLext', 'Puronext', 'Guronext', 'EurWnext', 'EurHnext', 'EuronexD', 'Nuronext', 'EuroneDt', 'Kuronext', 'EDronext', 'euGonext', 'EuronBxt', 'EuronIxt', 'EWronext', 'EuIonext', 'EuronexU', 'EurMnext', 'EMronext', 'eurBnext', 'Uuronext', 'EuroneCt', 'EuroOext', 'Quronext', 'ELronext', 'EuronLxt', 'EuroneRt', 'euronVxt', 'EuUonext', 'EuronexV', 'EuronOxt', 'EuroneSt', 'EuronKxt', 'EuLonext', 'EPronext', 'EuroIext', 'ESronext', 'euronXxt', 'EurNnext', 'EurUnext', 'EuronexA', 'EurKnext', 'EuronZxt', 'ENronext', 'EuroZext', 'euroIext', 'EuronFxt', 'EuFonext', 'Buronext', 'EurQnext', 'EuQonext', 'EuronexF', 'ECronext', 'EXronext', 'EZronext', 'EHronext', 'EuronMxt', 'EuroKext', 'EuroAext', 'EuronexK', 'EYronext', 'EuroHext', 'EuroneFt', 'EuWonext', 'EuMonext', 'euroneFt', 'euroneZt', 'EuroUext', 'EurLnext', 'EuronexS', 'EIronext', 'EuroGext', 'EurRnext', 'Iuronext', 'EuOonext', 'EurTnext', 'euronexJ', 'EuronexN', 'EuronGxt', 'euroUext', 'eurFnext', 'EuDonext', 'Auronext', 'euroEext', 'EuroneEt', 'euronexE', 'EurJnext', 'EuroneVt', 'EuroneUt', 'EuroRext', 'Ouronext', 'EuronDxt', 'EuronexJ', 'eurJnext', 'euronexB', 'EuroPext', 'euroneMt', 'EuroVext', 'euroneNt', 'EurSnext', 'euroNext', 'EuPonext', 'euronexU', 'EuroneZt', 'euroneRt', 'EuroYext', 'euronOxt', 'EuroneQt', 'EuroQext', 'EuroFext', 'EuronexR', 'EuronexL', 'eGronext', 'EuZonext', 'eurHnext', 'euronPxt', 'euroneBt', 'eVronext', 'EuroneBt', 'EuronSxt', 'ETronext', 'EuronexB', 'EuronexO', 'EuKonext', 'EAronext', 'euronBxt', 'EuXonext', 'EGronext', 'EuroWext', 'euroneHt', 'EuroneXt', 'EuVonext', 'EuronexM', 'EurYnext', 'eurAnext', 'EuGonext', 'EuHonext', 'euroMext', 'euroDext', 'EuronePt', 'EurBnext', 'EuroneHt', 'Vuronext', 'EuroCext', 'euroZext', 'EuronJxt', 'EOronext', 'euUonext', 'EuTonext', 'Turonext', 'EuJonext', 'EuroXext', 'EVronext', 'EuEonext', 'EuroneYt', 'EuroneKt', 'EuronexY', 'EuronexI', 'Zuronext', 'Yuronext', 'eurInext', 'EurFnext', 'Furonext', 'Suronext', 'Xuronext', 'euronexY', 'EKronext', 'EuroneMt', 'EJronext', 'EurPnext', 'euronWxt', 'EuroText', 'euroCext', 'EuronexW', 'eurPnext', 'EuSonext', 'eurRnext', 'EuroSext', 'euronePt', 'euronexX', 'euZonext', 'EuronTxt', 'euronexV', 'EurEnext', 'EurCnext', 'EurAnext', 'euronexQ', 'eFronext', 'EuronAxt', 'euroXext', 'euronJxt', 'eEronext', 'EuronexX', 'EuNonext', 'EurDnext', 'EuronYxt', 'EuroneNt', 'EuroBext', 'Muronext', 'eXronext', 'euronexS', 'eBronext', 'eurGnext', 'euroText', 'euroneSt', 'euConext', 'EuronexC', 'euroOext', 'euSonext', 'EuroneGt', 'EuroneOt', 'euronAxt', 'EUronext', 'euMonext', 'EuronexP', 'EQronext', 'EuronPxt', 'eurOnext', 'euroneTt', 'EuroneTt', 'euAonext', 'Juronext', 'euronFxt', 'EuronexH', 'EuronexE', 'euronDxt', 'ERronext', 'euronexR', 'euroWext', 'euQonext', 'euroneVt', 'euronKxt', 'euKonext', 'euJonext', 'eurTnext', 'eNronext', 'EuroneIt', 'EuronexT', 'eUronext', 'euroLext', 'eZronext', 'euronexH', 'euronTxt', 'euroneEt']
# Grupo 7: ['tse', 'sse', 'tsx', 'lse', 'tsE', 'sJe', 'tVe', 'Ose', 'tsF', 'Vse', 'tDe', 'Nse', 'tCe', 'tsM', 'sQe', 'Rse', 'Kse', 'Jse', 'Pse', 'sYe', 'tsH', 'Cse', 'tsG', 'tUe', 'Hse', 'sTe', 'Sse', 'Dse', 'tPe', 'tsO', 'tsQ', 'tYe', 'Tse', 'tsL', 'tsK', 'Xse', 'tIe', 'sMe', 'tsB', 'sAe', 'sOe', 'tsS', 'tQe', 'tsA', 'Ise', 'tsY', 'Lse', 'sGe', 'tZe', 'Wse', 'Zse', 'sCe', 'Bse', 'Yse', 'Gse', 'sUe', 'Qse', 'Mse', 'tsC', 'tsV', 'sNe', 'sHe', 'tAe', 'tsW', 'sIe', 'tsX', 'tEe', 'Ase', 'sPe', 'tsD', 'tGe', 'tHe', 'tsI', 'tRe', 'tWe', 'tMe', 'tTe', 'sKe', 'tsZ', 'Ese', 'tKe', 'Use', 'sWe', 'tsJ', 'sVe', 'sSe', 'tsT', 'tFe', 'sRe', 'tsP', 'sBe', 'tJe']
# Grupo 8: ['hkex', 'hMex', 'hkeO', 'hEex', 'hkYx', 'hkeS', 'hQex', 'hkeL', 'hWex', 'hkEx', 'hkeI', 'hNex', 'Akex', 'hkeD', 'Fkex', 'Xkex', 'hkeB', 'hkeV', 'hkZx', 'Tkex', 'hJex', 'Nkex', 'Mkex', 'hkeT', 'hkeC', 'hkFx', 'hkIx', 'hkWx', 'hkCx', 'hkKx', 'hkeA', 'hCex', 'hPex', 'hKex', 'hkeY', 'hBex', 'hHex', 'hSex', 'hYex', 'hkeK', 'hkPx', 'hLex', 'hkAx', 'hkeG', 'Kkex', 'Vkex', 'Zkex', 'hAex', 'hkQx', 'Ekex', 'Ikex', 'hkNx', 'hkVx', 'hkDx', 'hkSx', 'hFex', 'hkXx', 'hkBx', 'hkOx', 'hkHx', 'hkLx', 'Bkex', 'hkeH', 'hDex', 'hXex', 'hkeR', 'Ykex', 'Dkex', 'Rkex']
# Grupo 9: ['SSN', 'SSB', 'LSN', 'SSI', 'SSL', 'SST', 'SSX', 'SSA', 'LSS', 'SSU', 'SSJ', 'SSO', 'SSF', 'SSV', 'SSD', 'SSH', 'SSC', 'SSW', 'SSK', 'SSR', 'SSS', 'SSG', 'SSM', 'SSP', 'SSY', 'SSQ', 'SSZ']
# Grupo 10: ['nyse', 'nyKe', 'nyFe', 'nysN', 'nysW', 'nWse', 'Oyse', 'nTse', 'Dyse', 'nysK', 'nyBe', 'nyTe', 'nysM', 'Uyse', 'nyDe', 'Qyse', 'Wyse', 'nIse', 'nOse', 'Ayse', 'nysX', 'nysQ', 'nyPe', 'nysR', 'nyXe', 'nysJ', 'Syse', 'nKse', 'nNse', 'nBse', 'Myse', 'nJse', 'Pyse', 'nyQe', 'nyYe', 'nVse', 'nysE', 'Ryse', 'Xyse', 'nDse', 'nLse', 'nyJe', 'nysA', 'nysI', 'nZse', 'nEse', 'nRse', 'nMse', 'Eyse', 'nYse', 'nysB', 'Cyse', 'nyLe', 'Yyse', 'nysL', 'Fyse', 'nysH', 'nysF', 'nyOe', 'nySe', 'nysD', 'nUse', 'nyCe', 'nyVe', 'nysS']
# Grupo 11: ['EURONEXT', 'EURZNEXT', 'EURONEXY', 'EURONEXN', 'EURONEXL', 'EURONYXT', 'EURQNEXT', 'EUROYEXT', 'EUSONEXT', 'EUROHEXT', 'EUROMEXT', 'EURONEPT', 'EBRONEXT', 'EURONHXT', 'EURGNEXT', 'EUROIEXT', 'EMRONEXT', 'EURONEZT', 'EIRONEXT', 'UURONEXT', 'EURRNEXT', 'EUROSEXT', 'EARONEXT', 'PURONEXT', 'EUYONEXT', 'EPRONEXT', 'MURONEXT', 'EURONPXT', 'EURONEXU', 'JURONEXT', 'EURONQXT', 'ESRONEXT', 'EURODEXT', 'EURONKXT', 'EURONOXT', 'EURONAXT', 'EURVNEXT', 'EURONEST', 'EKRONEXT', 'EUBONEXT', 'EDRONEXT', 'ZURONEXT', 'EURONCXT', 'EUROZEXT', 'EZRONEXT', 'BURONEXT', 'EURONEXS', 'EURONENT', 'EURUNEXT', 'EUCONEXT', 'EURJNEXT', 'EQRONEXT', 'TURONEXT', 'EURONEVT', 'EUROWEXT', 'EURXNEXT', 'EURNNEXT', 'EURONEIT', 'EURONEXW', 'EUROPEXT', 'EUWONEXT', 'ELRONEXT', 'EGRONEXT', 'EURONJXT', 'XURONEXT', 'VURONEXT', 'EUROOEXT', 'EURONWXT', 'EUROGEXT', 'EURONEXF', 'EUAONEXT', 'EURONEYT', 'EURONEET', 'FURONEXT', 'EURONEXH', 'EUROJEXT', 'EURONEXX', 'EURFNEXT', 'EUTONEXT', 'EURLNEXT', 'EURONEDT', 'EUROEEXT', 'EURTNEXT', 'EUROCEXT', 'LURONEXT', 'EURONBXT', 'EUZONEXT', 'EURPNEXT', 'EUROFEXT', 'EUUONEXT', 'EUKONEXT', 'EURONEUT']
# Grupo 12: ['nasdaq', 'nasdLq', 'nasdTq', 'nPsdaq', 'nasdXq', 'Jasdaq', 'naRdaq', 'nasdRq', 'nRsdaq', 'nCsdaq', 'nasdaC', 'Fasdaq', 'nasCaq', 'Masdaq', 'nasdNq', 'nasdaR', 'naZdaq', 'nTsdaq', 'Gasdaq', 'nasWaq', 'naJdaq', 'nasdZq', 'nasVaq', 'nDsdaq', 'nasUaq', 'nasdPq', 'nasdaH', 'nasdaE', 'naWdaq', 'nKsdaq', 'Basdaq', 'nEsdaq', 'nasdUq', 'naGdaq', 'naKdaq', 'nasdVq', 'naYdaq', 'naIdaq', 'naMdaq', 'nasdaB', 'nasdBq', 'Zasdaq', 'nOsdaq', 'nasdMq', 'nGsdaq', 'nAsdaq', 'naTdaq', 'nasdaN', 'nasIaq', 'nVsdaq', 'nasGaq', 'nasdaT', 'nasdaO', 'nasdAq', 'nasDaq', 'nasdWq', 'nasdDq', 'nMsdaq', 'nasdaM', 'nasdEq', 'naNdaq']
# Grupo 13: ['amex', 'amQx', 'aSex', 'ameT', 'Gmex', 'ameA', 'aTex', 'ameJ', 'Vmex', 'Kmex', 'aZex', 'ameH', 'Qmex', 'amFx', 'aKex', 'amGx', 'Xmex', 'Cmex', 'ameV', 'amCx', 'amVx', 'Fmex', 'amNx', 'aIex', 'Pmex', 'Wmex', 'ameY', 'ameW', 'Dmex', 'ameC', 'Tmex', 'ameL', 'aXex', 'aMex', 'amWx', 'amUx', 'amYx', 'Bmex', 'aDex', 'amHx', 'amIx', 'ameE', 'ameB', 'ameO', 'Omex', 'amXx', 'ameI', 'ameM', 'Imex', 'aRex', 'ameN', 'ameU', 'Mmex', 'ameP', 'amEx', 'amBx', 'Hmex', 'Umex', 'aAex', 'Jmex', 'aHex', 'amSx', 'Nmex']
# Grupo 14: ['lsV', 'lsK', 'lsT', 'lsJ', 'lsM', 'lsO', 'lsL', 'lsP', 'lsS', 'lsN', 'lsY', 'lVe', 'lsB', 'lsR', 'lsW', 'lsA', 'lsU', 'lsF', 'lsE']
# Grupo 15: ['TAX', 'TIX', 'TNX', 'TFX', 'TKX', 'TLX', 'TOX', 'TZX', 'TDX', 'TWX', 'THX', 'ASX', 'TTX', 'TPX', 'TBX', 'TYX', 'TGX', 'TVX', 'TRX', 'TJX', 'TCX', 'TXX', 'TUX', 'TMX', 'TQX']
# Grupo 16: ['LDE', 'LWE', 'LYE', 'LFE', 'LOE', 'LIE', 'LUE', 'LHE', 'LVE', 'LEE', 'LLE', 'LAE', 'LZE', 'LNE', 'LJE', 'LPE', 'LRE', 'LCE', 'LSD', 'LBE', 'LME', 'LQE', 'LKE', 'LXE', 'LGE']
# Grupo 17: ['ISX', 'ZSX', 'PSX', 'VSX', 'WSX', 'KSX', 'HSX', 'CSX', 'BSX', 'FSX', 'RSX', 'MSX', 'OSX', 'XSX', 'LSX', 'QSX', 'USX', 'YSX', 'JSX', 'ESX', 'NSX', 'GSX', 'DSX']
# Grupo 18: ['LSV', 'LSZ', 'LSR', 'LSC', 'LSF', 'LSP', 'LST', 'LSQ', 'LSK', 'LSH', 'LSG', 'LSW', 'LSU', 'LSI', 'LSL', 'LSA', 'LSM', 'LSB', 'LSY', 'LSO', 'LSJ']
# Grupo 19: ['lJe', 'lWe', 'lTe', 'lHe', 'lPe', 'lOe', 'lQe', 'lGe', 'lBe', 'lSe', 'lNe', 'lFe', 'lDe', 'lLe', 'lMe', 'lCe']
# Grupo 20: ['Vsx', 'Wsx', 'Osx', 'Ssx', 'Asx', 'Gsx', 'Isx', 'Usx', 'Dsx', 'Ysx', 'Rsx', 'Msx', 'Jsx', 'Nsx', 'Zsx', 'Esx', 'Csx', 'Psx', 'Bsx', 'Xsx', 'Hsx', 'Qsx']
# Grupo 21: ['tAx', 'tOx', 'tYx', 'tLx', 'tMx', 'tFx', 'tZx', 'tUx', 'tNx', 'tBx', 'tXx', 'tGx', 'tSx', 'tCx', 'tRx', 'tWx', 'tJx', 'tQx', 'tTx', 'tEx', 'tKx', 'tHx']
# Grupo 22: ['ssX', 'ssB', 'ssS', 'ssK', 'ssQ', 'ssG', 'ssN', 'ssD', 'ssY', 'ssC', 'ssJ', 'ssL', 'ssP', 'ssU']

# %% [markdown]
# -> Aqui corrijimos os problemas de padronização passando tudo para o mesmo formato de texto

# %%
exchange_dicionario = {
    "NYSE": "NYSE",
    "NASDAQ": "NASDAQ",
    "LSE": "LSE",
    "HKEX": "HKEX",
    "TSE": "TSE",
    "EURONEXT": "EURONEXT",
    "TSX": "TSX",
    "SSE": "SSE",
    "SGX": "SGX",
    "ASX": "ASX",
    "AMEX": "AMEX",

    "nyse": "NYSE",
    "nasdaq": "NASDAQ",
    "lse": "LSE",
    "hkex": "HKEX",
    "tse": "TSE",
    "euronext": "EURONEXT",
    "tsx": "TSX",
    "sse": "SSE",
    "sgx": "SGX",
    "asx": "ASX",
    "amex": "AMEX"
}
base2_temp['Exchange'] = base2_temp['Exchange'].str.upper()
base2_temp['Exchange'] = base2_temp['Exchange'].replace(exchange_dicionario)

print(base2_temp['Exchange'].head(10))
# Out:
# 0      NYSE
# 1       TSE
# 2       LSE
# 3      HKEX
# 4    NASDAQ
# 5       TSX
# 6    NASDAQ
# 7       TSX
# 8      AMEX
# 9      AMEX
# Name: Exchange, dtype: object

# %% [markdown]
# -> Criamos uma tabela para que seja possível ver todas as siglas presentes na base e quantas vezes cada uma aparece. Cada sigla principal aparece cerca de 20.000 vezes, já os erros ortográficos possuem frequências consideravelmente menores

# %%
base2_temp['Exchange'] = base2_temp['Exchange'].str.strip()

variacoes_siglas = base2_temp['Exchange'].value_counts().reset_index()
variacoes_siglas.columns = ['variacao', 'frequencia']

#Para que possamos ver todas as siglas e sua frequência
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

print(variacoes_siglas)
# Out:
#      variacao  frequencia
# 0        HKEX       21285
# 1         TSX       21277
# 2         SSE       21270
# 3    EURONEXT       21196
# 4        NYSE       21176
# 5      NASDAQ       21150
# 6        AMEX       21130
# 7         TSE       21047
# 8         LSE       20912
# 9         DSE          51
# 10        YSE          51
# 11        OSE          51
# 12        PSE          49
# 13        NSE          47
# 14        VSE          47
# 15        JSE          47
# 16        GSE          47
# 17        HSE          47
# 18        USE          46
# 19        ASE          45
# 20        ISE          44
# 21        RSE          42
# 22        QSE          42
# 23        BSE          41
# 24        TSO          40
# 25        CSE          40
# 26        TSL          39
# 27        ZSE          39
# 28        WSE          39
# 29        MSE          39
# 30        XSE          39
# 31        TSJ          36
# 32        ESE          36
# 33        KSE          35
# 34        TSM          34
# 35        TSN          34
# 36        TSW          33
# 37        TSI          33
# 38        TSQ          32
# 39        TSK          32
# 40        TSH          31
# 41        TSC          31
# 42        FSE          31
# 43        PSX          31
# 44        LSX          30
# 45        TSB          30
# 46        TSV          29
# 47        TSA          29
# 48        TSZ          27
# 49        TSF          27
# 50       AKEX          27
# 51        TSS          27
# 52        TSG          25
# 53        TSD          25
# 54        TST          25
# 55        TQE          25
# 56        TSY          25
# 57        TSR          25
# 58        SSX          25
# 59        TSP          24
# 60        TUX          23
# 61        CSX          22
# 62        TIE          22
# 63        SUE          22
# 64        LQE          22
# 65        SSV          22
# 66        TSU          21
# 67        TPE          21
# 68        SWE          21
# 69        TVE          21
# 70        TAE          21
# 71        TGX          21
# 72        BSX          20
# 73        SJE          20
# 74        TKX          20
# 75       NLSE          19
# 76        SBE          19
# 77        SHE          19
# 78        SSB          19
# 79       NYQE          19
# 80       HMEX          19
# 81        TLX          19
# 82        LSL          19
# 83        TWE          18
# 84        LOE          18
# 85        SCE          18
# 86       AYSE          18
# 87       SYSE          18
# 88        SNE          18
# 89       AMEU          18
# 90        LHE          18
# 91        LCE          18
# 92        LSU          18
# 93        SSL          18
# 94        TXE          18
# 95        LVE          18
# 96        SKE          17
# 97       AMYX          17
# 98        TEE          17
# 99        SRE          17
# 100       SSN          17
# 101       LSQ          17
# 102      NYSK          17
# 103       TWX          17
# 104      HKEK          17
# 105       TCE          17
# 106      XYSE          17
# 107       TYX          17
# 108       SZE          17
# 109       ESX          17
# 110      NTSE          17
# 111       TBE          17
# 112       TFX          17
# 113       TJX          17
# 114       SSD          17
# 115      NYSM          17
# 116       SSJ          17
# 117      AMVX          17
# 118       ISX          17
# 119       SSO          17
# 120       LSF          16
# 121       SXE          16
# 122       TUE          16
# 123      HKEQ          16
# 124       SGE          16
# 125       LSK          16
# 126       XSX          16
# 127      XKEX          16
# 128      ADEX          16
# 129       LUE          16
# 130       FSX          16
# 131       GSX          16
# 132      AMEH          16
# 133      AMET          16
# 134       USX          16
# 135      HKDX          16
# 136  EUAONEXT          16
# 137      HKEN          16
# 138       TXX          16
# 139       LSZ          16
# 140      HKEB          16
# 141       TEX          16
# 142      VMEX          16
# 143       LPE          15
# 144       TAX          15
# 145      AMAX          15
# 146    NASNAQ          15
# 147      WMEX          15
# 148       SSQ          15
# 149       SSS          15
# 150      NYVE          15
# 151       JSX          15
# 152       SAE          15
# 153       TGE          15
# 154      AMNX          15
# 155      MYSE          15
# 156      HCEX          15
# 157       RSX          15
# 158       TPX          15
# 159      HKEP          15
# 160      HKEF          15
# 161       LSS          15
# 162      HKHX          15
# 163      NKSE          15
# 164      NRSE          15
# 165       LSR          15
# 166      HKJX          15
# 167      HKES          15
# 168    NADDAQ          15
# 169       TVX          15
# 170       LSI          15
# 171       SYE          15
# 172       SPE          15
# 173      HKEC          15
# 174       SSG          15
# 175       TNX          15
# 176      HWEX          15
# 177      AMEY          15
# 178       SFE          14
# 179      NYCE          14
# 180       SSY          14
# 181       LSV          14
# 182       SSM          14
# 183       TMX          14
# 184      AMEL          14
# 185       LSY          14
# 186      HDEX          14
# 187       LSM          14
# 188      MKEX          14
# 189       TZX          14
# 190      NYIE          14
# 191      HKEV          14
# 192      AWEX          14
# 193      AMER          14
# 194       LRE          14
# 195      HKQX          14
# 196      HGEX          14
# 197       LYE          14
# 198  EUROOEXT          14
# 199      QKEX          14
# 200      XMEX          14
# 201       SST          14
# 202       SIE          14
# 203      AMEW          14
# 204      HKYX          14
# 205    NZSDAQ          14
# 206       TDX          14
# 207      NYXE          14
# 208      KMEX          14
# 209       LNE          14
# 210       TFE          14
# 211       LSG          14
# 212      CYSE          14
# 213      HKCX          14
# 214      ANEX          14
# 215       SSF          14
# 216       LSW          14
# 217      HKNX          14
# 218      AMWX          14
# 219      HKED          14
# 220       LSJ          13
# 221      HTEX          13
# 222       SSW          13
# 223      NYSH          13
# 224      NUSE          13
# 225    NASDTQ          13
# 226      AMEO          13
# 227       TKE          13
# 228      AAEX          13
# 229      OMEX          13
# 230       TTX          13
# 231      EMEX          13
# 232       SSK          13
# 233      NYSP          13
# 234      FKEX          13
# 235       HSX          13
# 236      HKEE          13
# 237      HKET          13
# 238       LJE          13
# 239      NYJE          13
# 240       LDE          13
# 241      NQSE          13
# 242      HLEX          13
# 243       LIE          13
# 244      NVSE          13
# 245      NYSL          13
# 246       TBX          13
# 247      JMEX          13
# 248      AMEP          13
# 249      NYSF          13
# 250       TRX          13
# 251      HKGX          13
# 252      HKIX          13
# 253       LME          13
# 254       TJE          13
# 255      AMCX          13
# 256       LTE          13
# 257    NDSDAQ          13
# 258       DSX          13
# 259       LBE          13
# 260       SOE          13
# 261       TTE          13
# 262       VSX          13
# 263      NYSC          13
# 264      AMEB          13
# 265       TIX          13
# 266       LSO          13
# 267      HHEX          13
# 268       SSZ          13
# 269       LST          13
# 270       TOX          13
# 271      NYST          13
# 272      FYSE          13
# 273      NWSE          12
# 274      AMEF          12
# 275       TOE          12
# 276      AMEZ          12
# 277       WSX          12
# 278       SEE          12
# 279      NYBE          12
# 280      AMMX          12
# 281       QSX          12
# 282      HAEX          12
# 283      NYSA          12
# 284      HKEH          12
# 285      AMIX          12
# 286       ZSX          12
# 287      AMHX          12
# 288       YSX          12
# 289      HKER          12
# 290       OSX          12
# 291      NYRE          12
# 292      QYSE          12
# 293    JASDAQ          12
# 294       LSA          12
# 295       ASX          12
# 296      AMEG          12
# 297      NYZE          12
# 298      NYFE          12
# 299       SSU          12
# 300       LSD          12
# 301       TLE          12
# 302      CMEX          12
# 303      AMEA          12
# 304       LSN          12
# 305       LZE          12
# 306      NYSI          12
# 307      NBSE          12
# 308      UMEX          12
# 309    NASDUQ          12
# 310      QMEX          12
# 311      FMEX          12
# 312      HSEX          12
# 313       LWE          12
# 314       SLE          12
# 315      AREX          12
# 316    NASDAB          12
# 317      AMUX          12
# 318       SSH          12
# 319      AMTX          12
# 320       THE          12
# 321       TCX          12
# 322       LSB          12
# 323      AJEX          11
# 324      AMEC          11
# 325  BURONEXT          11
# 326       LSC          11
# 327  EUROIEXT          11
# 328       THX          11
# 329      NYKE          11
# 330      HZEX          11
# 331      IKEX          11
# 332      HYSE          11
# 333      NSSE          11
# 334      PYSE          11
# 335      AIEX          11
# 336      GYSE          11
# 337      HKBX          11
# 338  EARONEXT          11
# 339       MSX          11
# 340      AMEK          11
# 341      HKTX          11
# 342      HKEL          11
# 343      AXEX          11
# 344       LEE          11
# 345      ATEX          11
# 346      TKEX          11
# 347       SSA          11
# 348      NYSR          11
# 349      HKSX          11
# 350       SQE          11
# 351       SDE          11
# 352      HOEX          11
# 353      AMEM          11
# 354      ZMEX          11
# 355      GMEX          11
# 356      GKEX          11
# 357      NNSE          11
# 358  EURONFXT          11
# 359      HKAX          11
# 360       SSC          11
# 361      AMEE          11
# 362      HKEO          11
# 363       LSP          11
# 364      NDSE          10
# 365    NNSDAQ          10
# 366      HPEX          10
# 367    NMSDAQ          10
# 368      NYSD          10
# 369    FASDAQ          10
# 370      NYNE          10
# 371      RYSE          10
# 372      HEEX          10
# 373      AMFX          10
# 374      AMRX          10
# 375      AMEN          10
# 376      AHEX          10
# 377    NAQDAQ          10
# 378    GASDAQ          10
# 379      AFEX          10
# 380      NYSJ          10
# 381      HQEX          10
# 382      HKEG          10
# 383       TRE          10
# 384      NYPE          10
# 385    NASDNQ          10
# 386       NSX          10
# 387      NYSW          10
# 388      NYTE          10
# 389      NYWE          10
# 390       TQX          10
# 391      LMEX          10
# 392      PMEX          10
# 393      HKEA          10
# 394      HKKX          10
# 395  EURONEZT          10
# 396      HNEX          10
# 397      YYSE          10
# 398       TME          10
# 399      NMEX          10
# 400      LYSE          10
# 401    NHSDAQ          10
# 402  EURUNEXT          10
# 403      HKRX          10
# 404      BKEX          10
# 405    NASDOQ          10
# 406      NYHE          10
# 407      AMQX          10
# 408  EURONEXN          10
# 409      DKEX          10
# 410      AYEX          10
# 411      NGSE          10
# 412    NANDAQ          10
# 413      HKEI          10
# 414       SVE          10
# 415      EKEX          10
# 416      HKEM          10
# 417      NKEX          10
# 418      NOSE          10
# 419       LLE          10
# 420      EYSE          10
# 421  EUYONEXT          10
# 422      NYSY          10
# 423    QASDAQ          10
# 424      TMEX          10
# 425       LGE          10
# 426  MURONEXT          10
# 427      ZKEX           9
# 428      AMPX           9
# 429      SKEX           9
# 430      OYSE           9
# 431  EUROKEXT           9
# 432    NAUDAQ           9
# 433    NARDAQ           9
# 434      NYSV           9
# 435  EUWONEXT           9
# 436    VASDAQ           9
# 437    NASGAQ           9
# 438  EURZNEXT           9
# 439      YMEX           9
# 440    NAVDAQ           9
# 441      AMOX           9
# 442    NASDRQ           9
# 443      NYEE           9
# 444       SSP           9
# 445       LFE           9
# 446      NCSE           9
# 447      ALEX           9
# 448      AMDX           9
# 449      AMBX           9
# 450      AMEJ           9
# 451      BYSE           9
# 452      AMES           9
# 453    OASDAQ           9
# 454    NASDMQ           9
# 455    NATDAQ           9
# 456    NAYDAQ           9
# 457      AOEX           9
# 458    BASDAQ           9
# 459      HFEX           9
# 460      VKEX           9
# 461      AMJX           9
# 462       SSR           9
# 463    NASDWQ           9
# 464    NASXAQ           9
# 465      SMEX           9
# 466      RKEX           9
# 467    NAIDAQ           9
# 468      AQEX           9
# 469  EURONEXR           9
# 470       LSH           9
# 471      NZSE           9
# 472  EUUONEXT           9
# 473      DMEX           9
# 474       TYE           9
# 475    NAJDAQ           9
# 476      AMLX           9
# 477    MASDAQ           9
# 478  EUOONEXT           9
# 479      AUEX           9
# 480  UURONEXT           9
# 481      AEEX           9
# 482      NYLE           9
# 483      AMGX           9
# 484      DYSE           9
# 485      YKEX           9
# 486      HKFX           9
# 487      AMSX           9
# 488      HYEX           9
# 489    NASDHQ           9
# 490       LKE           9
# 491    NASDAR           9
# 492      NYSG           9
# 493    NAHDAQ           9
# 494    NQSDAQ           8
# 495    NASDAZ           8
# 496      HKZX           8
# 497       KSX           8
# 498    NALDAQ           8
# 499      NXSE           8
# 500      NYSZ           8
# 501      NYSB           8
# 502      KKEX           8
# 503  EURONWXT           8
# 504      NYSQ           8
# 505      AMXX           8
# 506      HREX           8
# 507      NFSE           8
# 508    NWSDAQ           8
# 509    NAXDAQ           8
# 510      NYGE           8
# 511       TDE           8
# 512      NYSX           8
# 513      ACEX           8
# 514      UYSE           8
# 515  EURONNXT           8
# 516      IYSE           8
# 517  EURONEXZ           8
# 518  EURONECT           8
# 519      AMEI           8
# 520      NMSE           8
# 521  EGRONEXT           8
# 522    NISDAQ           8
# 523      HJEX           8
# 524    NASMAQ           8
# 525       SSI           8
# 526      NYSU           8
# 527  EUROEEXT           8
# 528    EASDAQ           8
# 529  EURBNEXT           8
# 530  EURXNEXT           8
# 531  EURONEST           8
# 532      PKEX           8
# 533    NASDJQ           8
# 534      APEX           8
# 535  EURONEXG           8
# 536    NPSDAQ           8
# 537    NASDEQ           8
# 538       TNE           8
# 539      ZYSE           8
# 540    NKSDAQ           8
# 541      HKWX           8
# 542      HVEX           8
# 543      NHSE           8
# 544      NYYE           8
# 545    NASDIQ           8
# 546      NYDE           8
# 547  EURONEPT           8
# 548    AASDAQ           8
# 549    NAEDAQ           8
# 550      NPSE           8
# 551    NFSDAQ           8
# 552    NASDAV           7
# 553       TZE           7
# 554  EURYNEXT           7
# 555      WKEX           7
# 556      TYSE           7
# 557      HKOX           7
# 558      NASE           7
# 559  EUROWEXT           7
# 560    NASDBQ           7
# 561    NOSDAQ           7
# 562    NASDAJ           7
# 563      NYAE           7
# 564      HIEX           7
# 565    KASDAQ           7
# 566    NASKAQ           7
# 567    NASDAU           7
# 568      AMZX           7
# 569  EHRONEXT           7
# 570    NASDZQ           7
# 571  EURGNEXT           7
# 572  EXRONEXT           7
# 573       STE           7
# 574      AZEX           7
# 575      NESE           7
# 576    NASDLQ           7
# 577      HKEZ           7
# 578      AMKX           7
# 579    NUSDAQ           7
# 580      HKEW           7
# 581  EURONEJT           7
# 582  EURONEAT           7
# 583  EURONEXY           7
# 584      AVEX           7
# 585    NASFAQ           7
# 586      HKEY           7
# 587      MMEX           7
# 588  EUROLEXT           7
# 589  CURONEXT           7
# 590  EURONVXT           7
# 591  LURONEXT           7
# 592      NYUE           7
# 593    NASDAH           7
# 594    NASDPQ           7
# 595    HASDAQ           7
# 596  EUROMEXT           7
# 597  NURONEXT           7
# 598    NASDAP           7
# 599  EURWNEXT           7
# 600    NASDVQ           7
# 601  DURONEXT           7
# 602    NASDFQ           7
# 603      AMEV           7
# 604  EURONEFT           7
# 605    YASDAQ           7
# 606  EURONKXT           7
# 607    NAGDAQ           7
# 608    ZASDAQ           7
# 609    NASDAO           7
# 610  EURNNEXT           7
# 611  EPRONEXT           7
# 612      HKEJ           7
# 613  EURQNEXT           7
# 614    NASDDQ           7
# 615  EURONEUT           7
# 616  EURONEVT           7
# 617      NYOE           7
# 618    NASDAN           7
# 619  EUROHEXT           7
# 620    RASDAQ           7
# 621  EURONBXT           7
# 622      AMEQ           7
# 623      UKEX           7
# 624  EURONEXU           7
# 625    TASDAQ           7
# 626  EURONGXT           7
# 627  EURTNEXT           7
# 628    NASLAQ           7
# 629      NYSS           7
# 630    NAMDAQ           7
# 631  EURONLXT           7
# 632    SASDAQ           7
# 633    NASUAQ           7
# 634  EURODEXT           7
# 635      HKUX           7
# 636      HKEU           7
# 637  EURENEXT           7
# 638    NASHAQ           7
# 639  XURONEXT           6
# 640  EUROTEXT           6
# 641  EURONEXX           6
# 642      NISE           6
# 643    NASDAF           6
# 644      WYSE           6
# 645  ELRONEXT           6
# 646  ZURONEXT           6
# 647  EUROXEXT           6
# 648  EURONOXT           6
# 649    NASSAQ           6
# 650    NASRAQ           6
# 651  RURONEXT           6
# 652    NASDAD           6
# 653      NYME           6
# 654    NASBAQ           6
# 655  EURONERT           6
# 656  EURVNEXT           6
# 657  EUROJEXT           6
# 658      RMEX           6
# 659       LAE           6
# 660    NTSDAQ           6
# 661  EUROPEXT           6
# 662  EULONEXT           6
# 663    NRSDAQ           6
# 664  EUROYEXT           6
# 665  EURONDXT           6
# 666  EURONEXB           6
# 667  EURONEDT           6
# 668      CKEX           6
# 669    NASDAW           6
# 670      NJSE           6
# 671  EUROGEXT           6
# 672  EUROUEXT           6
# 673  EMRONEXT           6
# 674  EUSONEXT           6
# 675    NASDAX           6
# 676    NBSDAQ           6
# 677    WASDAQ           6
# 678  EURONEET           6
# 679  EERONEXT           6
# 680    NAKDAQ           6
# 681  EURFNEXT           6
# 682    NVSDAQ           6
# 683      ABEX           6
# 684  EURONENT           6
# 685  ETRONEXT           6
# 686    NASDAI           6
# 687    NASDAE           6
# 688  EUKONEXT           6
# 689      NYSO           6
# 690  EURONEHT           6
# 691  FURONEXT           6
# 692      OKEX           6
# 693    NJSDAQ           6
# 694  EUROCEXT           6
# 695  EURONJXT           6
# 696       LXE           6
# 697    NASDAM           6
# 698      HBEX           6
# 699  EURONHXT           6
# 700    NABDAQ           6
# 701  EJRONEXT           6
# 702  EUROZEXT           6
# 703      AGEX           6
# 704  ECRONEXT           6
# 705    NASPAQ           6
# 706    NASDXQ           6
# 707  EURONPXT           6
# 708  EUROSEXT           6
# 709      HUEX           6
# 710  EBRONEXT           6
# 711  EUCONEXT           6
# 712      NYSN           6
# 713  EURONYXT           6
# 714  EURONEXD           6
# 715  EVRONEXT           5
# 716      HKMX           5
# 717  EUMONEXT           5
# 718    NASTAQ           5
# 719  ESRONEXT           5
# 720    NASCAQ           5
# 721    NASDCQ           5
# 722    NASQAQ           5
# 723  EURJNEXT           5
# 724  EURPNEXT           5
# 725    NASDQQ           5
# 726      IMEX           5
# 727  EURONRXT           5
# 728  EURONEXS           5
# 729    NASIAQ           5
# 730  EUDONEXT           5
# 731  EURMNEXT           5
# 732      BMEX           5
# 733    NASDAA           5
# 734  SURONEXT           5
# 735    NASEAQ           5
# 736    NASDAG           5
# 737  EURONEXW           5
# 738    LASDAQ           5
# 739  EUTONEXT           5
# 740      HKPX           5
# 741  EUBONEXT           5
# 742    NASDYQ           5
# 743    NESDAQ           5
# 744    CASDAQ           5
# 745  EURONEBT           5
# 746  EUQONEXT           5
# 747  EUJONEXT           5
# 748    NASDAK           5
# 749    NAODAQ           5
# 750    NASDAL           5
# 751  EURONETT           5
# 752    NXSDAQ           5
# 753      KYSE           5
# 754       SME           5
# 755      HKXX           5
# 756    NCSDAQ           5
# 757    NASDAY           5
# 758  EFRONEXT           5
# 759    NAWDAQ           5
# 760  JURONEXT           5
# 761  EUVONEXT           5
# 762    NACDAQ           5
# 763    NAZDAQ           5
# 764  EUEONEXT           5
# 765  EURONCXT           5
# 766  EURONEXA           5
# 767  PURONEXT           5
# 768    NASWAQ           5
# 769  EURONZXT           5
# 770  EURONEXL           5
# 771  EUZONEXT           5
# 772  EURSNEXT           5
# 773    UASDAQ           5
# 774  GURONEXT           5
# 775    NASYAQ           5
# 776  EURONEXQ           5
# 777  EURONEXO           4
# 778  EURONEYT           4
# 779  EURONEKT           4
# 780  EURONAXT           4
# 781  EURONEXJ           4
# 782      HKLX           4
# 783  EURONQXT           4
# 784    NAADAQ           4
# 785    NASDAS           4
# 786    DASDAQ           4
# 787  EUGONEXT           4
# 788  EURONEXE           4
# 789  KURONEXT           4
# 790  EURRNEXT           4
# 791  IURONEXT           4
# 792    NASVAQ           4
# 793  EURANEXT           4
# 794  EURONXXT           4
# 795  VURONEXT           4
# 796  EURONEXI           4
# 797    NGSDAQ           4
# 798    NSSDAQ           4
# 799  EZRONEXT           4
# 800  EUROQEXT           4
# 801      HKVX           4
# 802  EURHNEXT           4
# 803  EUPONEXT           4
# 804  EUIONEXT           4
# 805  EURONUXT           4
# 806      LKEX           4
# 807  EIRONEXT           4
# 808  EDRONEXT           4
# 809    NASDAT           4
# 810    NASDSQ           4
# 811  EWRONEXT           4
# 812    NAFDAQ           4
# 813    PASDAQ           4
# 814  EQRONEXT           4
# 815  EUROFEXT           4
# 816  ENRONEXT           4
# 817    NASDKQ           4
# 818      JKEX           4
# 819    NYSDAQ           4
# 820  EURONEMT           4
# 821  EUROAEXT           4
# 822      JYSE           4
# 823      ASEX           4
# 824  EKRONEXT           3
# 825  EURONEQT           3
# 826    NASJAQ           3
# 827    NASOAQ           3
# 828  EUHONEXT           3
# 829  EURONEXV           3
# 830  TURONEXT           3
# 831  EUNONEXT           3
# 832  HURONEXT           3
# 833  EURONTXT           3
# 834  EURCNEXT           3
# 835  EURDNEXT           3
# 836  EURINEXT           3
# 837  AURONEXT           3
# 838      HXEX           3
# 839  EURLNEXT           3
# 840    NASDGQ           3
# 841      AMED           3
# 842  QURONEXT           3
# 843    NASDAC           3
# 844  EURONIXT           3
# 845  EORONEXT           3
# 846    NAPDAQ           3
# 847  EURONEXP           3
# 848      VYSE           3
# 849  EUROBEXT           3
# 850  EUXONEXT           3
# 851  EURONEXK           3
# 852  EURONMXT           3
# 853  WURONEXT           3
# 854  EURONEWT           3
# 855  EURONEXM           3
# 856  EURONEXF           3
# 857  EURONEXH           3
# 858  EURONEOT           3
# 859    IASDAQ           2
# 860    XASDAQ           2
# 861  YURONEXT           2
# 862  EYRONEXT           2
# 863  EUROREXT           2
# 864    NASZAQ           2
# 865    NLSDAQ           2
# 866  EURKNEXT           2
# 867  EUROVEXT           2
# 868    NASAAQ           2
# 869  ERRONEXT           2
# 870  EURONELT           2
# 871  EURONEIT           2
# 872  EURONEXC           2
# 873  OURONEXT           1
# 874  EUFONEXT           1
# 875  EURONEGT           1
# 876  EURONSXT           1

# %% [markdown]
# -> Alocando as siglas parecidas em grupos, usando a biblioteca thefuzz, para que fique mais fácil corrijir os erros de cada grupo

# %%
from thefuzz import fuzz

#Utilizando a função criada por Jairo com adição do retorno agora, uma vez que manipularemos os grupos
def Verifica_Categorias_base_retorno(dataframe, categoria):

    if categoria not in dataframe.columns:
        print(f"Erro: a categoria '{categoria}' não foi encontrada no DataFrame.")
        return []

    valores = dataframe[categoria].dropna().astype(str).str.strip().unique().tolist()
    grupos = []

    while valores:
        base = valores.pop(0)
        grupo = [base]
        similares = []

        for v in valores:
            if fuzz.ratio(base, v) >= 60:  # Pega apenas os valores mais próximos para comparação
                grupo.append(v)
                similares.append(v)

        # Remove os que já foram agrupados
        valores = [v for v in valores if v not in similares]
        grupos.append(grupo)

    # Exibe os grupos
    for i, grupo in enumerate(grupos, 1):
        print(f"Grupo {i}: {grupo}")

    return grupos  # <-- retorno adicionado aqui


grupos_siglas_b2 = Verifica_Categorias_base_retorno(variacoes_siglas, 'variacao')
# Out:
# Grupo 1: ['HKEX', 'AKEX', 'HMEX', 'HKEK', 'HKEQ', 'XKEX', 'HKDX', 'HKEN', 'HKEB', 'HCEX', 'HKEP', 'HKEF', 'HKHX', 'HKJX', 'HKES', 'HKEC', 'HWEX', 'HDEX', 'MKEX', 'HKEV', 'HKQX', 'HGEX', 'QKEX', 'HKYX', 'KMEX', 'HKCX', 'HKNX', 'HKED', 'HTEX', 'FKEX', 'HKEE', 'HKET', 'HLEX', 'HKGX', 'HKIX', 'HHEX', 'HAEX', 'HKEH', 'HKER', 'HSEX', 'HZEX', 'IKEX', 'HKBX', 'HKTX', 'HKEL', 'TKEX', 'HKSX', 'HOEX', 'GKEX', 'HKAX', 'HKEO', 'HPEX', 'HEEX', 'AHEX', 'HQEX', 'HKEG', 'HKEA', 'HKKX', 'HNEX', 'HKRX', 'BKEX', 'DKEX', 'HKEI', 'EKEX', 'HKEM', 'NKEX', 'ZKEX', 'SKEX', 'HFEX', 'VKEX', 'RKEX', 'YKEX', 'HKFX', 'HYEX', 'HKZX', 'KKEX', 'HREX', 'HJEX', 'PKEX', 'HKWX', 'HVEX', 'WKEX', 'HKOX', 'HIEX', 'HKEZ', 'HKEW', 'HKEY', 'HKEJ', 'UKEX', 'HKUX', 'HKEU', 'CKEX', 'OKEX', 'HBEX', 'HUEX', 'HKMX', 'HKPX', 'HKXX', 'HKLX', 'HKVX', 'LKEX', 'JKEX', 'HXEX']
# Grupo 2: ['TSX', 'TSE', 'TSO', 'TSL', 'TSJ', 'TSM', 'TSN', 'TSW', 'TSI', 'TSQ', 'TSK', 'TSH', 'TSC', 'PSX', 'LSX', 'TSB', 'TSV', 'TSA', 'TSZ', 'TSF', 'TSS', 'TSG', 'TSD', 'TST', 'TSY', 'TSR', 'SSX', 'TSP', 'TUX', 'CSX', 'TSU', 'TGX', 'BSX', 'TKX', 'TLX', 'TXE', 'TWX', 'TYX', 'ESX', 'TFX', 'TJX', 'ISX', 'SXE', 'XSX', 'FSX', 'GSX', 'USX', 'TXX', 'TEX', 'TAX', 'JSX', 'RSX', 'TPX', 'TVX', 'TNX', 'TMX', 'TZX', 'TDX', 'TTX', 'HSX', 'TBX', 'TRX', 'DSX', 'VSX', 'TIX', 'TOX', 'WSX', 'QSX', 'ZSX', 'YSX', 'OSX', 'ASX', 'TCX', 'THX', 'MSX', 'NSX', 'TQX', 'KSX']
# Grupo 3: ['SSE', 'LSE', 'DSE', 'YSE', 'OSE', 'PSE', 'NSE', 'VSE', 'JSE', 'GSE', 'HSE', 'USE', 'ASE', 'ISE', 'RSE', 'QSE', 'BSE', 'CSE', 'ZSE', 'WSE', 'MSE', 'XSE', 'ESE', 'KSE', 'FSE', 'SUE', 'SSV', 'SWE', 'SJE', 'SBE', 'SHE', 'SSB', 'SCE', 'SYSE', 'SNE', 'SSL', 'SKE', 'SRE', 'SSN', 'SZE', 'SSD', 'SSJ', 'SSO', 'SGE', 'SSQ', 'SSS', 'SAE', 'LSS', 'SYE', 'SPE', 'SSG', 'SFE', 'SSY', 'SSM', 'SST', 'SIE', 'SSF', 'SSW', 'SSK', 'SOE', 'SSZ', 'SEE', 'SSU', 'SLE', 'SSH', 'NSSE', 'SSA', 'SQE', 'SDE', 'SSC', 'SVE', 'SSP', 'SSR', 'SSI', 'STE', 'SME']
# Grupo 4: ['EURONEXT', 'EUAONEXT', 'EUROOEXT', 'BURONEXT', 'EUROIEXT', 'EARONEXT', 'EURONFXT', 'EURONEZT', 'EURUNEXT', 'EURONEXN', 'EUYONEXT', 'MURONEXT', 'EUROKEXT', 'EUWONEXT', 'EURZNEXT', 'EURONEXR', 'EUUONEXT', 'EUOONEXT', 'UURONEXT', 'EURONWXT', 'EURONNXT', 'EURONEXZ', 'EURONECT', 'EGRONEXT', 'EUROEEXT', 'EURBNEXT', 'EURXNEXT', 'EURONEST', 'EURONEXG', 'EURONEPT', 'EURYNEXT', 'EUROWEXT', 'EHRONEXT', 'EURGNEXT', 'EXRONEXT', 'EURONEJT', 'EURONEAT', 'EURONEXY', 'EUROLEXT', 'CURONEXT', 'EURONVXT', 'LURONEXT', 'EUROMEXT', 'NURONEXT', 'EURWNEXT', 'DURONEXT', 'EURONEFT', 'EURONKXT', 'EURNNEXT', 'EPRONEXT', 'EURQNEXT', 'EURONEUT', 'EURONEVT', 'EUROHEXT', 'EURONBXT', 'EURONEXU', 'EURONGXT', 'EURTNEXT', 'EURONLXT', 'EURODEXT', 'EURENEXT', 'XURONEXT', 'EUROTEXT', 'EURONEXX', 'ELRONEXT', 'ZURONEXT', 'EUROXEXT', 'EURONOXT', 'RURONEXT', 'EURONERT', 'EURVNEXT', 'EUROJEXT', 'EUROPEXT', 'EULONEXT', 'EUROYEXT', 'EURONDXT', 'EURONEXB', 'EURONEDT', 'EUROGEXT', 'EUROUEXT', 'EMRONEXT', 'EUSONEXT', 'EURONEET', 'EERONEXT', 'EURFNEXT', 'EURONENT', 'ETRONEXT', 'EUKONEXT', 'EURONEHT', 'FURONEXT', 'EUROCEXT', 'EURONJXT', 'EURONHXT', 'EJRONEXT', 'EUROZEXT', 'ECRONEXT', 'EURONPXT', 'EUROSEXT', 'EBRONEXT', 'EUCONEXT', 'EURONYXT', 'EURONEXD', 'EVRONEXT', 'EUMONEXT', 'ESRONEXT', 'EURJNEXT', 'EURPNEXT', 'EURONRXT', 'EURONEXS', 'EUDONEXT', 'EURMNEXT', 'SURONEXT', 'EURONEXW', 'EUTONEXT', 'EUBONEXT', 'EURONEBT', 'EUQONEXT', 'EUJONEXT', 'EURONETT', 'EFRONEXT', 'JURONEXT', 'EUVONEXT', 'EUEONEXT', 'EURONCXT', 'EURONEXA', 'PURONEXT', 'EURONZXT', 'EURONEXL', 'EUZONEXT', 'EURSNEXT', 'GURONEXT', 'EURONEXQ', 'EURONEXO', 'EURONEYT', 'EURONEKT', 'EURONAXT', 'EURONEXJ', 'EURONQXT', 'EUGONEXT', 'EURONEXE', 'KURONEXT', 'EURRNEXT', 'IURONEXT', 'EURANEXT', 'EURONXXT', 'VURONEXT', 'EURONEXI', 'EZRONEXT', 'EUROQEXT', 'EURHNEXT', 'EUPONEXT', 'EUIONEXT', 'EURONUXT', 'EIRONEXT', 'EDRONEXT', 'EWRONEXT', 'EQRONEXT', 'EUROFEXT', 'ENRONEXT', 'EURONEMT', 'EUROAEXT', 'EKRONEXT', 'EURONEQT', 'EUHONEXT', 'EURONEXV', 'TURONEXT', 'EUNONEXT', 'HURONEXT', 'EURONTXT', 'EURCNEXT', 'EURDNEXT', 'EURINEXT', 'AURONEXT', 'EURLNEXT', 'QURONEXT', 'EURONIXT', 'EORONEXT', 'EURONEXP', 'EUROBEXT', 'EUXONEXT', 'EURONEXK', 'EURONMXT', 'WURONEXT', 'EURONEWT', 'EURONEXM', 'EURONEXF', 'EURONEXH', 'EURONEOT', 'YURONEXT', 'EYRONEXT', 'EUROREXT', 'EURKNEXT', 'EUROVEXT', 'ERRONEXT', 'EURONELT', 'EURONEIT', 'EURONEXC', 'OURONEXT', 'EUFONEXT', 'EURONEGT', 'EURONSXT']
# Grupo 5: ['NYSE', 'NLSE', 'NYQE', 'AYSE', 'NYSK', 'XYSE', 'NTSE', 'NYSM', 'NYVE', 'MYSE', 'NKSE', 'NRSE', 'NYCE', 'NYIE', 'NYXE', 'CYSE', 'NYSH', 'NUSE', 'NYSP', 'NYJE', 'NQSE', 'NVSE', 'NYSL', 'NYSF', 'NYSC', 'NYST', 'FYSE', 'NWSE', 'NYBE', 'NYSA', 'NYRE', 'QYSE', 'NYZE', 'NYFE', 'NYSI', 'NBSE', 'NYKE', 'HYSE', 'PYSE', 'GYSE', 'NYSR', 'NNSE', 'NDSE', 'NYSD', 'NYNE', 'RYSE', 'NYSJ', 'NYPE', 'NYSW', 'NYTE', 'NYWE', 'YYSE', 'LYSE', 'NYHE', 'NGSE', 'NOSE', 'EYSE', 'NYSY', 'OYSE', 'NYSV', 'NYEE', 'NCSE', 'BYSE', 'NZSE', 'NYLE', 'DYSE', 'NYSG', 'NXSE', 'NYSZ', 'NYSB', 'NYSQ', 'NFSE', 'NYGE', 'NYSX', 'UYSE', 'IYSE', 'NMSE', 'NYSU', 'NASDEQ', 'ZYSE', 'NHSE', 'NYYE', 'NYDE', 'NPSE', 'TYSE', 'NASE', 'NYAE', 'NESE', 'NYUE', 'NYOE', 'NYSS', 'NISE', 'WYSE', 'NYME', 'NJSE', 'NASDAE', 'NYSO', 'NYSN', 'NASEAQ', 'KYSE', 'NYSDAQ', 'JYSE', 'VYSE']
# Grupo 6: ['NASDAQ', 'NASNAQ', 'NADDAQ', 'NZSDAQ', 'NASDTQ', 'NDSDAQ', 'JASDAQ', 'NASDUQ', 'NASDAB', 'NNSDAQ', 'NMSDAQ', 'FASDAQ', 'NAQDAQ', 'GASDAQ', 'NASDNQ', 'NHSDAQ', 'NASDOQ', 'NANDAQ', 'QASDAQ', 'NAUDAQ', 'NARDAQ', 'VASDAQ', 'NASGAQ', 'NAVDAQ', 'NASDRQ', 'OASDAQ', 'NASDMQ', 'NATDAQ', 'NAYDAQ', 'BASDAQ', 'NASDWQ', 'NASXAQ', 'NAIDAQ', 'NAJDAQ', 'MASDAQ', 'NASDHQ', 'NASDAR', 'NAHDAQ', 'NQSDAQ', 'NASDAZ', 'NALDAQ', 'NWSDAQ', 'NAXDAQ', 'NISDAQ', 'NASMAQ', 'EASDAQ', 'NASDJQ', 'NPSDAQ', 'NKSDAQ', 'NASDIQ', 'AASDAQ', 'NAEDAQ', 'NFSDAQ', 'NASDAV', 'NASDBQ', 'NOSDAQ', 'NASDAJ', 'KASDAQ', 'NASKAQ', 'NASDAU', 'NASDZQ', 'NASDLQ', 'NUSDAQ', 'NASFAQ', 'NASDAH', 'NASDPQ', 'HASDAQ', 'NASDAP', 'NASDVQ', 'NASDFQ', 'YASDAQ', 'NAGDAQ', 'ZASDAQ', 'NASDAO', 'NASDDQ', 'NASDAN', 'RASDAQ', 'TASDAQ', 'NASLAQ', 'NAMDAQ', 'SASDAQ', 'NASUAQ', 'NASHAQ', 'NASDAF', 'NASSAQ', 'NASRAQ', 'NASDAD', 'NASBAQ', 'NTSDAQ', 'NRSDAQ', 'NASDAW', 'NASDAX', 'NBSDAQ', 'WASDAQ', 'NAKDAQ', 'NVSDAQ', 'NASDAI', 'NJSDAQ', 'NASDAM', 'NABDAQ', 'NASPAQ', 'NASDXQ', 'NASTAQ', 'NASCAQ', 'NASDCQ', 'NASQAQ', 'NASDQQ', 'NASIAQ', 'NASDAA', 'NASDAG', 'LASDAQ', 'NASDYQ', 'NESDAQ', 'CASDAQ', 'NASDAK', 'NAODAQ', 'NASDAL', 'NXSDAQ', 'NCSDAQ', 'NASDAY', 'NAWDAQ', 'NACDAQ', 'NAZDAQ', 'NASWAQ', 'UASDAQ', 'NASYAQ', 'NAADAQ', 'NASDAS', 'DASDAQ', 'NASVAQ', 'NGSDAQ', 'NSSDAQ', 'NASDAT', 'NASDSQ', 'NAFDAQ', 'PASDAQ', 'NASDKQ', 'NASJAQ', 'NASOAQ', 'NASDGQ', 'NASDAC', 'NAPDAQ', 'IASDAQ', 'XASDAQ', 'NASZAQ', 'NLSDAQ', 'NASAAQ']
# Grupo 7: ['AMEX', 'AMEU', 'AMYX', 'AMVX', 'ADEX', 'AMEH', 'AMET', 'VMEX', 'AMAX', 'WMEX', 'AMNX', 'AMEY', 'AMEL', 'AWEX', 'AMER', 'XMEX', 'AMEW', 'ANEX', 'AMWX', 'AMEO', 'AAEX', 'OMEX', 'EMEX', 'JMEX', 'AMEP', 'AMCX', 'AMEB', 'AMEF', 'AMEZ', 'AMMX', 'AMIX', 'AMHX', 'AMEG', 'CMEX', 'AMEA', 'UMEX', 'QMEX', 'FMEX', 'AREX', 'AMUX', 'AMTX', 'AJEX', 'AMEC', 'AIEX', 'AMEK', 'AXEX', 'ATEX', 'AMEM', 'ZMEX', 'GMEX', 'AMEE', 'AMFX', 'AMRX', 'AMEN', 'AFEX', 'LMEX', 'PMEX', 'NMEX', 'AMQX', 'AYEX', 'TMEX', 'AMPX', 'YMEX', 'AMOX', 'ALEX', 'AMDX', 'AMBX', 'AMEJ', 'AMES', 'AOEX', 'AMJX', 'SMEX', 'AQEX', 'DMEX', 'AMLX', 'AUEX', 'AEEX', 'AMGX', 'AMSX', 'AMXX', 'ACEX', 'AMEI', 'APEX', 'AMZX', 'AZEX', 'AMKX', 'AVEX', 'MMEX', 'AMEV', 'AMEQ', 'RMEX', 'ABEX', 'AGEX', 'IMEX', 'BMEX', 'ASEX', 'AMED']
# Grupo 8: ['TQE', 'TIE', 'LQE', 'TPE', 'TVE', 'TAE', 'TWE', 'TEE', 'TCE', 'TBE', 'TUE', 'TGE', 'TFE', 'TKE', 'TJE', 'LTE', 'TTE', 'TOE', 'TLE', 'THE', 'TRE', 'TME', 'TYE', 'TDE', 'TNE', 'TZE']
# Grupo 9: ['LSL', 'LSU', 'LSQ', 'LSF', 'LSK', 'LSZ', 'LSR', 'LSI', 'LSV', 'LSY', 'LSM', 'LSG', 'LSW', 'LSJ', 'LSO', 'LST', 'LSA', 'LSD', 'LSN', 'LSB', 'LSC', 'LSP', 'LLE', 'LSH']
# Grupo 10: ['LOE', 'LHE', 'LCE', 'LVE', 'LUE', 'LPE', 'LRE', 'LYE', 'LNE', 'LJE', 'LDE', 'LIE', 'LME', 'LBE', 'LZE', 'LWE', 'LEE', 'LGE', 'LFE', 'LKE', 'LAE', 'LXE']

# %% [markdown]
# -> Corrijindo problemas manualmente

# %%
grupos_siglas_b2[9].extend(['LSE', 'LSS', 'LQE', 'LSL', 'LSU', 'LSQ', 'LSF', 'LSK', 'LSZ', 'LSR', 'LSI', 'LSV', 'LSY', 'LSM', 'LSG', 'LSW', 'LSJ', 'LSO', 'LST', 'LSA', 'LSD', 'LSN', 'LSB', 'LSC', 'LSP', 'LLE', 'LSH'])

grupos_siglas_b2.pop(8)
# Out:
# ['LSL',
#  'LSU',
#  'LSQ',
#  'LSF',
#  'LSK',
#  'LSZ',
#  'LSR',
#  'LSI',
#  'LSV',
#  'LSY',
#  'LSM',
#  'LSG',
#  'LSW',
#  'LSJ',
#  'LSO',
#  'LST',
#  'LSA',
#  'LSD',
#  'LSN',
#  'LSB',
#  'LSC',
#  'LSP',
#  'LLE',
#  'LSH']

# %% [markdown]
# -> Criando dicionários com os grupos todos montados para que seja possível a correção das siglas de maneira correta para cada bolsa de valores que elas representam

# %%
# Função para corrigir o valor com base no grupo
def corrigir_exchange(valor):
    if not isinstance(valor, str):
        return valor  # Retorna o valor original se não for string

    valor = valor.strip().upper()  # Remover espaços e converter para maiúsculas

    # Mapeamento dos grupos com suas variações (baseado na sua análise)
    grupos = {
        'HKEX': ['HKEX', 'AKEX', 'HMEX', 'HKEK', 'HKEQ', 'XKEX', 'HKDX', 'HKEN', 'HKEB', 'HCEX', 'HKEP', 'HKEF', 'HKHX', 'HKJX', 'HKES', 'HKEC', 'HWEX', 'HDEX', 'MKEX', 'HKEV', 'HKQX', 'HGEX', 'QKEX', 'HKYX', 'KMEX', 'HKCX', 'HKNX', 'HKED', 'HTEX', 'FKEX', 'HKEE', 'HKET', 'HLEX', 'HKGX', 'HKIX', 'HHEX', 'HAEX', 'HKEH', 'HKER', 'HSEX', 'HZEX', 'IKEX', 'HKBX', 'HKTX', 'HKEL', 'TKEX', 'HKSX', 'HOEX', 'GKEX', 'HKAX', 'HKEO', 'HPEX', 'HEEX', 'AHEX', 'HQEX', 'HKEG', 'HKEA', 'HKKX', 'HNEX', 'HKRX', 'BKEX', 'DKEX', 'HKEI', 'EKEX', 'HKEM', 'NKEX', 'ZKEX', 'SKEX', 'HFEX', 'VKEX', 'RKEX', 'YKEX', 'HKFX', 'HYEX', 'HKZX', 'KKEX', 'HREX', 'HJEX', 'PKEX', 'HKWX', 'HVEX', 'WKEX', 'HKOX', 'HIEX', 'HKEZ', 'HKEW', 'HKEY', 'HKEJ', 'UKEX', 'HKUX', 'HKEU', 'CKEX', 'OKEX', 'HBEX', 'HUEX', 'HKMX', 'HKPX', 'HKXX', 'HKLX', 'HKVX', 'LKEX', 'JKEX', 'HXEX'],
        'TSX': ['TSX', 'TSO', 'TSL', 'TSJ', 'TSM', 'TSN', 'TSW', 'TSI', 'TSQ', 'TSK', 'TSH', 'TSC', 'PSX', 'LSX', 'TSB', 'TSV', 'TSA', 'TSZ', 'TSF', 'TSS', 'TSG', 'TSD', 'TST', 'TSY', 'TSR', 'SSX', 'TSP', 'TUX', 'CSX', 'TSU', 'TGX', 'BSX', 'TKX', 'TLX', 'TXE', 'TWX', 'TYX', 'ESX', 'TFX', 'TJX', 'ISX', 'SXE', 'XSX', 'FSX', 'GSX', 'USX', 'TXX', 'TEX', 'TAX', 'JSX', 'RSX', 'TPX', 'TVX', 'TNX', 'TMX', 'TZX', 'TDX', 'TTX', 'HSX', 'TBX', 'TRX', 'DSX', 'VSX', 'TIX', 'TOX', 'WSX', 'QSX', 'ZSX', 'YSX', 'OSX', 'ASX', 'TCX', 'THX', 'MSX', 'NSX', 'TQX', 'KSX'],
        'SSE': ['SSE', 'DSE', 'YSE', 'OSE', 'PSE', 'NSE', 'VSE', 'JSE', 'GSE', 'HSE', 'USE', 'ASE', 'ISE', 'RSE', 'QSE', 'BSE', 'CSE', 'ZSE', 'WSE', 'MSE', 'XSE', 'ESE', 'KSE', 'FSE', 'SUE', 'SSV', 'SWE', 'SJE', 'SBE', 'SHE', 'SSB', 'SCE', 'SYSE', 'SNE', 'SSL', 'SKE', 'SRE', 'SSN', 'SZE', 'SSD', 'SSJ', 'SSO', 'SGE', 'SSQ', 'SSS', 'SAE', 'SYE', 'SPE', 'SSG', 'SFE', 'SSY', 'SSM', 'SST', 'SIE', 'SSF', 'SSW', 'SSK', 'SOE', 'SSZ', 'SEE', 'SSU', 'SLE', 'SSH', 'NSSE', 'SSA', 'SQE', 'SDE', 'SSC', 'SVE', 'SSP', 'SSR', 'SSI', 'STE', 'SME'],
        'EURONEXT': ['EURONEXT', 'EUAONEXT', 'EUROOEXT', 'BURONEXT', 'EUROIEXT', 'EARONEXT', 'EURONFXT', 'EURONEZT', 'EURUNEXT', 'EURONEXN', 'EUYONEXT', 'MURONEXT', 'EUROKEXT', 'EUWONEXT', 'EURZNEXT', 'EURONEXR', 'EUUONEXT', 'EUOONEXT', 'UURONEXT', 'EURONWXT', 'EURONNXT', 'EURONEXZ', 'EURONECT', 'EGRONEXT', 'EUROEEXT', 'EURBNEXT', 'EURXNEXT', 'EURONEST', 'EURONEXG', 'EURONEPT', 'EURYNEXT', 'EUROWEXT', 'EHRONEXT', 'EURGNEXT', 'EXRONEXT', 'EURONEJT', 'EURONEAT', 'EURONEXY', 'EUROLEXT', 'CURONEXT', 'EURONVXT', 'LURONEXT', 'EUROMEXT', 'NURONEXT', 'EURWNEXT', 'DURONEXT', 'EURONEFT', 'EURONKXT', 'EURNNEXT', 'EPRONEXT', 'EURQNEXT', 'EURONEUT', 'EURONEVT', 'EUROHEXT', 'EURONBXT', 'EURONEXU', 'EURONGXT', 'EURTNEXT', 'EURONLXT', 'EURODEXT', 'EURENEXT', 'XURONEXT', 'EUROTEXT', 'EURONEXX', 'ELRONEXT', 'ZURONEXT', 'EUROXEXT', 'EURONOXT', 'RURONEXT', 'EURONERT', 'EURVNEXT', 'EUROJEXT', 'EUROPEXT', 'EULONEXT', 'EUROYEXT', 'EURONDXT', 'EURONEXB', 'EURONEDT', 'EUROGEXT', 'EUROUEXT', 'EMRONEXT', 'EUSONEXT', 'EURONEET', 'EERONEXT', 'EURFNEXT', 'EURONENT', 'ETRONEXT', 'EUKONEXT', 'EURONEHT', 'FURONEXT', 'EUROCEXT', 'EURONJXT', 'EURONHXT', 'EJRONEXT', 'EUROZEXT', 'ECRONEXT', 'EURONPXT', 'EUROSEXT', 'EBRONEXT', 'EUCONEXT', 'EURONYXT', 'EURONEXD', 'EVRONEXT', 'EUMONEXT', 'ESRONEXT', 'EURJNEXT', 'EURPNEXT', 'EURONRXT', 'EURONEXS', 'EUDONEXT', 'EURMNEXT', 'SURONEXT', 'EURONEXW', 'EUTONEXT', 'EUBONEXT', 'EURONEBT', 'EUQONEXT', 'EUJONEXT', 'EURONETT', 'EFRONEXT', 'JURONEXT', 'EUVONEXT', 'EUEONEXT', 'EURONCXT', 'EURONEXA', 'PURONEXT', 'EURONZXT', 'EURONEXL', 'EUZONEXT', 'EURSNEXT', 'GURONEXT', 'EURONEXQ', 'EURONEXO', 'EURONEYT', 'EURONEKT', 'EURONAXT', 'EURONEXJ', 'EURONQXT', 'EUGONEXT', 'EURONEXE', 'KURONEXT', 'EURRNEXT', 'IURONEXT', 'EURANEXT', 'EURONXXT', 'VURONEXT', 'EURONEXI', 'EZRONEXT', 'EUROQEXT', 'EURHNEXT', 'EUPONEXT', 'EUIONEXT', 'EURONUXT', 'EIRONEXT', 'EDRONEXT', 'EWRONEXT', 'EQRONEXT', 'EUROFEXT', 'ENRONEXT', 'EURONEMT', 'EUROAEXT', 'EKRONEXT', 'EURONEQT', 'EUHONEXT', 'EURONEXV', 'TURONEXT', 'EUNONEXT', 'HURONEXT', 'EURONTXT', 'EURCNEXT', 'EURDNEXT', 'EURINEXT', 'AURONEXT', 'EURLNEXT', 'QURONEXT', 'EURONIXT', 'EORONEXT', 'EURONEXP', 'EUROBEXT', 'EUXONEXT', 'EURONEXK', 'EURONMXT', 'WURONEXT', 'EURONEWT', 'EURONEXM', 'EURONEXF', 'EURONEXH', 'EURONEOT', 'YURONEXT', 'EYRONEXT', 'EUROREXT', 'EURKNEXT', 'EUROVEXT', 'ERRONEXT', 'EURONELT', 'EURONEIT', 'EURONEXC', 'OURONEXT', 'EUFONEXT', 'EURONEGT', 'EURONSXT'],
        'NYSE': ['NYSE', 'NLSE', 'NYQE', 'AYSE', 'NYSK', 'XYSE', 'NTSE', 'NYSM', 'NYVE', 'MYSE', 'NKSE', 'NRSE', 'NYCE', 'NYIE', 'NYXE', 'CYSE', 'NYSH', 'NUSE', 'NYSP', 'NYJE', 'NQSE', 'NVSE', 'NYSL', 'NYSF', 'NYSC', 'NYST', 'FYSE', 'NWSE', 'NYBE', 'NYSA', 'NYRE', 'QYSE', 'NYZE', 'NYFE', 'NYSI', 'NBSE', 'NYKE', 'HYSE', 'PYSE', 'GYSE', 'NYSR', 'NNSE', 'NDSE', 'NYSD', 'NYNE', 'RYSE', 'NYSJ', 'NYPE', 'NYSW', 'NYTE', 'NYWE', 'YYSE', 'LYSE', 'NYHE', 'NGSE', 'NOSE', 'EYSE', 'NYSY', 'OYSE', 'NYSV', 'NYEE', 'NCSE', 'BYSE', 'NZSE', 'NYLE', 'DYSE', 'NYSG', 'NXSE', 'NYSZ', 'NYSB', 'NYSQ', 'NFSE', 'NYGE', 'NYSX', 'UYSE', 'IYSE', 'NMSE', 'NYSU', 'ZYSE', 'NHSE', 'NYYE', 'NYDE', 'NPSE', 'TYSE', 'NASE', 'NYAE', 'NESE', 'NYUE', 'NYOE', 'NYSS', 'NISE', 'WYSE', 'NYME', 'NJSE', 'NYSO', 'NYSN', 'KYSE', 'JYSE', 'VYSE'],
        'NASDAQ': ['NASDAQ', 'NASNAQ', 'NADDAQ', 'NZSDAQ', 'NASDTQ', 'NDSDAQ', 'JASDAQ', 'NASDUQ', 'NASDAB', 'NNSDAQ', 'NMSDAQ', 'FASDAQ', 'NAQDAQ', 'GASDAQ', 'NASDNQ', 'NHSDAQ', 'NASDOQ', 'NANDAQ', 'QASDAQ', 'NAVDAQ', 'NASDRQ', 'OASDAQ', 'NASDMQ', 'NATDAQ', 'NAYDAQ', 'BASDAQ', 'NASDWQ', 'NASXAQ', 'NAIDAQ', 'NAJDAQ', 'MASDAQ', 'NASDHQ', 'NASDAR', 'NAHDAQ', 'NQSDAQ', 'NASDAZ', 'NALDAQ', 'NWSDAQ', 'NAXDAQ', 'NISDAQ', 'NASDAQ', 'NASDJQ', 'NPSDAQ', 'NKSDAQ', 'NASDIQ', 'AASDAQ', 'NAEDAQ', 'NFSDAQ', 'NASDAV', 'NASDBQ', 'NOSDAQ', 'NASDAJ', 'KASDAQ', 'NASKAQ', 'NASDAH', 'NASDPQ', 'HASDAQ', 'NASDAP', 'NASDVQ', 'NASDFQ', 'YASDAQ', 'NAGDAQ', 'ZASDAQ', 'NASDAO', 'NASDDQ', 'NASDAN', 'RASDAQ', 'TASDAQ', 'NASLAQ', 'NAMDAQ', 'SASDAQ', 'NASUAQ', 'NASHAQ', 'NASDAF', 'NASSAQ', 'NASRAQ', 'NASDAD', 'NASBAQ', 'NTSDAQ', 'NRSDAQ', 'NASDUQ'],
        'AMEX': ['AMEX', 'AMEU', 'AMYX', 'AMVX', 'ADEX', 'AMEH', 'AMET', 'VMEX', 'AMAX', 'WMEX', 'AMNX', 'AMEY', 'AMEL', 'AWEX', 'AMER', 'XMEX', 'AMEW', 'ANEX', 'AMWX', 'AMEO', 'AAEX', 'OMEX', 'EMEX', 'JMEX', 'AMEP', 'AMCX', 'AMEB', 'AMEF', 'AMEZ', 'AMMX', 'AMIX', 'AMHX', 'AMEG', 'CMEX', 'AMEA', 'UMEX', 'QMEX', 'FMEX', 'AREX', 'AMUX', 'AMTX', 'AJEX', 'AMEC', 'AIEX', 'AMEK', 'AXEX', 'ATEX', 'AMEM', 'ZMEX', 'GMEX', 'AMEE', 'AMFX', 'AMRX', 'AMEN', 'AFEX', 'LMEX', 'PMEX', 'NMEX', 'AMQX', 'AYEX', 'TMEX', 'AMPX', 'YMEX', 'AMOX', 'ALEX', 'AMDX', 'AMBX', 'AMEJ', 'AMES', 'AOEX', 'AMJX', 'SMEX', 'AQEX', 'DMEX', 'AMLX', 'AUEX', 'AEEX', 'AMGX', 'AMSX', 'AMXX', 'ACEX', 'AMEI', 'APEX', 'AMZX', 'AZEX', 'AMKX', 'AVEX', 'MMEX', 'AMEV', 'AMEQ', 'RMEX', 'ABEX', 'AGEX', 'IMEX', 'BMEX', 'ASEX', 'AMED'],
        'TSE': ['TQE', 'TIE', 'TPE', 'TVE', 'TAE', 'TWE', 'TEE', 'TCE', 'TBE', 'TUE', 'TGE', 'TFE', 'TKE', 'TJE', 'TTE', 'TOE', 'TLE', 'THE', 'TRE', 'TME', 'TYE', 'TDE', 'TNE', 'TZE','TSE'],
        'LSE': ['LSE', 'LOE', 'LHE', 'LCE', 'LVE', 'LUE', 'LPE', 'LRE', 'LYE', 'LNE', 'LJE', 'LDE', 'LIE', 'LME', 'LBE', 'LZE', 'LWE', 'LEE', 'LGE', 'LFE', 'LKE', 'LAE', 'LXE', 'LSL', 'LSU', 'LSQ', 'LSF', 'LSK', 'LSZ', 'LSR', 'LSI', 'LSV', 'LSY', 'LSM', 'LSG', 'LSW', 'LSJ', 'LSO', 'LST', 'LSA', 'LSD', 'LSN', 'LSB', 'LSC', 'LSP', 'LLE', 'LSH', 'LQE', 'LSS', 'LTE']
    }

    # Verificar se o valor está em algum grupo
    for chave_grupo, variacoes in grupos.items():
        if valor in variacoes:
            return chave_grupo.upper()

    # Se não encontrar, retorna o valor original
    return valor

    # Aplicar a função à coluna exchange (índice 3)
base2_temp['Exchange'] = base2_temp['Exchange'].apply(corrigir_exchange)

# %% [markdown]
# -> Fazendo a checagem, é possível perceber que ainda existem variações, então vamos corrijí-las

# %%
variacoes_siglas = base2_temp['Exchange'].value_counts().reset_index()
variacoes_siglas.columns = ['variacao', 'frequencia']

#Para que possamos ver todas as siglas e sua frequência
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

print(variacoes_siglas)
# Out:
#     variacao  frequencia
# 0        SSE       22991
# 1        TSX       22804
# 2       HKEX       22381
# 3   EURONEXT       22303
# 4       NYSE       22199
# 5       AMEX       22164
# 6     NASDAQ       21812
# 7        LSE       21577
# 8        TSE       21398
# 9     NARDAQ           9
# 10    NASGAQ           9
# 11    VASDAQ           9
# 12    NAUDAQ           9
# 13    EASDAQ           8
# 14    NASMAQ           8
# 15    NASDEQ           8
# 16    NASDLQ           7
# 17    NUSDAQ           7
# 18    NASDAU           7
# 19    NASFAQ           7
# 20    NASDZQ           7
# 21    NJSDAQ           6
# 22    WASDAQ           6
# 23    NASDAM           6
# 24    NASDAX           6
# 25    NASDAE           6
# 26    NASPAQ           6
# 27    NVSDAQ           6
# 28    NASDXQ           6
# 29    NASDAW           6
# 30    NABDAQ           6
# 31    NBSDAQ           6
# 32    NAKDAQ           6
# 33    NASDAI           6
# 34    NXSDAQ           5
# 35    CASDAQ           5
# 36    NASWAQ           5
# 37    NASCAQ           5
# 38    NASTAQ           5
# 39    NACDAQ           5
# 40    NASDCQ           5
# 41    NASQAQ           5
# 42    UASDAQ           5
# 43    NESDAQ           5
# 44    NASDAY           5
# 45    NASYAQ           5
# 46    NASDYQ           5
# 47    NAWDAQ           5
# 48    NASEAQ           5
# 49    NCSDAQ           5
# 50    NASDAL           5
# 51    NASDAA           5
# 52    NASDQQ           5
# 53    LASDAQ           5
# 54    NASDAK           5
# 55    NAZDAQ           5
# 56    NASIAQ           5
# 57    NASDAG           5
# 58    NAODAQ           5
# 59    DASDAQ           4
# 60    NAFDAQ           4
# 61    NASDSQ           4
# 62    PASDAQ           4
# 63    NASDAS           4
# 64    NYSDAQ           4
# 65    NAADAQ           4
# 66    NGSDAQ           4
# 67    NSSDAQ           4
# 68    NASVAQ           4
# 69    NASDAT           4
# 70    NASDKQ           4
# 71    NAPDAQ           3
# 72    NASOAQ           3
# 73    NASJAQ           3
# 74    NASDAC           3
# 75    NASDGQ           3
# 76    NASZAQ           2
# 77    NLSDAQ           2
# 78    XASDAQ           2
# 79    NASAAQ           2
# 80    IASDAQ           2

# %% [markdown]
# -> Realizando as últimas correções na coluna para que a padronização fique correta. Verficação final mostrando que a coluna foi tratada com sucesso

# %%
# Dicionário com as variações incorretas de NASDAQ
correcoes_nasdaq = {
    'NARDAQ', 'NASGAQ', 'VASDAQ', 'NAUDAQ', 'EASDAQ', 'NASMAQ', 'NASDEQ',
    'NASDLQ', 'NUSDAQ', 'NASDAU', 'NASFAQ', 'NASDZQ', 'NJSDAQ', 'WASDAQ',
    'NASDAM', 'NASDAX', 'NASDAE', 'NASPAQ', 'NVSDAQ', 'NASDXQ', 'NASDAW',
    'NABDAQ', 'NBSDAQ', 'NAKDAQ', 'NASDAI', 'NXSDAQ', 'CASDAQ', 'NASWAQ',
    'NASCAQ', 'NASTAQ', 'NACDAQ', 'NASDCQ', 'NASQAQ', 'UASDAQ', 'NESDAQ',
    'NASDAY', 'NASYAQ', 'NASDYQ', 'NAWDAQ', 'NASEAQ', 'NCSDAQ', 'NASDAL',
    'NASDAA', 'NASDQQ', 'LASDAQ', 'NASDAK', 'NAZDAQ', 'NASIAQ', 'NASDAG',
    'NAODAQ', 'DASDAQ', 'NAFDAQ', 'NASDSQ', 'PASDAQ', 'NASDAS', 'NYSDAQ',
    'NAADAQ', 'NGSDAQ', 'NSSDAQ', 'NASVAQ', 'NASDAT', 'NASDKQ', 'NAPDAQ',
    'NASOAQ', 'NASJAQ', 'NASDAC', 'NASDGQ', 'NASZAQ', 'NLSDAQ', 'XASDAQ',
    'NASAAQ', 'IASDAQ'
}

# Função para corrigir a coluna exchange (índice 3)
def corrigir_nasdaq(valor):
    if isinstance(valor, str) and valor.upper() in correcoes_nasdaq:
        return 'NASDAQ'
    return valor

# Aplicar a função à coluna exchange (índice 3)
base2_temp['Exchange'] = base2_temp['Exchange'].apply(corrigir_nasdaq)

print(base2_temp['Exchange'].unique())
# Out:
# ['NYSE' 'TSE' 'LSE' 'HKEX' 'NASDAQ' 'TSX' 'AMEX' 'SSE' 'EURONEXT']

# %% [markdown]
# ---
# #### **Tratamento da coluna Currency**

# %% [markdown]
# -> Essa coluna é afetada por vários erros de formatação e digitação, por isso vamos criar um dicionáio com as formas incorretas para padronizar

# %%
currency_dicionario = {
    "USD": "USD",
    "US Dollar": "USD",
    "$": "USD",
    "usd": "USD",
    "US DOLLAR": "USD",
    "US DollaS": "USD",
    "US DBLLAR": "USD",
    "US DXllar": "USD",
    "US uollar": "USD",
    "US DolEar": "USD",
    "UE Dollar": "USD",
    "US DollaJ": "USD",
    "USR": "USD",
    "USRDollar": "USD",
}

base2_temp['Currency'] = base2_temp['Currency'].replace(currency_dicionario)

print(base2_temp[['Currency']].head(10))
# Out:
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# 8      USD
# 9      USD

# %% [markdown]
# -> Analisando os valores únicos da coluna, ainda existem muitos erros de digitação que devem ser corrigidos, para isso vamos criar outro dicionário contendo todos esses erros e passando eles para a formatação correta

# %%
valores_unicos = base2_temp['Currency'].unique()

print(valores_unicos)
# Out:
# ['USD' 'us dollar' 'US Vollar' 'WS Dollar' 'RSD' 'LSD' 'YSD' 'UID' 'ASD'
#  'US DollGr' 'US DollVr' 'USN' 'HSD' 'US DKllar' 'US DollTr' 'UX Dollar'
#  'US DoMlar' 'UY Dollar' 'US DOLYAR' 'US Jollar' 'US DolNar' 'USKDollar'
#  'Isd' 'UH Dollar' 'US DollaT' 'ISD' 'US DAllar' 'usG' 'US DoOlar' 'USV'
#  'usT' 'US DollYr' 'US DOLLOR' 'KSD' 'UK Dollar' 'US Aollar' 'US DollHr'
#  'US DolBar' 'ZSD' 'USX' 'US DoUlar' 'MSD' 'MS Dollar' 'US Uollar'
#  'US Xollar' 'USP' 'KS Dollar' 'USL' 'US DolFar' 'UOD' 'UZD' 'US DolVar'
#  'Csd' 'USB' 'US DoJlar' 'PSD' 'US DoYlar' 'UAD' 'USU' 'YS Dollar'
#  'IS Dollar' 'XSD' 'US DoAlar' 'Rs dollar' 'US DOLLTR' 'UPD' 'UR Dollar'
#  'QS DOLLAR' 'UED' 'US DollaZ' 'US DollaV' 'USK' 'US DYllar' 'US DLllar'
#  'USZ' 'US Follar' 'UQD' 'LS Dollar' 'AS Dollar' 'us dollRr' 'USH'
#  'US DOLKAR' 'US DoPlar' 'USJ' 'UKD' 'US DollLr' 'US DollaY' 'XS Dollar'
#  'VSD' 'US DolLar' 'CSD' 'US Eollar' 'US DoLlar' 'US DoNlar' 'us dollaR'
#  'UE DOLLAR' 'DSD' 'UBD' 'US DollNr' 'SSD' 'VS Dollar' 'US DoDlar' 'UWD'
#  'BSD' 'UND' 'US Gollar' 'USA' 'US DIllar' 'us dolSar' 'US DOLLBR' 'WSD'
#  'US Mollar' 'UUD' 'uX dollar' 'Ls dollar' 'USIDollar' 'UST' 'USDDollar'
#  'usC' 'UYD' 'UVD' 'USM' 'US DollMr' 'Zsd' 'TSD' 'Nsd' 'FS Dollar' 'USE'
#  'ES Dollar' 'ZS Dollar' 'us dollNr' 'US DPllar' 'US DOllar' 'UR DOLLAR'
#  'US Hollar' 'DS Dollar' 'US DWllar' 'usNdollar' 'UFD' 'UB Dollar'
#  'US Collar' 'US Wollar' 'UG Dollar' 'UO Dollar' 'US DollaA' 'UN Dollar'
#  'SS Dollar' 'US DCLLAR' 'uK dollar' 'Gsd' 'UJ Dollar' 'UW Dollar'
#  'US DollDr' 'US DollJr' 'UT Dollar' 'US DolAar' 'Xsd' 'US DWLLAR' 'uVd'
#  'us dollaG' 'US DollaF' 'UT DOLLAR' 'GS DOLLAR' 'UDD' 'US DolTar' 'ULD'
#  'US DollaM' 'USNDollar' 'CS DOLLAR' 'BS Dollar' 'US DoSlar' 'US DoIlar'
#  'US DolIar' 'US DTllar' 'usP' 'SS DOLLAR' 'USTDollar' 'US DolYar' 'UJD'
#  'US DollFr' 'US DOLLUR' 'USY' 'Ysd' 'US DOALAR' 'US DEllar' 'Psd' 'FSD'
#  'US DOSLAR' 'US DoVlar' 'US DALLAR' 'US DBllar' 'NS Dollar' 'US DOLPAR'
#  'usEdollar' 'US DollAr' 'USO' 'USPDollar' 'UHD' 'US DOLLAT' 'US DollZr'
#  'USG' 'UZ DOLLAR' 'us dollMr' 'USQ' 'US DollPr' 'USC' 'US Rollar'
#  'US DollaQ' 'UU DOLLAR' 'USS' 'us dollKr' 'US DDllar' 'USSDOLLAR'
#  'USLDollar' 'US Yollar' 'USI' 'JSD' 'US DolOar' 'UI Dollar' 'us Lollar'
#  'uTd' 'US DolCar' 'usA' 'US DOULAR' 'US DODLAR' 'Qsd' 'uS dollar'
#  'US DollaX' 'UV Dollar' 'uKd' 'UC DOLLAR' 'us dolDar' 'US DollaP'
#  'USGDollar' 'UCD' 'US DollaO' 'US DOPLAR' 'UTD' 'US DolJar' 'US DOGLAR'
#  'US DollRr' 'Cs dollar' 'US DoKlar' 'uV dollar' 'USCDollar' 'US DolWar'
#  'US DolZar' 'UC Dollar' 'NSD' 'us Follar' 'US DollaD' 'UF Dollar'
#  'USVDOLLAR' 'USXDollar' 'US DollIr' 'US DoRlar' 'USVDollar' 'OSD'
#  'US DollaI' 'USZDollar' 'usAdollar' 'US DolMar' 'US DoQlar' 'Ksd' 'usV'
#  'UA Dollar' 'US DolDar' 'uNd' 'US DolUar' 'US DJllar' 'us dXllar' 'GSD'
#  'US DOLLAX' 'US DoFlar' 'UXD' 'usGdollar' 'usR' 'US Kollar' 'us dJllar'
#  'Dsd' 'US Nollar' 'Msd' 'US DOMLAR' 'US DoXlar' 'US DollXr' 'URD'
#  'US DolPar' 'uWd' 'USHDollar' 'US Pollar' 'UMD' 'US DollaL' 'US DollCr'
#  'Lsd' 'us dNllar' 'OS Dollar' 'UO DOLLAR' 'US DULLAR' 'us dolMar'
#  'QS Dollar' 'UP DOLLAR' 'US DolGar' 'USYDollar' 'US DoClar' 'US DQllar'
#  'US DOLLHR' 'US DCllar' 'US DSLLAR' 'US DHllar' 'US DollaU' 'uQd'
#  'HS Dollar' 'US DNllar' 'USW' 'US DFLLAR' 'US DoBlar' 'US DOLLKR'
#  'US DollBr' 'USFDollar' 'CS Dollar' 'PS Dollar' 'US DoWlar' 'US Sollar'
#  'US DollaR' 'US DollaB' 'USSDollar' 'USF' 'UGD' 'usB' 'us dFllar'
#  'US DHLLAR' 'US DZllar' 'US DOLRAR' 'UL Dollar' 'US Zollar' 'US DollaE'
#  'us dollaW' 'ESD' 'us dollaE' 'usQ' 'USIDOLLAR' 'US DRllar' 'us doOlar'
#  'UY DOLLAR' 'US DolHar' 'UM Dollar' 'US Tollar' 'US DollEr' 'US SOLLAR'
#  'UD Dollar' 'us dolZar' 'US DoTlar' 'US DoZlar' 'GS Dollar' 'USEDollar'
#  'US DUllar' 'US DOLLAU' 'US DollaW' 'USQDOLLAR' 'US DTLLAR' 'uFd'
#  'USODollar' 'USADollar' 'US DOLLAZ' 'RS Dollar' 'US DoHlar' 'US DOLLYR'
#  'US DoGlar' 'USJDOLLAR' 'uLd' 'US DolKar' 'US DollaK' 'us Rollar'
#  'Xs dollar' 'Bs dollar' 'US DolSar' 'US DollUr' 'uL dollar' 'uAd'
#  'US DFllar' 'USWDollar' 'UP Dollar' 'us dollXr' 'USHDOLLAR' 'US DSllar'
#  'USJDollar' 'usL' 'US DollaG' 'US DOTLAR' 'XS DOLLAR' 'NS DOLLAR'
#  'TS DOLLAR' 'us Iollar' 'US DolQar' 'us dolHar' 'us Jollar' 'us dLllar'
#  'US DollQr' 'US DGllar' 'uY dollar' 'US DMllar' 'AS DOLLAR' 'US DoElar'
#  'USBDollar' 'us dolVar' 'uXd' 'USGDOLLAR' 'USQDollar' 'US DOLZAR'
#  'US VOLLAR' 'us doLlar' 'us dolUar' 'Bsd' 'uC dollar' 'us doNlar' 'Rsd'
#  'usF' 'uCd' 'usH' 'us doFlar' 'us Bollar' 'Usd' 'US UOLLAR' 'US DOLLRR'
#  'us Wollar' 'Vsd' 'US DOLLAS' 'us dollLr' 'US Lollar' 'UQ Dollar'
#  'Ms dollar' 'uZ dollar' 'US DollOr' 'usI' 'US DOLLWR' 'JS Dollar'
#  'us dollaC' 'US DKLLAR' 'uJd' 'US Qollar' 'US DOVLAR' 'us doJlar'
#  'uO dollar' 'Wsd' 'US DollWr' 'USLDOLLAR' 'uDd' 'USMDOLLAR' 'QSD'
#  'UZ Dollar' 'US DolRar' 'Ts dollar' 'us dollUr' 'uMd' 'UU Dollar'
#  'us dollaB' 'JS DOLLAR' 'USMDollar' 'us Nollar' 'us dYllar' 'US DollaH'
#  'US DOOLAR' 'uId' 'US QOLLAR' 'US DollaC' 'US MOLLAR' 'us dolNar' 'Ssd'
#  'US DollKr' 'USXDOLLAR' 'US DolXar' 'RS DOLLAR' 'US DPLLAR' 'UX DOLLAR'
#  'uGd' 'US DOLCAR' 'usXdollar' 'UW DOLLAR' 'US DollaN' 'uHd' 'BS DOLLAR'
#  'US DOWLAR' 'US DYLLAR' 'us dollaQ' 'USUDollar' 'us Qollar' 'USBDOLLAR'
#  'us dollEr' 'US DOCLAR' 'USUDOLLAR' 'uB dollar' 'us dollaV' 'US DOILAR'
#  'VS DOLLAR' 'us dolTar' 'US DOLBAR' 'uPd' 'us dollaT' 'usW' 'US DOQLAR'
#  'US WOLLAR' 'usVdollar' 'USCDOLLAR' 'us dGllar' 'US Oollar' 'usZ' 'usU'
#  'us dolKar' 'uT dollar' 'UF DOLLAR' 'UK DOLLAR' 'US DVLLAR' 'USFDOLLAR'
#  'US DOLLPR' 'us doWlar' 'US DOLLJR' 'Ss dollar' 'us dolWar' 'Js dollar'
#  'usIdollar' 'us Eollar' 'uOd' 'US DVllar' 'us dollaN' 'us Collar'
#  'us doAlar' 'US Iollar' 'TS Dollar' 'US DOLLFR' 'us dollVr' 'US DOLLAV'
#  'US DORLAR' 'us dolGar' 'uSd' 'US DOLEAR' 'usD' 'us dollaI' 'usBdollar'
#  'US NOLLAR' 'us dolBar' 'US DOLOAR' 'US DOLMAR' 'US DOKLAR' 'USKDOLLAR'
#  'uEd' 'Qs dollar' 'uRd' 'us dolPar' 'usE' 'US DollSr' 'WS DOLLAR'
#  'UJ DOLLAR' 'usJ' 'US DOJLAR' 'US LOLLAR' 'USRDOLLAR' 'us doHlar'
#  'USEDOLLAR' 'uU dollar' 'US DOLLAL' 'usDdollar' 'UH DOLLAR' 'us doUlar'
#  'Ds dollar' 'us dolAar' 'IS DOLLAR' 'us dollZr' 'us doSlar' 'usY'
#  'US DOLLAY' 'US DOLLAI' 'uUd' 'US DOLTAR' 'US DOLLAM' 'uN dollar'
#  'us dDllar' 'us dollPr' 'us dollSr' 'Tsd' 'UM DOLLAR' 'US DOLLER'
#  'US Bollar' 'US DOLLLR' 'US DRLLAR' 'US DOLLAB' 'USNDOLLAR' 'US DOLLAC'
#  'UI DOLLAR' 'us dollaZ' 'us dSllar' 'us doClar' 'US DOELAR' 'uZd'
#  'US DLLLAR' 'UA DOLLAR' 'us doGlar' 'us dolIar' 'Ks dollar' 'usYdollar'
#  'USWDOLLAR' 'As dollar' 'Esd' 'US DJLLAR' 'uBd' 'Zs dollar' 'USYDOLLAR'
#  'us dZllar' 'usN' 'usPdollar' 'us Dollar' 'Ns dollar' 'us dollWr' 'Asd'
#  'US DOHLAR' 'US DOLLZR' 'US DDLLAR' 'usRdollar' 'us dollQr' 'usUdollar'
#  'us doElar' 'US DMLLAR' 'Os dollar' 'us dollaH' 'uI dollar' 'US DONLAR'
#  'us dCllar' 'FS DOLLAR' 'usSdollar' 'US GOLLAR' 'us dIllar' 'us dolJar'
#  'US DOLLAF' 'US DOLLQR' 'Jsd' 'usOdollar' 'US DNLLAR' 'KS DOLLAR'
#  'us dolLar' 'us dTllar' 'Ws dollar' 'usLdollar' 'us dUllar' 'us dMllar'
#  'us dollaK' 'us Tollar' 'uE dollar' 'ES DOLLAR' 'us dQllar' 'YS DOLLAR'
#  'US DOLLIR' 'Fsd' 'us dollCr' 'US OOLLAR' 'US DOLUAR' 'usS' 'USDDOLLAR'
#  'usO' 'usX' 'US DOYLAR' 'us doRlar' 'US COLLAR' 'US KOLLAR' 'us dollAr'
#  'US DOLSAR' 'US DOLLAW' 'us dollOr' 'us dollaA' 'US HOLLAR' 'Is dollar'
#  'US DOLAAR' 'uG dollar' 'US DQLLAR' 'us dollJr' 'US DOLLDR' 'USTDOLLAR'
#  'usM' 'US DOLGAR' 'USADOLLAR' 'Ys dollar' 'usFdollar' 'UL DOLLAR'
#  'US EOLLAR' 'us dAllar' 'us dolXar' 'us doVlar' 'us Kollar' 'us Sollar'
#  'uA dollar' 'US DZLLAR' 'us doXlar' 'US DOLLAN' 'us dollaM' 'us doTlar'
#  'us dolCar' 'US DOLLXR' 'US DOLLSR' 'PS DOLLAR' 'us dPllar' 'uQ dollar'
#  'uYd' 'US DOLVAR' 'US IOLLAR' 'US ZOLLAR' 'us dollDr' 'Es dollar'
#  'us dollaO' 'us dollaF' 'us dollBr' 'us Zollar' 'US DOLQAR' 'Ps dollar'
#  'US DOLLAQ' 'uW dollar' 'uP dollar' 'us dolOar' 'uJ dollar' 'US YOLLAR'
#  'USODOLLAR' 'US DOLNAR' 'usTdollar']

# %%
currency_dicionario2 = {
    "us dollar": "USD",
    "US Dollar": "USD",
    "$": "USD",
    "usd": "USD",
    "USD": "USD",
    "US DOLLAR": "USD",
    "US DollaS": "USD",
    "US DBLLAR": "USD",
    "US DXllar": "USD",
    "US uollar": "USD",
    "US DolEar": "USD",
    "UE Dollar": "USD",
}

for variation in [
    'us dollar', 'US Vollar', 'WS Dollar', 'RSD', 'LSD', 'YSD', 'UID', 'ASD',
    'US DollGr', 'US DollVr', 'USN', 'HSD', 'US DKllar', 'US DollTr', 'UX Dollar',
    'US DoMlar', 'UY Dollar', 'US DOLYAR', 'US Jollar', 'US DolNar', 'USKDollar',
    'Isd', 'UH Dollar', 'US DollaT', 'ISD', 'US DAllar', 'usG', 'US DoOlar', 'USV',
    'usT', 'US DollYr', 'US DOLLOR', 'KSD', 'UK Dollar', 'US Aollar', 'US DollHr',
    'US DolBar', 'ZSD', 'USX', 'US DoUlar', 'MSD', 'MS Dollar', 'US Uollar',
    'US Xollar', 'USP', 'KS Dollar', 'USL', 'US DolFar', 'UOD', 'UZD', 'US DolVar',
    'Csd', 'USB', 'US DoJlar', 'PSD', 'US DoYlar', 'UAD', 'USU', 'YS Dollar',
    'IS Dollar', 'XSD', 'US DoAlar', 'Rs dollar', 'US DOLLTR', 'UPD', 'UR Dollar',
    'QS DOLLAR', 'UED', 'US DollaZ', 'US DollaV', 'USK', 'US DYllar', 'US DLllar',
    'USZ', 'US Follar', 'UQD', 'LS Dollar', 'AS Dollar', 'us dollRr', 'USH',
    'US DOLKAR', 'US DoPlar', 'USJ', 'UKD', 'US DollLr', 'US DollaY', 'XS Dollar',
    'VSD', 'US DolLar', 'CSD', 'US Eollar', 'US DoLlar', 'US DoNlar', 'us dollaR',
    'UE DOLLAR', 'DSD', 'UBD', 'US DollNr', 'SSD', 'VS Dollar', 'US DoDlar', 'UWD',
    'BSD', 'UND', 'US Gollar', 'USA', 'US DIllar', 'us dolSar', 'US DOLLBR', 'WSD',
    'US Mollar', 'UUD', 'uX dollar', 'Ls dollar', 'USIDollar', 'UST', 'USDDollar',
    'usC', 'UYD', 'UVD', 'USM', 'US DollMr', 'Zsd', 'TSD', 'Nsd', 'FS Dollar', 'USE',
    'ES Dollar', 'ZS Dollar', 'us dollNr', 'US DPllar', 'US DOllar', 'UR DOLLAR',
    'US Hollar', 'DS Dollar', 'US DWllar', 'usNdollar', 'UFD', 'UB Dollar',
    'US Collar', 'US Wollar', 'UG Dollar', 'UO Dollar', 'US DollaA', 'UN Dollar',
    'SS Dollar', 'US DCLLAR', 'uK dollar', 'Gsd', 'UJ Dollar', 'UW Dollar',
    'US DollDr', 'US DollJr', 'UT Dollar', 'US DolAar', 'Xsd', 'US DWLLAR', 'uVd',
    'us dollaG', 'US DollaF', 'UT DOLLAR', 'GS DOLLAR', 'UDD', 'US DolTar', 'ULD',
    'US DollaM', 'USNDollar', 'CS DOLLAR', 'BS Dollar', 'US DoSlar', 'US DoIlar',
    'US DolIar', 'US DTllar', 'usP', 'SS DOLLAR', 'USTDollar', 'US DolYar', 'UJD',
    'US DollFr', 'US DOLLUR', 'USY', 'Ysd', 'US DOALAR', 'US DEllar', 'Psd', 'FSD',
    'US DOSLAR', 'US DoVlar', 'US DALLAR', 'US DBllar', 'NS Dollar', 'US DOLPAR',
    'usEdollar', 'US DollAr', 'USO', 'USPDollar', 'UHD', 'US DOLLAT', 'US DollZr',
    'USG', 'UZ DOLLAR', 'us dollMr', 'USQ', 'US DollPr', 'USC', 'US Rollar',
    'US DollaQ', 'UU DOLLAR', 'USS', 'us dollKr', 'US DDllar', 'USSDOLLAR',
    'USLDollar', 'US Yollar', 'USI', 'JSD', 'US DolOar', 'UI Dollar', 'us Lollar',
    'uTd', 'US DolCar', 'usA', 'US DOULAR', 'US DODLAR', 'Qsd', 'uS dollar',
    'US DollaX', 'UV Dollar', 'uKd', 'UC DOLLAR', 'us dolDar', 'US DollaP',
    'USGDollar', 'UCD', 'US DollaO', 'US DOPLAR', 'UTD', 'US DolJar', 'US DOGLAR',
    'US DollRr', 'Cs dollar', 'US DoKlar', 'uV dollar', 'USCDollar', 'US DolWar',
    'US DolZar', 'UC Dollar', 'NSD', 'us Follar', 'US DollaD', 'UF Dollar',
    'USVDOLLAR', 'USXDollar', 'US DollIr', 'US DoRlar', 'USVDollar', 'OSD',
    'US DollaI', 'USZDollar', 'usAdollar', 'US DolMar', 'US DoQlar', 'Ksd', 'usV',
    'UA Dollar', 'US DolDar', 'uNd', 'US DolUar', 'US DJllar', 'us dXllar', 'GSD',
    'US DOLLAX', 'US DoFlar', 'UXD', 'usGdollar', 'usR', 'US Kollar', 'us dJllar',
    'Dsd', 'US Nollar', 'Msd', 'US DOMLAR', 'US DoXlar', 'US DollXr', 'URD',
    'US DolPar', 'uWd', 'USHDollar', 'US Pollar', 'UMD', 'US DollaL', 'US DollCr',
    'Lsd', 'us dNllar', 'OS Dollar', 'UO DOLLAR', 'US DULLAR', 'us dolMar',
    'QS Dollar', 'UP DOLLAR', 'US DolGar', 'USYDollar', 'US DoClar', 'US DQllar',
    'US DOLLHR', 'US DCllar', 'US DSLLAR', 'US DHllar', 'US DollaU', 'uQd',
    'HS Dollar', 'US DNllar', 'USW', 'US DFLLAR', 'US DoBlar', 'US DOLLKR',
    'US DollBr', 'USFDollar', 'CS Dollar', 'PS Dollar', 'US DoWlar', 'US Sollar',
    'US DollaR', 'US DollaB', 'USSDollar', 'USF', 'UGD', 'usB', 'us dFllar',
    'US DHLLAR', 'US DZllar', 'US DOLRAR', 'UL Dollar', 'US Zollar', 'US DollaE',
    'us dollaW', 'ESD', 'us dollaE', 'usQ', 'USIDOLLAR', 'US DRllar', 'us doOlar',
    'UY DOLLAR', 'US DolHar', 'UM Dollar', 'US Tollar', 'US DollEr', 'US SOLLAR',
    'UD Dollar', 'us dolZar', 'US DoTlar', 'US DoZlar', 'GS Dollar', 'USEDollar',
    'US DUllar', 'US DOLLAU', 'US DollaW', 'USQDOLLAR', 'US DTLLAR', 'uFd',
    'USODollar', 'USADollar', 'US DOLLAZ', 'RS Dollar', 'US DoHlar', 'US DOLLYR',
    'US DoGlar', 'USJDOLLAR', 'uLd', 'US DolKar', 'US DollaK', 'us Rollar',
    'Xs dollar', 'Bs dollar', 'US DolSar', 'US DollUr', 'uL dollar', 'uAd',
    'US DFllar', 'USWDollar', 'UP Dollar', 'us dollXr', 'USHDOLLAR', 'US DSllar',
    'USJDollar', 'usL', 'US DollaG', 'US DOTLAR', 'XS DOLLAR', 'NS DOLLAR',
    'TS DOLLAR', 'us Iollar', 'US DolQar', 'us dolHar', 'us Jollar', 'us dLllar',
    'US DollQr', 'US DGllar', 'uY dollar', 'US DMllar', 'AS DOLLAR', 'US DoElar',
    'USBDollar', 'us dolVar', 'uXd', 'USGDOLLAR', 'USQDollar', 'US DOLZAR',
    'US VOLLAR', 'us doLlar', 'us dolUar', 'Bsd', 'uC dollar', 'us doNlar', 'Rsd',
    'usF', 'uCd', 'usH', 'us doFlar', 'us Bollar', 'Usd', 'US UOLLAR', 'US DOLLRR',
    'us Wollar', 'Vsd', 'US DOLLAS', 'us dollLr', 'US Lollar', 'UQ Dollar',
    'Ms dollar', 'uZ dollar', 'US DollOr', 'usI', 'US DOLLWR', 'JS Dollar',
    'us dollaC', 'US DKLLAR', 'uJd', 'US Qollar', 'US DOVLAR', 'us doJlar',
    'uO dollar', 'Wsd', 'US DollWr', 'USLDOLLAR', 'uDd', 'USMDOLLAR', 'QSD',
    'UZ Dollar', 'US DolRar', 'Ts dollar', 'us dollUr', 'uMd', 'UU Dollar',
    'us dollaB', 'JS DOLLAR', 'USMDollar', 'us Nollar', 'us dYllar', 'US DollaH',
    'US DOOLAR', 'uId', 'US QOLLAR', 'US DollaC', 'US MOLLAR', 'us dolNar', 'Ssd',
    'US DollKr', 'USXDOLLAR', 'US DolXar', 'RS DOLLAR', 'US DPLLAR', 'UX DOLLAR',
    'uGd', 'US DOLCAR', 'usXdollar', 'UW DOLLAR', 'US DollaN', 'uHd', 'BS DOLLAR',
    'US DOWLAR', 'US DYLLAR', 'us dollaQ', 'USUDollar', 'us Qollar', 'USBDOLLAR',
    'us dollEr', 'US DOCLAR', 'USUDOLLAR', 'uB dollar', 'us dollaV', 'US DOILAR',
    'VS DOLLAR', 'us dolTar', 'US DOLBAR', 'uPd', 'us dollaT', 'usW', 'US DOQLAR',
    'US WOLLAR', 'usVdollar', 'USCDOLLAR', 'us dGllar', 'US Oollar', 'usZ', 'usU',
    'us dolKar', 'uT dollar', 'UF DOLLAR', 'UK DOLLAR', 'US DVLLAR', 'USFDOLLAR',
    'US DOLLPR', 'us doWlar', 'US DOLLJR', 'Ss dollar', 'us dolWar', 'Js dollar',
    'usIdollar', 'us Eollar', 'uOd', 'US DVllar', 'us dollaN', 'us Collar',
    'us doAlar', 'US Iollar', 'TS Dollar', 'US DOLLFR', 'us dollVr', 'US DOLLAV',
    'US DORLAR', 'us dolGar', 'uSd', 'US DOLEAR', 'usD', 'us dollaI', 'usBdollar',
    'US NOLLAR', 'us dolBar', 'US DOLOAR', 'US DOLMAR', 'US DOKLAR', 'USKDOLLAR',
    'uEd', 'Qs dollar', 'uRd', 'us dolPar', 'usE', 'US DollSr', 'WS DOLLAR',
    'UJ DOLLAR', 'usJ', 'US DOJLAR', 'US LOLLAR', 'USRDOLLAR', 'us doHlar',
    'USEDOLLAR', 'uU dollar', 'US DOLLAL', 'usDdollar', 'UH DOLLAR', 'us doUlar',
    'Ds dollar', 'us dolAar', 'IS DOLLAR', 'us dollZr', 'us doSlar', 'usY',
    'US DOLLAY', 'US DOLLAI', 'uUd', 'US DOLTAR', 'US DOLLAM', 'uN dollar',
    'us dDllar', 'us dollPr', 'us dollSr', 'Tsd', 'UM DOLLAR', 'US DOLLER',
    'US Bollar', 'US DOLLLR', 'US DRLLAR', 'US DOLLAB', 'USNDOLLAR', 'US DOLLAC',
    'UI DOLLAR', 'us dollaZ', 'us dSllar', 'us doClar', 'US DOELAR', 'uZd',
    'US DLLLAR', 'UA DOLLAR', 'us doGlar', 'us dolIar', 'Ks dollar', 'usYdollar',
    'USWDOLLAR', 'As dollar', 'Esd', 'US DJLLAR', 'uBd', 'Zs dollar', 'USYDOLLAR',
    'us dZllar', 'usN', 'usPdollar', 'us Dollar', 'Ns dollar', 'us dollWr', 'Asd',
    'US DOHLAR', 'US DOLLZR', 'US DDLLAR', 'usRdollar', 'us dollQr', 'usUdollar',
    'us doElar', 'US DMLLAR', 'Os dollar', 'us dollaH', 'uI dollar', 'US DONLAR',
    'us dCllar', 'FS DOLLAR', 'usSdollar', 'US GOLLAR', 'us dIllar', 'us dolJar',
    'US DOLLAF', 'US DOLLQR', 'Jsd', 'usOdollar', 'US DNLLAR', 'KS DOLLAR',
    'us dolLar', 'us dTllar', 'Ws dollar', 'usLdollar', 'us dUllar', 'us dMllar',
    'us dollaK', 'us Tollar', 'uE dollar', 'ES DOLLAR', 'us dQllar', 'YS DOLLAR',
    'US DOLLIR', 'Fsd', 'us dollCr', 'US OOLLAR', 'US DOLUAR', 'usS', 'USDDOLLAR',
    'usO', 'usX', 'US DOYLAR', 'us doRlar', 'US COLLAR', 'US KOLLAR', 'us dollAr',
    'US DOLSAR', 'US DOLLAW', 'us dollOr', 'us dollaA', 'US HOLLAR', 'Is dollar',
    'US DOLAAR', 'uG dollar', 'US DQLLAR', 'us dollJr', 'US DOLLDR', 'USTDOLLAR',
    'usM', 'US DOLGAR', 'USADOLLAR', 'Ys dollar', 'usFdollar', 'UL DOLLAR',
    'US EOLLAR', 'us dAllar', 'us dolXar', 'us doVlar', 'us Kollar', 'us Sollar',
    'uA dollar', 'US DZLLAR', 'us doXlar', 'US DOLLAN', 'us dollaM', 'us doTlar',
    'us dolCar', 'US DOLLXR', 'US DOLLSR', 'PS DOLLAR', 'us dPllar', 'uQ dollar',
    'uYd', 'US DOLVAR', 'US IOLLAR', 'US ZOLLAR', 'us dollDr', 'Es dollar',
    'us dollaO', 'us dollaF', 'us dollBr', 'us Zollar', 'US DOLQAR', 'Ps dollar',
    'US DOLLAQ', 'uW dollar', 'uP dollar', 'us dolOar', 'uJ dollar', 'US YOLLAR',
    'USODOLLAR', 'US DOLNAR', 'usTdollar'
]:
    currency_dicionario2[variation] = "USD"

# %%
base2_temp['Currency'] = base2_temp['Currency'].replace(currency_dicionario2)

base2_temp['Currency'] = base2_temp['Currency'].str.upper()

print(base2_temp['Currency'].head(10))
# Out:
# 0    USD
# 1    USD
# 2    USD
# 3    USD
# 4    USD
# 5    USD
# 6    USD
# 7    USD
# 8    USD
# 9    USD
# Name: Currency, dtype: object

# %% [markdown]
# -> Aqui vemos que a coluna foi toda padronizada para um só valor

# %%
valores_unicos = base2_temp['Currency'].unique()

print(valores_unicos)
# Out:
# ['USD']

# %% [markdown]
# ---
# #### **Tratamento da coluna Marketcap**

# %% [markdown]
# -> A ideia inicial do tratamento, apos uma analise visual, era saber quais palavras, letras e simbolos estavam misturados nos inteiros para poder tratar.
#
# ->Então partimos para o tratamento mais rapido e pratico que era a retirada de virgulas e $

# %%
base2_temp['MarketCap'] = base2_temp['MarketCap'].astype(str).str.replace(',', '', regex=False)
base2_temp['MarketCap'] = base2_temp['MarketCap'].astype(str).str.replace('$', '', regex=False)

# %% [markdown]
# -> Verificação das primeiras linhas que ja tinham algumas virgulas e $

# %%
base2_temp.head(20)
# Out:
#     ID Exchange Currency       MarketCap PE Ratio     EPS Next Earnings  \
# 0    1     NYSE      USD    370815220190    27.40   16.68  May 19, 2025
# 1    2      TSE      USD   1289775810656    90.13    0,57    06-23-2025
# 2    3      LSE      USD     97815908000   $15.67   18.17    07-21-2025
# 3    4     HKEX      USD   1658573090566    83.90   -4.82    23/07/2025
# 4    5   NASDAQ      USD    315341356874    79.86    5.67    08/06/2025
# 5    6      TSX      USD   1324763810463    76.46   18.45    03/08/2025
# 6    7   NASDAQ      USD   1368238210098    73,04   -Z.44    08-06-2025
# 7    8      TSX      USD   1250223756881    65.29   19.56    05/07/2025
# 8    9     AMEX      USD   1543749651001    42.29    2.46    06/06/2025
# 9   10     AMEX      USD   1532453560561    55.93   -4.76    2025-05-17
# 10  11      LSE      USD   1095702991467    90.86    8.37    06-02-2025
# 11  12      LSE      USD   1433641721149   $25.89   -1.71    24/07/2025
# 12  13   NASDAQ      USD     1340038.14M    69,22   13.94    06-18-2025
# 13  14      TSE      USD    931636261330    54.08   15.23    2025-06-21
# 14  15     HKEX      USD     1211261.19M    50,27   $8.06    07-25-2025
# 15  16      SSE      USD  1794168804590K    85.68  $15.20  May 14, 2025
# 16  17     HKEX      USD   1687910571529   $92.09   15,40    03/06/2025
# 17  18     NYSE      USD   1513922987181    18.29   17.80    05-15-2025
# 18  19      SSE      USD    438492418606    85.47   11.39    05-15-2025
# 19  20      SSE      USD   1198290710513    42.83  $10.49    05-20-2025
#
#    Previous Close        Day Range
# 0          567.57   X095.58-898.36
# 1         $185.1Z    907.52-552.85
# 2          823.07  1380.78-1361.69
# 3          179.88    457.99-138.11
# 4        $1004.79    644.16-920.32
# 5          530.09   849.09-1331.72
# 6          445.71   1020.75-139.13
# 7          482.83    386.80-852.52
# 8          361.15    868.17-589.25
# 9         1107.40   749.11-1066.47
# 10        1263.99   422.18-1466.15
# 11         573.07  1349.97-1398.46
# 12         406.6Z     94.21-322.52
# 13         780.09    769.96-686E77
# 14         956.81   1472.58-293.39
# 15        1059.11   374.94-1040.02
# 16         185.68   407.95-1105.40
# 17         715.31    675.35-483.14
# 18         223.32   664.69-1301.57
# 19         260.73   994.50-1291.40

# %% [markdown]
# -> Após removermos os símbolos de pontuação, como vírgulas e cifrões, partimos para o segundo problema da coluna Market Cap.
#
# -> Identificamos que os valores estavam acompanhados de letras como M, K, B, entre outros sufixos que representam grandezas (mil, milhão, bilhão etc.). Após análise e discussão em grupo, concluímos que o valor médio de capitalização de mercado das empresas gira em torno de 13 dígitos.
# Com base nessa constatação, desenvolvemos uma função chamada converter_market_cap (localizada na seção Funções generalizadas) que realiza os seguintes passos:
#
# - Identifica e extrai o número e o sufixo (ex: "12.3B")
#
# - Converte o número para o valor real multiplicando pelo fator correto (ex: B → 1 bilhão)
#
# - Verifica se o valor convertido possui menos de 14 digitos
#
# - Se sim, o valor é mantido convertido.
#
# - Se não, o valor original é mantido, pois é considerado fora do padrão esperado.
#
# Essa abordagem nos permitiu padronizar os valores válidos de Market.

# %% [markdown]
# ###### **Verificação dos sufixos que estão na coluna**

# %%
resultado = extrair_sufixos_unicos(base2_temp['MarketCap'])
print(resultado)
# Out:
# ['Billion', 'K', 'M', 'MK', 'Mb', 'b']

# %% [markdown]
# ###### **Verificação e aplicação do tratamento**

# %%
base2_temp = converter_market_cap(base2_temp, 'MarketCap')

# %%
resultado = extrair_sufixos_unicos(base2_temp['MarketCap'])
print(resultado)
# Out:
# []

# %% [markdown]
# -> Verificação final com uma amostra simples

# %%
base2_temp.head(20)
# Out:
#     ID Exchange Currency      MarketCap PE Ratio     EPS Next Earnings  \
# 0    1     NYSE      USD   370815220190    27.40   16.68  May 19, 2025
# 1    2      TSE      USD  1289775810656    90.13    0,57    06-23-2025
# 2    3      LSE      USD    97815908000   $15.67   18.17    07-21-2025
# 3    4     HKEX      USD  1658573090566    83.90   -4.82    23/07/2025
# 4    5   NASDAQ      USD   315341356874    79.86    5.67    08/06/2025
# 5    6      TSX      USD  1324763810463    76.46   18.45    03/08/2025
# 6    7   NASDAQ      USD  1368238210098    73,04   -Z.44    08-06-2025
# 7    8      TSX      USD  1250223756881    65.29   19.56    05/07/2025
# 8    9     AMEX      USD  1543749651001    42.29    2.46    06/06/2025
# 9   10     AMEX      USD  1532453560561    55.93   -4.76    2025-05-17
# 10  11      LSE      USD  1095702991467    90.86    8.37    06-02-2025
# 11  12      LSE      USD  1433641721149   $25.89   -1.71    24/07/2025
# 12  13   NASDAQ      USD        1340038    69,22   13.94    06-18-2025
# 13  14      TSE      USD   931636261330    54.08   15.23    2025-06-21
# 14  15     HKEX      USD        1211261    50,27   $8.06    07-25-2025
# 15  16      SSE      USD  1794168804590    85.68  $15.20  May 14, 2025
# 16  17     HKEX      USD  1687910571529   $92.09   15,40    03/06/2025
# 17  18     NYSE      USD  1513922987181    18.29   17.80    05-15-2025
# 18  19      SSE      USD   438492418606    85.47   11.39    05-15-2025
# 19  20      SSE      USD  1198290710513    42.83  $10.49    05-20-2025
#
#    Previous Close        Day Range
# 0          567.57   X095.58-898.36
# 1         $185.1Z    907.52-552.85
# 2          823.07  1380.78-1361.69
# 3          179.88    457.99-138.11
# 4        $1004.79    644.16-920.32
# 5          530.09   849.09-1331.72
# 6          445.71   1020.75-139.13
# 7          482.83    386.80-852.52
# 8          361.15    868.17-589.25
# 9         1107.40   749.11-1066.47
# 10        1263.99   422.18-1466.15
# 11         573.07  1349.97-1398.46
# 12         406.6Z     94.21-322.52
# 13         780.09    769.96-686E77
# 14         956.81   1472.58-293.39
# 15        1059.11   374.94-1040.02
# 16         185.68   407.95-1105.40
# 17         715.31    675.35-483.14
# 18         223.32   664.69-1301.57
# 19         260.73   994.50-1291.40

# %% [markdown]
# ---
# #### **Tratamento de PE Ratio**

# %% [markdown]
# -> Essa coluna apenas tem o problema de apresentar simbolos extras que não fazem parte da padronização, por exemplo $ e Z.
#
# -> Nosso objetivo vai ser limpar os $ e tratar o Z baseado noq o monitor falar segunda(WIP)
#
# -> O primeiro passo é encontrar valores que possam estar fora do padrao pa isso irei usar encontrar_simbolos para poder entender melhor o que tenho que fazer

# %%
encontrar_simbolos(base2_temp, 'PE Ratio')
# Out:
# {'$', ',', '.', 'Z'}

# %% [markdown]
# -> Após encontrar os simbolos, é visto que alguns numeros sao separados por virgula e precisamos mudar para ponto, bem como alguns numeros apresentam o simbolo $ e Z que precisam ser tratados

# %%
base2_temp['PE Ratio'] = base2_temp['PE Ratio'].astype(str).str.replace(',', '.', regex=False)
base2_temp['PE Ratio'] = base2_temp['PE Ratio'].astype(str).str.replace('$', '', regex=False)
base2_temp['PE Ratio'] = base2_temp['PE Ratio'].astype(str).str.replace('Z', '2', regex=False)

# %% [markdown]
# -> Verificando símbolos que podem ter sobrado

# %%
encontrar_simbolos(base2_temp, 'PE Ratio')
# Out:
# {'.'}

# %% [markdown]
# ---
# #### **Tratamento de EPS**

# %% [markdown]
# -> A ideia inicial de tratar essa coluna é analisar simbolos que não estão corretos para a padronização.
#
# -> Para isso usaremos a mesma função de antes, encontrar_simbolos

# %%
encontrar_simbolos(base2_temp, 'EPS')
# Out:
# {'$', ',', '-', '.', 'Z'}

# %% [markdown]
# -> Foi visto simbolos como $, virgula e Z que não fazem parte da padronização da coluna, dessa forma precisaremos tratá-los
#
# -> Seguiremos a mesma ideia de PE Ratio

# %%
base2_temp['EPS'] = base2_temp['EPS'].astype(str).str.replace(',', '.', regex=False)
base2_temp['EPS'] = base2_temp['EPS'].astype(str).str.replace('$', '', regex=False)
base2_temp['EPS'] = base2_temp['EPS'].astype(str).str.replace('Z', '2', regex=False)

# %% [markdown]
# -> Verificação dos símbolos que sobraram

# %%
encontrar_simbolos(base2_temp, 'EPS')
# Out:
# {'-', '.'}

# %% [markdown]
# ---
# #### **Tratamento de Previous Close**

# %% [markdown]
# -> Essa coluna também sofre do mesmo problema de PE Ratio e EPS, logo precisamos seguir a mesma logica que fizemos

# %%
encontrar_simbolos(base2_temp, 'Previous Close')
# Out:
# {'$', ',', '.', 'Z'}

# %% [markdown]
# -> Seguiremos a mesma logica, já que essa coluna apresenta o mesmo problema

# %%
base2_temp['Previous Close'] = base2_temp['Previous Close'].astype(str).str.replace(',', '.', regex=False)
base2_temp['Previous Close'] = base2_temp['Previous Close'].astype(str).str.replace('$', '', regex=False)
base2_temp['Previous Close'] = base2_temp['Previous Close'].astype(str).str.replace('Z', '2', regex=False)

# %%
encontrar_simbolos(base2_temp, 'Previous Close')
# Out:
# {'.'}

# %% [markdown]
# ---
# #### **Tratamento de Next Earnings**

# %% [markdown]
# -> Vamos tratar as datas na coluna para padronizar todas no formato dd-mm-yyyy

# %%
from dateutil import parser

def padronizar_data(data):
    try:
        data_convertida = parser.parse(str(data), dayfirst=False)
        return data_convertida.strftime('%d-%m-%Y')
    except Exception:
        return data

base2_temp['Next Earnings'] = base2_temp['Next Earnings'].apply(padronizar_data)

print(base2_temp['Next Earnings'].head(15))
# Out:
# 0     19-05-2025
# 1     23-06-2025
# 2     21-07-2025
# 3     23-07-2025
# 4     06-08-2025
# 5     08-03-2025
# 6     06-08-2025
# 7     07-05-2025
# 8     06-06-2025
# 9     17-05-2025
# 10    02-06-2025
# 11    24-07-2025
# 12    18-06-2025
# 13    21-06-2025
# 14    25-07-2025
# Name: Next Earnings, dtype: object

# %% [markdown]
# -> Nessa verificação é possível notar que ainda existem 2001 valores que ainda são considerados inválidos por diversos motivos

# %%
print(base2_temp['Next Earnings'].astype(str).str.extract(r'(\d{2}-\d{2}-\d{4})').isnull().sum())
print(base2_temp['Next Earnings'].unique())
# Out:
# 0    2001
# dtype: int64
# ['19-05-2025' '23-06-2025' '21-07-2025' ... '12/95/2013' '1/47/2009'
#  '3/93/2006']

# %% [markdown]
# -> Executando outra função para garantir que todas as datas sejam passadas para o formato correto e transformando em None os valores inválidos para que possam ser substituídos pela moda

# %%
# Função para padronizar a data no formato dd-mm-yyyy
def padronizar_data2(data):
    try:
        data_convertida = parser.parse(data, dayfirst=False)  # tenta interpretar a data
        return data_convertida.strftime("%d-%m-%Y")  # retorna no formato desejado
    except Exception:
        return None  # retorna None se não conseguir converter

# Aplicar a função à coluna "Next Earnings"
base2_temp['Next Earnings'] = base2_temp['Next Earnings'].apply(padronizar_data2)

# %% [markdown]
# -> Verificando se o tratamento deu certo, checando o número de linhas que está em outro formato

# %%
# Função para verificar se a data está no formato dd-mm-yyyy
def check_date_format(data):
    if data is None:
        return True
    try:
        pd.to_datetime(data, format='%d-%m-%Y', exact=True)
        return True
    except ValueError:
        return False

# Aplicar a função para verificar o formato e contar as datas que não correspondem
invalid_format_count = base2_temp['Next Earnings'].apply(lambda x: not check_date_format(x)).sum()

print(f"\nNúmero de datas em 'Next Earnings' que NÃO estão no formato dd-mm-yyyy: {invalid_format_count}")

# Visualizar as datas com formato inválido
invalid_dates = base2_temp[base2_temp['Next Earnings'].apply(lambda x: not check_date_format(x))]['Next Earnings']
print("\nDatas com formato inválido:")
print(invalid_dates)
# Out:
# Número de datas em 'Next Earnings' que NÃO estão no formato dd-mm-yyyy: 0
#
# Datas com formato inválido:
# Series([], Name: Next Earnings, dtype: object)

# %% [markdown]
# -> Substituindo os valores nulos pela moda das datas e checagem final

# %%
# Preencher os valores nulos da coluna 'Next Earnings' com a moda
mode_next_earnings = base2_temp['Next Earnings'].mode()[0] # Calcula a moda
base2_temp['Next Earnings'].fillna(mode_next_earnings, inplace=True) # Preenche os nulos com a moda

# Verificar se ainda existem valores nulos na coluna 'Next Earnings'
print("\nContagem de valores nulos após o preenchimento com a moda:")
print(base2_temp['Next Earnings'].isnull().sum())

print("\nPrimeiras linhas do DataFrame após o preenchimento:")
print(base2_temp.head())
# Out:
# Contagem de valores nulos após o preenchimento com a moda:
# 0
#
# Primeiras linhas do DataFrame após o preenchimento:
#    ID Exchange Currency      MarketCap PE Ratio    EPS Next Earnings  \
# 0   1     NYSE      USD   370815220190    27.40  16.68    19-05-2025
# 1   2      TSE      USD  1289775810656    90.13   0.57    23-06-2025
# 2   3      LSE      USD    97815908000    15.67  18.17    21-07-2025
# 3   4     HKEX      USD  1658573090566    83.90  -4.82    23-07-2025
# 4   5   NASDAQ      USD   315341356874    79.86   5.67    08-06-2025
#
#   Previous Close        Day Range
# 0         567.57   X095.58-898.36
# 1         185.12    907.52-552.85
# 2         823.07  1380.78-1361.69
# 3         179.88    457.99-138.11
# 4        1004.79    644.16-920.32
# <ipython-input-93-42a943686293>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base2_temp['Next Earnings'].fillna(mode_next_earnings, inplace=True) # Preenche os nulos com a moda

# %% [markdown]
# ---
#
# -> Agora vamos converter para o formato da biblioteca datetime () para facilitar nossas futuras análises

# %%
# Limpa a coluna Date antes da conversão
base2_temp['Next Earnings'] = base2_temp['Next Earnings'].astype(str).str.strip()

# Converte para datetime com formato explícito
base2_temp['Next Earnings'] = pd.to_datetime(base2_temp['Next Earnings'], format='%d-%m-%Y', errors='coerce')

# %% [markdown]
# ---
# #### **Tratamento da coluna Day Range**

# %% [markdown]
# -> Pensando já no merge(essa foi a ultima coluna que faltava) nós pensamos, ok ela determina a diferença do menor para o maior valor, mas nos temos uma coluna na 1 base que tambem fala sobre isso, a Low e High.
#
# -> Com esse pensamente, achamos justo refazer a coluna com os valores de low-high, colocando-a como float representado pela variância
#
# -> Mas obviamente tiveram outros pontos que nos levaram a pensar assim. O principal foi o fato de ter numeros com letras e tais letras iam de a-z  deixando inviavel um dicionaio ou algo do tipo.

# %% [markdown]
# -> Substituindo pela variância, temos:

# %%
# Utilizando variáveis temporárias por boa prática
base_tmp111 = base1.copy()

# Substituindo pelo High e Low da base1
base2_temp['Day Range'] = base_tmp111['High']-base_tmp111['Low']

# %% [markdown]
# -> Visualização das mudanças

# %%
base2_temp.head()
# Out:
#    ID Exchange Currency      MarketCap PE Ratio    EPS Next Earnings  \
# 0   1     NYSE      USD   370815220190    27.40  16.68    2025-05-19
# 1   2      TSE      USD  1289775810656    90.13   0.57    2025-06-23
# 2   3      LSE      USD    97815908000    15.67  18.17    2025-07-21
# 3   4     HKEX      USD  1658573090566    83.90  -4.82    2025-07-23
# 4   5   NASDAQ      USD   315341356874    79.86   5.67    2025-06-08
#
#   Previous Close  Day Range
# 0         567.57    1121.61
# 1         185.12     539.52
# 2         823.07    1133.94
# 3         179.88     925.46
# 4        1004.79    1085.19

# %% [markdown]
# -> Passando as mudanças para a base original

# %%
base2 = base2_temp.copy()

# %% [markdown]
# ---
# #### **Visualização final da padronização e limpeza da Base 2**

# %%
base2.head()
# Out:
#    ID Exchange Currency      MarketCap PE Ratio    EPS Next Earnings  \
# 0   1     NYSE      USD   370815220190    27.40  16.68    2025-05-19
# 1   2      TSE      USD  1289775810656    90.13   0.57    2025-06-23
# 2   3      LSE      USD    97815908000    15.67  18.17    2025-07-21
# 3   4     HKEX      USD  1658573090566    83.90  -4.82    2025-07-23
# 4   5   NASDAQ      USD   315341356874    79.86   5.67    2025-06-08
#
#   Previous Close  Day Range
# 0         567.57    1121.61
# 1         185.12     539.52
# 2         823.07    1133.94
# 3         179.88     925.46
# 4        1004.79    1085.19

# %% [markdown]
# ---
# ### **Etapa *Load***

# %% [markdown]
# -> Nessa última etapa, faremos a junção das duas bases limpas e padronizadas, gerando uma base final na qual trabalharemos a EDA

# %% [markdown]
# -> Para isso, nos basearemos no ID das duas bases para fazer o merge

# %%
# Junta as duas bases com base na coluna em comum ID
base_final = pd.merge(base1, base2, how = 'inner', on = 'ID')

# %% [markdown]
# -> Agora daremos uma visão geral na base final

# %%
base_final.head(10)
# Out:
#    ID       Date Ticker     Open     High     Low   Close  Adj Close  \
# 0   1 2023-09-03   META   909.63  1380.05  258.44  595.86      61.54
# 1   2 2024-08-28   NVDA   678.96   725.03  185.51  295.83     843.78
# 2   3 2022-05-10   INTU   831.86  1348.94  215.00  874.05     336.19
# 3   4 2017-12-26   NVDA   508.65  1111.85  186.39  511.49     952.63
# 4   5 2022-01-20   WORK   692.20  1425.94  340.75  378.58    1493.44
# 5   6 2016-12-12   GOOG   262.36  1315.19   61.76  793.41     174.00
# 6   7 2015-11-13   TSLA  1112.92  1342.15  105.69  917.22      57.66
# 7   8 2015-01-31   NVDA   425.99   866.78  190.38  485.90    1434.97
# 8   9 2021-02-14   NFLX   676.41  1033.25  524.23  604.71     350.97
# 9  10 2024-11-17   ADBE   373.11   652.81  322.90  522.85     274.67
#
#        Volume  Dividend Split Ratio             Sector  \
# 0  8846040350      3.57         1:1      Communication
# 1  7346935699      2.85         3:2         Technology
# 2  8027589419      2.28         2:1         Technology
# 3  1939500000      4.51         3:2         Technology
# 4  8984007687      1.93         3:2         Technology
# 5  1434944091      4.09         3:2      Communication
# 6  4621479471      0.33         2:1  Consumer Cyclical
# 7  5081802848      0.33         2:1         Technology
# 8  7748945628      2.64         2:1      Communication
# 9  8357743507      2.41         2:1         Technology
#
#                        Industry Exchange Currency      MarketCap PE Ratio  \
# 0  Media & Interactive Services     NYSE      USD   370815220190    27.40
# 1                Semiconductors      TSE      USD  1289775810656    90.13
# 2        Software – Application      LSE      USD    97815908000    15.67
# 3                Semiconductors     HKEX      USD  1658573090566    83.90
# 4        Software – Application   NASDAQ      USD   315341356874    79.86
# 5             Internet Services      TSX      USD  1324763810463    76.46
# 6            Auto Manufacturers   NASDAQ      USD  1368238210098    73.04
# 7                Semiconductors      TSX      USD  1250223756881    65.29
# 8                 Entertainment     AMEX      USD  1543749651001    42.29
# 9        Software – Application     AMEX      USD  1532453560561    55.93
#
#      EPS Next Earnings Previous Close  Day Range
# 0  16.68    2025-05-19         567.57    1121.61
# 1   0.57    2025-06-23         185.12     539.52
# 2  18.17    2025-07-21         823.07    1133.94
# 3  -4.82    2025-07-23         179.88     925.46
# 4   5.67    2025-06-08        1004.79    1085.19
# 5  18.45    2025-08-03         530.09    1253.43
# 6  -2.44    2025-06-08         445.71    1236.46
# 7  19.56    2025-07-05         482.83     676.40
# 8   2.46    2025-06-06         361.15     509.02
# 9  -4.76    2025-05-17        1107.40     329.91

# %% [markdown]
# -> Confirmaremos se não há dados nulos:

# %%
base_final.isnull().sum()
# Out:
# ID                0
# Date              0
# Ticker            0
# Open              0
# High              0
# Low               0
# Close             0
# Adj Close         0
# Volume            0
# Dividend          0
# Split Ratio       0
# Sector            0
# Industry          0
# Exchange          0
# Currency          0
# MarketCap         0
# PE Ratio          0
# EPS               0
# Next Earnings     0
# Previous Close    0
# Day Range         0
# dtype: int64

# %% [markdown]
# -> Confirmaremos também se há dados duplicados

# %%
base_final.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# -> Assim, visto que a base está padronizada e limpa, baixaremos e depois utilizarmos essa base no EDA:

# %%
base_final.to_csv('base_dados_final.csv', index=True)

# %%
from google.colab import files

# Faz o download do arquivo salvo
files.download('base_dados_final.csv')

# %% [markdown]
# -> Baixaremos para xlsx para o Power BI

# %%
base_final.to_excel('base_dados_final.xlsx', index=True)
